# %%
import pandas as pd
import numpy as np
import csv
import h5py
import pickle
import random
random.seed(42)

# %% [markdown]
# ### Functions to process data:
# make_hint_df - makes a dataframe from the HINT interactions and Gene IDs.
#
# sig_set_nodot - removes all the proteins with . after gene name since these are duplicates.

# %%
### Make a dataframe with HINT interactions and the Gene IDs
def make_hint_df(hint_data):
    gene_sets = []
    for entry in hint_data:
        prot_1 = entry[0].decode('utf-8')
        prot_2 = entry[1].decode('utf-8')
        
        gene_sets.append([prot_1, prot_2])
    return gene_sets

# %%
###Removes genes with . in them (isoforms)
def sig_set_nodot(gene_set, set_name='PPS', output_dir='../../Input_data/first_degree_int', save='True', taiji='False'):
    nodot = []
    if taiji=='True':
        gene_list = pd.read_csv('{0}'.format(gene_set))
        gene_list = set(gene_list['Genes'])
    else:
        gene_list = list(pd.read_csv('{0}'.format(gene_set)))
        gene_list = set(gene_list)
    for gene in gene_list:
        new_gene = gene.split(".")[0]
        if new_gene not in nodot:  
            nodot.append(new_gene)        
    if save=='True':
        with open("{0}/{1}_nodot_genes.pkl".format(output_dir, set_name), "wb") as fp:   #Pickling
            pickle.dump(nodot, fp)
    
    return nodot

# %% [markdown]
# ### Functions to get first degree interactors from the genes of interest
# first_degree_interactors - from a list of interest find all interacting pairs (including first degrees) in the HINT dataset.
#
# first_degree_goldstand_set - from a gene_set of interest (Vinuesa, Crotty, etc.) how many significant genes and first degree interactors are there. Keeps all genes from the gene_set of interest, and provides lables (found in both, found only in significant genes, found only in gene_set.
#
# first_degree_cytoscape_set -  from a gene_set of interest (Vinuesa, Crotty, etc.) how many significant genes and first degree interactors are there. Keeps all genes from the gene_set of interest, and provides lables (found in both, found only in significant genes, found only in gene_set for cytoscape mapping).

# %%
### Finds all first degree interactors of a significant gene list, saves the pairs in a df and a list of all unique genes.
def first_degree_interactors(sig_genes, hint_data, output_dir='../../Input_data/first_degree_int', set_name='PPS', save ='off'):
    gene_sets = []
    genes = []
    for entry in hint_data:
        prot_1 = entry[0].decode('utf-8')
        prot_2 = entry[1].decode('utf-8')

        if prot_1 in sig_genes or prot_2 in sig_genes:
            print('Hit:', prot_1, prot_2)
            gene_sets.append([prot_1, prot_2])

            if prot_1 not in genes:
                genes.append(prot_1)
            if prot_2 not in genes:
                genes.append(prot_2)
                
    if save == 'on':
        print('Saving...')
        gene_set_df = pd.DataFrame(gene_sets, columns = ['Prot_1', 'Prot_2'])
        gene_set_df.to_csv('{0}/{1}_protein_pairs_df.csv'.format(output_dir, set_name), sep =',', index = False)
        
        with open("{0}/{1}_unique_genes.pkl".format(output_dir, set_name), "wb") as fp:   #Pickling
            pickle.dump(genes, fp)
            
        my_genes_df = pd.DataFrame(genes, columns=['Genes'])
        my_genes_df.to_csv('{0}/{1}_unique_genes_df.csv'.format(output_dir, set_name), sep =',', index = False)
        
    
    return gene_set_df, genes, my_genes_df

# %%
### Compares the genes from a set to the found genes
def first_degree_goldstand_set(gene_set, sig_list, hint_data, save='off', set_name='PPS', output_dir='../../Input_data/first_degree_int'):
    gene_sets = []
    all_genes = []
    
    for entry in hint_data:
        prot_1 = entry[0].decode('utf-8')
        prot_2 = entry[1].decode('utf-8')
        
    
        if prot_1 in gene_set or prot_2 in gene_set:
            if prot_1 in sig_list or prot_2 in sig_list:
                print('Hit:', prot_1, prot_2)
                gene_sets.append([prot_1, prot_2])

                if prot_1 not in all_genes:
                    all_genes.append(prot_1)
                if prot_2 not in all_genes:
                    all_genes.append(prot_2)
    
    prot_label = []
    for my_gene in all_genes:
        if my_gene in gene_set and my_gene in sig_list:
            prot_label.append([my_gene, 0])
        if my_gene not in gene_set and my_gene in sig_list:
            prot_label.append([my_gene, 1])
        if my_gene in gene_set and my_gene not in sig_list:
            prot_label.append([my_gene, 2])
        if my_gene not in gene_set and my_gene not in sig_list:
            prot_label.append([my_gene, 3])
        
    if save == 'on':
        print('Saving files ...')
        gene_sets_df = pd.DataFrame(gene_sets, columns = ['Prot_1', 'Prot_2'])
        gene_sets_df.to_csv('{0}/{1}_nodot_gene_sets_df.csv'.format(output_dir, set_name), sep =',', index = False)
        
        gene_labels_df = pd.DataFrame(prot_label, columns = ['Prot', 'Label'])
        gene_labels_df.to_csv('{0}/{1}_nodot_gene_labels_df.csv'.format(output_dir, set_name), sep =',', index = False)
        
        with open("{0}/{1}_nodot_unique_genes.pkl".format(directory, output), "wb") as fp:   #Pickling
            pickle.dump(all_genes, fp)
            
    return gene_sets, all_genes

# %%
### Map the full gold standard set (gene_set)
def first_degree_cytoscape_set(gene_set, sig_list, sig_fd, hint_data, save='off', output='genes', directory='../../Sample_outputs/'):
    gene_sets = []
    all_genes = []
    
    for entry in hint_data:
        prot_1 = entry[0].decode('utf-8')
        prot_2 = entry[1].decode('utf-8')
        
    
        if prot_1 in gene_set and prot_2 in gene_set:
            gene_sets.append([prot_1, prot_2])
        
            if prot_1 not in all_genes:
                all_genes.append(prot_1)
            if prot_2 not in all_genes:
                all_genes.append(prot_2)
                
        if (prot_1 not in gene_set and prot_2 in gene_set) or (prot_1 in gene_set and prot_2  not in gene_set):
            if prot_1 in sig_list and prot_2 in sig_list:
                gene_sets.append([prot_1, prot_2])

                if prot_1 not in all_genes:
                    all_genes.append(prot_1)
                if prot_2 not in all_genes:
                    all_genes.append(prot_2)
    
    prot_label = []
    for my_gene in all_genes:
        if my_gene in gene_set and my_gene in sig_fd:
            prot_label.append([my_gene, 0])
        if my_gene not in gene_set and my_gene in sig_fd:
            prot_label.append([my_gene, 1])
        if my_gene in gene_set and my_gene not in sig_fd:
            prot_label.append([my_gene, 2])
        if my_gene not in gene_set and my_gene not in sig_fd:
            prot_label.append([my_gene, 3])
        
    if save == 'on':
        print('Saving files ...')
        gene_sets_df = pd.DataFrame(gene_sets, columns = ['Prot_1', 'Prot_2'])
        gene_sets_df.to_csv('{0}/{1}_nodot_gene_sets_df.csv'.format(directory, output), sep =',', index = False)
        
        gene_labels_df = pd.DataFrame(prot_label, columns = ['Prot', 'Label'])
        gene_labels_df.to_csv('{0}/{1}_nodot_gene_labels_df.csv'.format(directory, output), sep =',', index = False)
        
        with open("{0}/{1}_nodot_unique_genes.pkl".format(directory, output), "wb") as fp:   #Pickling
            pickle.dump(all_genes, fp)
            
    return gene_sets_df, all_genes, gene_labels_df

# %% [markdown]
# ### Find overlap function:
# find_overlap - gives either the percent, length, or genes that are found in the significant genes with the gene_sets of interest (vinuesa, Crotty, etc.)

# %%
def find_overlap(gene_list, list_name = 'patternB', output='percent'):
    vinuesa_overlap = vinuesa_list & gene_list
    vinuesa_overlap_percent = len(vinuesa_overlap)/len(vinuesa_list)

    beckys_overlap = beckys_genes & gene_list
    beckys_overlap_percent = len(beckys_overlap)/len(beckys_genes)

    crotty_overlap = crotty_mouse & gene_list
    crotty_overlap_percent = len(crotty_overlap)/len(crotty_mouse)

    TFH_review_overlap = TFH_reviews & gene_list
    TFH_review_overlap_percent = len(TFH_review_overlap)/len(TFH_reviews)

    #all_sets_overlap = all_sets & gene_list
    #all_sets_overlap_percent = len(all_sets_overlap)/len(all_sets)
    if output == 'genes':
        return vinuesa_overlap, TFH_review_overlap, crotty_overlap,  beckys_overlap #, liu_overlap, all_sets_overlap
    if output == 'gene_len':
        return len(vinuesa_overlap), len(TFH_review_overlap), len(crotty_overlap), len(beckys_overlap),  #, liu_overlap, all_sets_overlap
    if output == 'genes_gene_len':
        return len(vinuesa_overlap), len(TFH_review_overlap), len(crotty_overlap),  len(beckys_overlap), gene_list # liu_overlap, all_sets_overlap
    if output == 'percent':
        return vinuesa_overlap_percent, TFH_review_overlap_percent, crotty_overlap_percent, beckys_overlap_percent #, all_sets_overlap_percent

# %% [markdown]
# ### Random Overlaps functions:
# These find how many genes would overlapping if a set were randomly made.
#
# random_set - make a set which is of a specific length from the hint genes.
#
# random_overlaps_perm - for a length of a sig_gene set, make a random set, and record a dataframe of how many genes are overlapping with known gene_sets, and repeat a desired amount.
#
# get_random_gene_list - needed for the upset plot, will take the average random and make a gene list that would mach the reviews such that one list of genes will map to the correct random.

# %%
def random_set(gene_set):
    gene_sets = []
    all_genes = []

    random_size_matched_list = set(random.sample(all_hint_genes, len(gene_set)))

    return random_size_matched_list

# %%
def random_overlaps_perm(sig_genes, set_name = 'PatternB', num_perm = 1000, output='percent'):
    for i in range(0,num_perm):
        print('Num_perm=', i)
        random_gene_set = random_set(sig_genes)
        random_genes_overlapping = find_overlap(random_gene_set, output=output)
        df1 = {'Set':['Random_{0}_{1}'.format(set_name, i)],
               'Vinuesa':[random_genes_overlapping[0]], 'TFH Review': [random_genes_overlapping[1]],'Crotty': [random_genes_overlapping[2]], 'Beckys': [random_genes_overlapping[3]],
                'Genes':[random_genes_overlapping[4]]}
        #df1 = {'Set':['Random_{0}_{1}'.format(set_name, i)],
        #       'Vinuesa':[random_genes_overlapping[0]],'TFH Review': [random_genes_overlapping[1]], 'Genes':[random_genes_overlapping[2]]}
            
        #print(df1)
        if i==0:
            random_percents_df = pd.DataFrame(df1)
        else:
            df1 = pd.DataFrame(df1)
            random_percents_df = pd.concat([random_percents_df,df1], axis=0)
        print(random_percents_df)
    
    return random_percents_df

# %%
def get_random_gene_list(random_overlap_set, output_dir = '../../Input_data/first_degree_int', set_name = 'PPS', save='on'):
    random_overlap_set = random_overlap_set.reset_index().drop(columns=['index'])
    random_overlap_subset_human = random_overlap_set.loc[(random_overlap_set['Vinuesa'].eq(np.round(np.mean(random_overlap_set['Vinuesa'])))) 
                                                   & (random_overlap_set['TFH Review'].eq(np.round(np.mean(random_overlap_set['TFH Review']))))].reset_index()
    random_overlap_subset_mouse = random_overlap_set.loc[(random_overlap_set['Crotty'].eq(np.round(np.mean(random_overlap_set['Crotty']))))
                                                  & (random_overlap_set['Beckys'].eq(np.round(np.mean(random_overlap_set['Beckys']))))].reset_index()
    
    random_overlap_genes_human = random_overlap_subset_human.loc[0]['Genes']
    random_overlap_genes_mouse = random_overlap_subset_mouse.loc[0]['Genes']
    gene_list_human = []
    gene_list_mouse = []
    
    for gene in random_overlap_genes_human:
        gene_list_human.append(gene)
    
    for gene in random_overlap_genes_mouse:
        gene_list_mouse.append(gene)
    random_overlap_genes_df_human = pd.DataFrame()
    random_overlap_genes_df_human['Genes'] = gene_list_human
    
    random_overlap_genes_df_mouse = pd.DataFrame()
    random_overlap_genes_df_mouse['Genes'] = gene_list_mouse
    
    if save=='on':
        print('Saving File...')
        with open('{0}/{1}_random_upset_human.txt'.format(output_dir, set_name), 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(random_overlap_genes_human)
            
        with open("{0}/{1}_random_upset_human.pkl".format(output_dir, set_name), "wb") as fp:   #Pickling
            pickle.dump(random_overlap_genes_human, fp)
        
        random_overlap_genes_df_human.to_csv("{0}/{1}_random_upset_human.csv".format(output_dir, set_name), index=False )
        
        with open('{0}/{1}_random_upset_mouse.txt'.format(output_dir, set_name), 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(random_overlap_genes_mouse)
            
        with open("{0}/{1}_random_upset_mouse.pkl".format(output_dir, set_name), "wb") as fp:   #Pickling
            pickle.dump(random_overlap_genes_mouse, fp)
        
        random_overlap_genes_df_mouse.to_csv("{0}/{1}_random_upset_mouse.csv".format(output_dir, set_name), index=False )
    return(random_overlap_genes_human, random_overlap_genes_mouse)

# %% [markdown]
# ### Load in datasets:

# %%
###Load HINT interactions:
ppi = h5py.File('../../Input_data/HomoSapiens_binary_co_complex_Feb2023_1_ppr_0.4.h5', 'r')
#list(ppi.keys())
hint_data = ppi['edges']

with open("../../Input_data/all_hint_genes_list.pkl", "rb") as fp:   #Pickling
    all_hint_genes = pickle.load(fp)

# %%
hint = make_hint_df(hint_data)
hint_df = pd.DataFrame(hint)

# %%
###Load in outputs from network approaches:

#taiji_output = pd.read_csv('../../Input_data/processed_Taiji/final_genes_all_sets_152.csv')
#taiji_set = set(taiji_output['Genes'])

#pps_output = pd.read_csv('/ix/djishnu/Alisa/Tfh/ForPaper/process_network_prop_output/PPS_1_significant_gene_list.csv')
#pps_set= set(pps_output['Genes'])

#pps_output = pd.read_csv('/ix/djishnu/Alisa/Tfh/ForPaper/process_network_prop_output/PPS_nomodule1_significant_gene_list_p0.05.csv')
#pps_set= set(pps_output['Genes'])

#logFC_rna = pd.read_csv('/ix/djishnu/Alisa/Tfh/Network_analysis/data/Pattern_1234_RNASeq_S1234_logFC_top328.csv')
#log_FC_rna_set = set(logFC_rna['gene'])

#pps_noprop = pd.read_csv('/ix/djishnu/Alisa/Tfh/Network_analysis/data/Pattern_1234_Genes_top328.csv')
#pps_noprop_set= set(pps_noprop['Gene'])

pps_noprop = pd.read_csv('../../Input_data/Pattern_1234_Genes_top184.csv')
pps_noprop_set= set(pps_noprop['Gene'])

#rna_output = pd.read_csv('/ix/djishnu/Alisa/Tfh/ForPaper/process_network_prop_output/RNA_Early_Late_significant_gene_list_p0.05.csv')
#rna_set= set(rna_output['Genes'])

###Load in datasets from literature:
with open('../../Input_data/literature_sets/vinuesa_list.pkl',"rb") as fp:
    vinuesa_list = pickle.load(fp)

with open('../../Input_data/literature_sets/TFH_review_list.pkl',"rb") as fp:
    TFH_reviews = pickle.load(fp)

with open('../../Input_data/literature_sets/mouse_gene_list.pkl',"rb") as fp:
    crotty_mouse = pickle.load(fp)

with open('../../Input_data/literature_sets/beckys_list.pkl',"rb") as fp:
    beckys_genes = pickle.load(fp)

# %%
#Generate datasets with first degree interactors.
#taiji_genes = first_degree_interactors(sig_genes = taiji_set, hint_data= hint_data, set_name = 'taiji', save='off')
#pps_genes = first_degree_interactors(sig_genes = pps_set, hint_data= hint_data, set_name = 'pps', save='off')
#rna_genes = first_degree_interactors(sig_genes = rna_set, hint_data= hint_data, set_name = 'rna_2', save='on')
#pps_genes = first_degree_interactors(sig_genes = pps_set, hint_data= hint_data, set_name = 'pps_nomodule1', save='on')
#logFC_genes = first_degree_interactors(sig_genes = log_FC_rna_set, hint_data= hint_data, set_name = 'log_FC_rna_set', save='on')
pps_noprop = first_degree_interactors(sig_genes=pps_noprop_set, hint_data= hint_data, set_name = 'PPS_noprop_set_184', save='on' )
# Out:
# Hit: UBE2Q1 C1QTNF2
# Hit: ZNF707 CASP8
# Hit: ZC3H15 CEP44
# Hit: RNF111 ACTN3
# Hit: FOXQ1 ARHGAP10
# Hit: XPA ARID3A
# Hit: FBL CFLAR
# Hit: GTSE1 BMP2K
# Hit: NSL1 CBX3
# Hit: NSL1 BRCA2
# Hit: COL4A2 C1QTNF2
# Hit: BCL2A1 BCL2L11
# Hit: BCL2A1 BIK
# Hit: BCL2A1 CT45A1
# Hit: BCL2A1 SLC9A3R1
# Hit: BCL2A1 BAX
# Hit: BCL2A1 BAK1
# Hit: BCL2A1 FAM9B
# Hit: BCL2A1 BAD
# Hit: BCL2A1 REL
# Hit: BCL2A1 PMAIP1
# Hit: BCL2A1 BBC3
# Hit: SMAD9 ARID1B
# Hit: SMAD2 ANTXR2
# Hit: SMAD3 CFLAR
# Hit: TCEA2 CEP44
# Hit: TCEA2 AGR2
# Hit: CCDC116 CEP44
# Hit: ATP1A3 AKAP14
# Hit: ATP1A3 CASP8
# Hit: ATP1A1 ECPAS
# Hit: ATP1A1 LIMK2
# Hit: ATP1A1 TCTN3
# Hit: ATP1A1 HIPK4
# Hit: ATP1A1 BIRC3
# Hit: ATP1A1 ILK
# Hit: ATP1A1 NCSTN
# Hit: ATP1A1 KIF14
# Hit: ATP1A1 GOLT1B
# Hit: ATP1A1 MBOAT1
# Hit: ATP1A1 EZH2
# Hit: ATP1A1 DYRK4
# Hit: ATP1A1 CIT
# Hit: ATP1A1 A2M
# Hit: ATP1A1 PEBP1
# Hit: ATP1A1 TMEM17
# Hit: ATP1A1 CAND1
# Hit: ATP1A1 TUBA1C
# Hit: ATP1A1 PPT1
# Hit: ATP1A1 JUN
# Hit: ATP1A1 TRADD
# Hit: ATP1A1 MAPK7
# Hit: ATP1A1 AURKB
# Hit: ATP1A1 MAP1LC3A
# Hit: ATP1A1 NFKB1
# Hit: ATP1A1 IRAK1
# Hit: ATP1A1 CUL3
# Hit: ATP1A1 ERBB2
# Hit: ATP1A1 IQCB1
# Hit: ATP1A1 TPT1
# Hit: ATP1A1 CSK
# Hit: ATP1A1 EGFR
# Hit: ATP1A1 ATP1B1
# Hit: ATP1A1 VIRMA
# Hit: ATP1A1 MAPK4
# Hit: ATP1A1 CDK20
# Hit: ATP1A1 RHOA
# Hit: ATP1A1 COPS5
# Hit: ATP1A1 B7Z8L6
# Hit: ATP1A1 STAU1
# Hit: ATP1A1 TMEM63B
# Hit: ATP1A1 TNFRSF1B
# Hit: ATP1A1 TNFRSF1A
# Hit: ATP1A1 VAV1
# Hit: ATP1A1 CD81
# Hit: ATP1A1 UBC
# Hit: ATP1A1 CDK9
# Hit: ATP1A1 SNAPIN
# Hit: ATP1A1 YIPF5
# Hit: ATP1A1 WDR76
# Hit: MGRN1 AMFR
# Hit: H3C15|H3C14|H3C13 ASF1B
# Hit: IPO11 BSG
# Hit: IFT81 CEP44
# Hit: SP4 ATXN7L1
# Hit: ATG4B ATG3
# Hit: UPK2 CLEC17A
# Hit: CFB CFD
# Hit: LAP3 CBX3
# Hit: UFD1 AMFR
# Hit: HMG20A AGR2
# Hit: HMG20B BRCA2
# Hit: APC AKAP13
# Hit: APC ADGRL1
# Hit: APC AGR3
# Hit: APC ACTN1
# Hit: UQCRC2 CHCHD10
# Hit: UQCRC1 CCNJL
# Hit: BAK1 AKAP13
# Hit: BAK1 BCL2
# Hit: IGFBP3 ADAM12
# Hit: IGFBP5 CLEC17A
# Hit: IGFBP5 CLDN20
# Hit: SKP2 CDC34
# Hit: RTBDN BIRC6
# Hit: NIF3L1 APIP
# Hit: NOP9 BSG
# Hit: NOP9 CEP44
# Hit: APIP VSIG8
# Hit: APIP SMN1|SMN2
# Hit: APIP GORASP2
# Hit: APIP ZBTB25
# Hit: APIP SDCBP
# Hit: APIP NTAQ1
# Hit: APIP NDE1
# Hit: APIP BAZ2B
# Hit: APIP TNPO2
# Hit: APIP FASTKD2
# Hit: APIP HEPHL1
# Hit: APIP VPS25
# Hit: APIP IMPDH2
# Hit: APIP PSMA1
# Hit: APIP DSG4
# Hit: APIP TRAF1
# Hit: APIP TRAF2
# Hit: APIP LNX1
# Hit: APIP TSC22D4
# Hit: APIP NUDT18
# Hit: APIP LYG2
# Hit: APIP SKP1
# Hit: APIP VIM
# Hit: APIP PDZD4
# Hit: APIP CFAP206
# Hit: APIP UBA3
# Hit: PRKAR2A AKAP14
# Hit: PRKAR2A AKAP11
# Hit: PRKAR2A AKAP13
# Hit: PRKAR2B AKAP14
# Hit: PRKAR2B AKAP13
# Hit: PRKAR2B AKAP11
# Hit: MLF1 BRCA2
# Hit: MLF1 AKAP11
# Hit: QPRT ARID1B
# Hit: TMEM14C CDC34
# Hit: TMEM14B CNIH3
# Hit: TMEM14B CNIH2
# Hit: TMEM14B AGPAT4
# Hit: TMEM14B AGR3
# Hit: ITGA3 ABI1
# Hit: ASGR2 CLEC17A
# Hit: FOXL1 ARID3A
# Hit: Q59FK4 ABI1
# Hit: HLA-DPA1 CLU
# Hit: CT55 BFSP2
# Hit: ZMAT3 ACTA2
# Hit: ZMAT2 CDR2
# Hit: MYBL2 ARID4B
# Hit: NEMP1 CNIH3
# Hit: RAC1 CHN1
# Hit: VCL BIRC6
# Hit: VCL ACTN1
# Hit: VCP AMFR
# Hit: PBX4 BFSP2
# Hit: PBX4 BCL6
# Hit: PBX2 BFSP2
# Hit: AIRE CCDC87
# Hit: PTCH1 B3GLCT
# Hit: PTCH1 CCPG1
# Hit: PTCH1 CD200R1
# Hit: PTCH1 ADAM17
# Hit: TIMM44 CHCHD10
# Hit: TUFM CFLAR
# Hit: KMT5C CBX3
# Hit: KMT5C CCNL1
# Hit: RAD9A BCL2
# Hit: ERGIC3 AGPAT4
# Hit: ERGIC3 CNIH3
# Hit: CDR2L BFSP2
# Hit: CDR2L CDR2
# Hit: GSDME BIRC6
# Hit: DLGAP4 ALDH16A1
# Hit: OIP5 CASP10
# Hit: OIP5 BFSP2
# Hit: FBXL19 ABI1
# Hit: BRD9 ARID1B
# Hit: BRD4 CBX3
# Hit: BRD7 AGR2
# Hit: BRD7 ARID1B
# Hit: BRD1 CASP8
# Hit: BRD2 ARHGAP10
# Hit: BRD2 CBX3
# Hit: BRD2 ARSB
# Hit: BRD3 CBX3
# Hit: DNAJA1 CEP44
# Hit: DNAJA1 CD58
# Hit: DNAJA1 CCNJL
# Hit: AKT1 AGR3
# Hit: PTPN11 BTLA
# Hit: LYAR CD2
# Hit: CH25H OTX1
# Hit: CH25H KRTAP12-4
# Hit: MRPL28 CDR2
# Hit: ZSCAN1 ANKRD55
# Hit: SRSF1 ARID3A
# Hit: SRSF2 CIR1
# Hit: HOXA1 CIR1
# Hit: HOXA1 ADAM12
# Hit: MRC2 BRMS1
# Hit: ZNF587 CEP44
# Hit: MYO1C ABI1
# Hit: CHMP7 CASP6
# Hit: CHMP7 HSPA2
# Hit: CHMP7 KLF11
# Hit: CHMP7 UBQLN1
# Hit: CHMP7 CHAT
# Hit: CHMP7 TCTN2
# Hit: CHMP7 GRIN2C
# Hit: CHMP7 RAN
# Hit: CHMP7 HRAS
# Hit: CHMP7 NUP58
# Hit: CHMP7 CREB3
# Hit: CHMP7 SPRED1
# Hit: CHMP7 DNALI1
# Hit: CHMP7 LAMP2
# Hit: CHMP7 CCK
# Hit: CHMP7 FKBP1A
# Hit: CHMP7 PMP22
# Hit: CHMP7 DMWD
# Hit: CHMP7 FGFR3
# Hit: CHMP7 PAFAH1B3
# Hit: CHMP7 GSN
# Hit: SIAE CHSY3
# Hit: SIAE ARSB
# Hit: KRTAP19-1 BCL6
# Hit: SRC ADGRE5
# Hit: SRC CASP8
# Hit: LGALS9 CD58
# Hit: LGALS8 CD58
# Hit: LGALS3 CD58
# Hit: KRTAP11-1 CDKL2
# Hit: KRTAP11-1 AGR3
# Hit: MYO19 BMP2K
# Hit: MYO19 BNIP3L
# Hit: MYO19 ACTN1
# Hit: PLAUR ARSB
# Hit: PLAUR CHSY3
# Hit: LRRC25 ANKRD46
# Hit: LRRC25 CNIH3
# Hit: LRRC25 AGPAT4
# Hit: KIAA1522 ABI1
# Hit: LPCAT1 BBS2
# Hit: PIGS ACAP2
# Hit: TMEM80 CNIH3
# Hit: SRRM1 ABI1
# Hit: SRRM1 AKAP13
# Hit: BBIP1 BBS1
# Hit: PDK1 CELF2
# Hit: PDK3 ACAP2
# Hit: EBP ANKRD46
# Hit: PECR ACTA2
# Hit: MGST3 AGPAT4
# Hit: MGST3 BIRC6
# Hit: CEP128 CEP44
# Hit: CEP120 CEP295
# Hit: ARHGAP26 ARHGAP10
# Hit: NFKBIL1 CASP10
# Hit: PCGF3 CBX3
# Hit: PCGF3 ARID3A
# Hit: RIIAD1 AGR2
# Hit: PTPMT1 BSG
# Hit: RASSF2 BIRC6
# Hit: RASSF7 CLU
# Hit: RSAD1 BSG
# Hit: CHD3 ARID4B
# Hit: CHD3 CBX3
# Hit: CHD3 CASP8
# Hit: CHD5 ARID4B
# Hit: CHD4 CBX3
# Hit: TTC8 BBS1
# Hit: TTC8 BBS2
# Hit: DAG1 AGR2
# Hit: STC2 CCNJL
# Hit: ABCG8 LMNB1
# Hit: ABCG8 ABCG5
# Hit: ABCG8 NUPR1
# Hit: ABCG8 MAL2
# Hit: ABCG8 NR4A1
# Hit: ABCG8 AKT2
# Hit: ABCG8 ANG
# Hit: ABCG8 AGPAT2
# Hit: ABCG8 MESD
# Hit: MCPH1 BIRC6
# Hit: KDM1A ARHGAP15
# Hit: BTG1 NCK2
# Hit: BTG1 CDKN2D
# Hit: BTG1 TUBA1A
# Hit: BTG1 PRMT1
# Hit: BTG1 RNF181
# Hit: BTG1 CNOT8
# Hit: BTG1 GRB2
# Hit: BTG1 FADD
# Hit: BTG1 CNOT7
# Hit: BTG1 XRCC6
# Hit: GGA1 ATXN7L1
# Hit: GGA1 CCDC91
# Hit: GGA2 CA8
# Hit: PRKACG AKAP14
# Hit: PRKACA AKAP14
# Hit: PRKACA AKAP13
# Hit: PRKACA AKAP11
# Hit: PRKACB AKAP11
# Hit: PRKACB AKAP14
# Hit: PSMB4 BCL6
# Hit: PSMB2 AMFR
# Hit: PSMB1 AGR2
# Hit: TRIML2 CDR2
# Hit: SH3KBP1 CD2
# Hit: BEX5 ELAVL4
# Hit: BEX5 FARS2
# Hit: BEX5 SPRED1
# Hit: BEX5 GTF3C3
# Hit: BEX5 MAGEA8
# Hit: BEX5 CRK
# Hit: BEX5 GSN
# Hit: BEX5 NDUFAB1
# Hit: BEX5 PACRGL
# Hit: BEX5 GNG13
# Hit: BEX5 NF2
# Hit: BEX5 ING3
# Hit: BEX5 MORF4L2
# Hit: BEX5 MORF4L1
# Hit: BEX5 GOLGA8F|GOLGA8G
# Hit: BEX5 BFSP2
# Hit: BEX5 LSM1
# Hit: BEX5 FOXD4L3
# Hit: BEX5 COPS7B
# Hit: BEX5 FGFR3
# Hit: BEX5 TARDBP
# Hit: BEX5 EMILIN1
# Hit: BEX5 FKBP1A
# Hit: BEX5 DMWD
# Hit: BEX3 BFSP2
# Hit: BEX2 BRMS1
# Hit: BEX2 CDR2
# Hit: CLDN19 CD200R1
# Hit: DBN1 BMP2K
# Hit: DBN1 ACTN1
# Hit: CDC73 ANXA6
# Hit: GTF2F1 C1QTNF2
# Hit: CAGE1 BFSP2
# Hit: HSP90B1 CLU
# Hit: CETN3 AGR2
# Hit: H3F3B CBX3
# Hit: H3F3B ASF1B
# Hit: KLHL38 AGR2
# Hit: SLC18A1 ANKRD46
# Hit: RALBP1 BIRC6
# Hit: RAP1B CHGB
# Hit: LRIF1 BRMS1
# Hit: LRIF1 CBX3
# Hit: LRIF1 ARL3
# Hit: ZNF410 AGR2
# Hit: IVD ACTN3
# Hit: SUGCT AGR2
# Hit: MAP3K20 CCDC69
# Hit: ITCH CDC34
# Hit: ITCH CFLAR
# Hit: CHMP4B AKAP11
# Hit: CHMP4B CIR1
# Hit: CHMP4B ACTN3
# Hit: CHMP4B ACTN1
# Hit: CHMP4C BSG
# Hit: CHMP4C CBX3
# Hit: CHMP4C CLU
# Hit: CHMP4C ACTN3
# Hit: CHMP4C ACTN1
# Hit: BAX BCL2L12
# Hit: BAX CLU
# Hit: BAX BCL2
# Hit: BAD BCL2
# Hit: COBLL1 IFFO1
# Hit: COBLL1 AMOTL1
# Hit: COBLL1 ITGB3BP
# Hit: COBLL1 CDADC1
# Hit: COBLL1 PPP4R3A
# Hit: COBLL1 DLG3
# Hit: COBLL1 DDHD1
# Hit: COBLL1 DVL2
# Hit: COBLL1 PACSIN1
# Hit: COBLL1 PACSIN3
# Hit: COBLL1 PACSIN2
# Hit: COBLL1 CEP43
# Hit: COBLL1 KIAA1107
# Hit: COBLL1 UHRF1BP1L
# Hit: COBLL1 FAM117A
# Hit: COBLL1 TMBIM6
# Hit: COBLL1 SCML1
# Hit: COBLL1 TLK2
# Hit: COBLL1 AK1
# Hit: COBLL1 HMBOX1
# Hit: COBLL1 SORT1
# Hit: COBLL1 HSP90AA1
# Hit: CDK18 CDR2
# Hit: CDK19 CLU
# Hit: GFI1B ACTN1
# Hit: BFSP2 ANKRD33
# Hit: BFSP2 WASHC3
# Hit: BFSP2 AMOTL2
# Hit: BFSP2 POU6F2
# Hit: BFSP2 KRT31
# Hit: BFSP2 TRIB3
# Hit: BFSP2 COPS6
# Hit: BFSP2 KIF14
# Hit: BFSP2 USHBP1
# Hit: BFSP2 SYCE1L
# Hit: BFSP2 CCDC183
# Hit: BFSP2 HAUS1
# Hit: BFSP2 MYOG
# Hit: BFSP2 MAGEA6
# Hit: BFSP2 DMAP1
# Hit: BFSP2 SYCE1
# Hit: BFSP2 SERTAD3
# Hit: BFSP2 BLOC1S2
# Hit: BFSP2 MBIP
# Hit: BFSP2 CALCOCO1
# Hit: BFSP2 ZNF620
# Hit: BFSP2 C3ORF62
# Hit: BFSP2 MCCD1
# Hit: BFSP2 ZNF343
# Hit: BFSP2 DISC1
# Hit: BFSP2 CDCA4
# Hit: BFSP2 SAPCD2
# Hit: BFSP2 PSMC5
# Hit: BFSP2 KRT27
# Hit: BFSP2 SNAPIN
# Hit: BFSP2 CEP63
# Hit: BFSP2 CEP44
# Hit: BFSP2 HGS
# Hit: BFSP2 KRT24
# Hit: BFSP2 BFSP1
# Hit: BFSP2 CCDC153
# Hit: BFSP2 RINT1
# Hit: BFSP2 KRT37
# Hit: BFSP2 SNAPC5
# Hit: BFSP2 SUFU
# Hit: BFSP2 SCOC
# Hit: BFSP2 RNASE10
# Hit: BFSP2 BICRAL
# Hit: BFSP2 ABI3
# Hit: BFSP2 USP54
# Hit: BFSP2 KRT14
# Hit: BFSP2 PPP1R13B
# Hit: BFSP2 ATF4
# Hit: BFSP2 ECSIT
# Hit: PPP3CA BCL2
# Hit: LRRC49 AHI1
# Hit: LRRC49 CEP44
# Hit: FNDC9 CNIH3
# Hit: E7ER99 ATG3
# Hit: FGFR3 ARHGEF38
# Hit: FGFR3 ATXN7L1
# Hit: FGFR3 CHGB
# Hit: PWWP2A ARID4B
# Hit: GPATCH1 CEP44
# Hit: GINM1 CLU
# Hit: BORCS6 BORCS7
# Hit: CCDC153 CDR2
# Hit: WRAP73 AHI1
# Hit: MTCH2 CHCHD10
# Hit: FN1 CBX3
# Hit: FN1 CELF2
# Hit: FN1 BMP2K
# Hit: CXCL9 CLEC17A
# Hit: NCSTN BSG
# Hit: FAM189A2 ADGRL1
# Hit: SAP30 BRMS1
# Hit: SAP30 CIR1
# Hit: SAP30 ARID4B
# Hit: LGALS7|LGALS7B ACTA2
# Hit: GUCA1A AGR2
# Hit: ATM BSG
# Hit: ATR BSG
# Hit: TTC28 BSG
# Hit: ENO1 ARID1B
# Hit: ENO1 AGR2
# Hit: ENO1 BCL6
# Hit: LLGL2 BIRC6
# Hit: VENTX ATXN7L1
# Hit: CFD HDHD2
# Hit: CFD UBC
# Hit: PTK6 ANKRD55
# Hit: PTK6 ACTN3
# Hit: PRKAA2 CDR2
# Hit: PRKAA2 ABI1
# Hit: MCL1 BCL2
# Hit: SORBS3 CCNL1
# Hit: SORBS2 ABI1
# Hit: ATG16L1 ATG3
# Hit: STIL CCNJL
# Hit: STIL ARID1B
# Hit: FFAR2 AGPAT4
# Hit: ENDOV BBS2
# Hit: ENDOV APAF1
# Hit: DDX23 BSG
# Hit: RAB3IP BBS1
# Hit: BCLAF1 ABI1
# Hit: PARD6A ARID5B
# Hit: ERBB2 CHN1
# Hit: ERBB2 ANKS1B
# Hit: ERBB2 ANXA6
# Hit: ERBB3 B3GLCT
# Hit: KRTAP1-3 ADAM12
# Hit: SHC1 ANKS1B
# Hit: ERBB4 ANKS1B
# Hit: CGRRF1 AGR3
# Hit: GHITM CHCHD10
# Hit: IBTK CEP44
# Hit: TIMM8A ARID3A
# Hit: TIMM8A C1QTNF2
# Hit: DAXX CBX3
# Hit: LGALS9C CD58
# Hit: MAP1B ATG3
# Hit: EIPR1 BBS1
# Hit: SPICE1 ARID1B
# Hit: SPICE1 CEP295
# Hit: SPICE1 CEP44
# Hit: GNAS CAT
# Hit: DPF2 ARID1B
# Hit: DPF3 ARID1B
# Hit: DPF1 ARID1B
# Hit: CLPX CHCHD10
# Hit: CRYGA AGR2
# Hit: BORCS7 TEX35
# Hit: VPS45 CASP8
# Hit: TMCC2 CDR2
# Hit: BORCS8 AGR2
# Hit: GMEB1 CASP8
# Hit: VHL BCL2L14
# Hit: VHL C1QTNF2
# Hit: RIPK3 CASP8
# Hit: C1ORF216 CDR2
# Hit: GPAA1 ACAP2
# Hit: MOGS CHGB
# Hit: RECK ADAM12
# Hit: RECK CEP44
# Hit: KAT2B BRCA2
# Hit: KAT2B ACTN1
# Hit: INSR CD28
# Hit: RUNX1T1 CDR2
# Hit: SPTBN2 ATAD2
# Hit: SPTBN2 ACTR1A
# Hit: KLF11 CLU
# Hit: KLF11 CD248
# Hit: TFAP2D ADAM12
# Hit: TFAP2D AGR2
# Hit: PCNA CAT
# Hit: PCNA CCDC80
# Hit: PCNA ACTN3
# Hit: ZBTB7B BCL6
# Hit: C14ORF119 ACTN1
# Hit: ADNP2 CBX3
# Hit: NDUFS1 ACAP2
# Hit: NDUFS3 CHCHD10
# Hit: NDUFS3 AGR2
# Hit: NDUFS6 CHCHD10
# Hit: ZRANB1 CCNL1
# Hit: REEP4 AGPAT4
# Hit: Q9Y649 ARHGEF38
# Hit: Q9Y649 ATXN7L1
# Hit: PHC3 AGR2
# Hit: HDAC4 CDR2
# Hit: HDAC4 BCL6
# Hit: RNF8 CEP44
# Hit: RNF7 CDC34
# Hit: RNF2 CBX3
# Hit: NRXN1 ARHGAP10
# Hit: CLTC BMP2K
# Hit: CLTB BMP2K
# Hit: FAM118B BSG
# Hit: INTS5 BSG
# Hit: ACTR3 CAT
# Hit: CLUAP1 BBS1
# Hit: CLUAP1 BBS2
# Hit: GPANK1 C1QTNF2
# Hit: ADNP CBX3
# Hit: CNR2 AGPAT4
# Hit: GNL3L BSG
# Hit: POLDIP2 CHCHD10
# Hit: RASA1 ACAP2
# Hit: ACTN3 CTAG1A|CTAG1B
# Hit: ACTN3 USP2
# Hit: ACTN3 KCTD6
# Hit: ACTN3 GLIS2
# Hit: ACTN3 ECM1
# Hit: ACTN3 MYOT
# Hit: ACTN3 KIF14
# Hit: ACTN3 ATP23
# Hit: ACTN3 RTP5
# Hit: ACTN3 PKP2
# Hit: ACTN3 REL
# Hit: ADAM17 CD9
# Hit: CPNE6 AGR2
# Hit: PYCARD CASP8
# Hit: DNMT3B CBX3
# Hit: NDEL1 CLVS2
# Hit: SHANK1 ADGRL1
# Hit: KLC4 CDR2
# Hit: ZDHHC17 CCDC7
# Hit: NAPG AKAP11
# Hit: FAM74A4|FAM74A6 CEP44
# Hit: YAF2 CBX3
# Hit: LARP7 ACTR1A
# Hit: DDX42 AKAP13
# Hit: PTEN CHGB
# Hit: CDKN1B CDC34
# Hit: CDKN1A CHGB
# Hit: CDKN1A ABR
# Hit: UBE2D2 AMFR
# Hit: UBE2D3 AMFR
# Hit: UBE2D1 AMFR
# Hit: SAP130 ARID4B
# Hit: APOE BCL2
# Hit: MLKL CASP8
# Hit: CCDC57 ABI1
# Hit: PAXIP1 CLU
# Hit: CABP5 ANKRD55
# Hit: CABP4 BCL6
# Hit: MBOAT7 CD200R1
# Hit: MBOAT7 ACAP2
# Hit: HMGXB4 ARID4B
# Hit: CDC34 FBXW11
# Hit: CDC34 SDCBP
# Hit: CDC34 MEOX1
# Hit: CDC34 MEOX2
# Hit: CDC34 EIF3K
# Hit: CDC34 TIMM13
# Hit: CDC34 CUL1
# Hit: CDC34 CUL2
# Hit: CDC34 SIAH1
# Hit: CDC34 RAD21
# Hit: CDC34 PPARG
# Hit: CDC34 UBA1
# Hit: CDC34 ZNRF1
# Hit: CDC34 BTRC
# Hit: CDC34 UBC
# Hit: CDC34 RBX1
# Hit: CDC34 CSNK2B
# Hit: CDC37 CDKL2
# Hit: CDC37 CFLAR
# Hit: CDC37 CCDC91
# Hit: S100A8 CHGB
# Hit: S100A7 CA8
# Hit: S100A7 CLVS2
# Hit: RB1CC1 CCPG1
# Hit: DYNC1I1 CADM4
# Hit: CBWD3 AZU1
# Hit: E2F6 CBX3
# Hit: RPGR BIRC6
# Hit: COX6A1 CHCHD10
# Hit: GNG11 CEP44
# Hit: DMC1 BRCA2
# Hit: HPCAL1 C1QTNF2
# Hit: TRIP6 ANKRD55
# Hit: TRIP6 CEP44
# Hit: CCND3 CLU
# Hit: ATP7B CLU
# Hit: RUVBL1 CCDC87
# Hit: RUVBL2 CCDC87
# Hit: RUVBL2 AGR2
# Hit: COX7A2 CHCHD10
# Hit: MGA CBX3
# Hit: TBP AHR
# Hit: VEGFD BIRC6
# Hit: NSD1 AGR2
# Hit: NSD3 CBX3
# Hit: NSD3 CASP8
# Hit: NSD2 CLU
# Hit: NUDCD3 CFLAR
# Hit: NUDCD3 BBS1
# Hit: B7Z3D6 BCL2
# Hit: GMNN CASP8
# Hit: CFAP161 BCL6
# Hit: TIMMDC1 ANKRD46
# Hit: TIMMDC1 AGR3
# Hit: CCDC190 APP
# Hit: KRTAP26-1 CCNJL
# Hit: ZW10 BSG
# Hit: STX2 ANKRD46
# Hit: STX4 ANKRD46
# Hit: RPS3A CHN1
# Hit: RPS3A ASF1B
# Hit: ECE2 CASP10
# Hit: CLIC3 ANKRD55
# Hit: CLIC3 AGR2
# Hit: CASQ2 ACTA2
# Hit: BCL2 BNIPL
# Hit: BCL2 CEBPB
# Hit: BCL2 BCL2L11
# Hit: BCL2 BIK
# Hit: BCL2 KEAP1
# Hit: BCL2 FKBP8
# Hit: BCL2 BID
# Hit: BCL2 HSP90AA1
# Hit: BCL2 VIRMA
# Hit: BCL2 BNIP3L
# Hit: BCL2 SOD1
# Hit: BCL2 RTN4
# Hit: BCL2 NR4A1
# Hit: BCL2 HIF1A
# Hit: BCL2 HRK
# Hit: BCL2 TP53BP2
# Hit: BCL2 NLRP1
# Hit: BCL2 ITPR1
# Hit: BCL2 MDM4
# Hit: BCL2 BNIP2
# Hit: BCL2 BNIP3
# Hit: BCL2 BCAP31
# Hit: BCL2 SQSTM1
# Hit: BCL2 BECN1
# Hit: BCL2 PPP1CA
# Hit: BCL2 PPP2CA
# Hit: BCL2 APP
# Hit: BCL2 CASP8
# Hit: BCL2 CDK1
# Hit: BCL2 TP53
# Hit: BCL2 UBC
# Hit: BCL2 PSEN1
# Hit: BLID CASP8
# Hit: PLK1 CLU
# Hit: PLK1 BIRC6
# Hit: PLK1 CASP8
# Hit: LYRM4 AGR2
# Hit: KLHL23 BNIP3L
# Hit: OAS1 ACTN1
# Hit: STK11IP ARID1B
# Hit: SERPINB2 CA8
# Hit: SERPINB5 ACTA2
# Hit: SERPINB5 CASP8
# Hit: PCGF1 CBX3
# Hit: FAM76A CCNL1
# Hit: PCGF2 CBX3
# Hit: PCGF5 CBX3
# Hit: PCGF6 CBX3
# Hit: MAGED1 CA8
# Hit: ELP3 ATXN7L1
# Hit: ELP1 ATXN7L1
# Hit: CYFIP2 ABI1
# Hit: CCDC87 KASH5
# Hit: CCDC87 CDR2
# Hit: CCDC87 CEP250
# Hit: CCDC87 TRIM27
# Hit: CCDC87 GOLGA2
# Hit: CCDC87 USHBP1
# Hit: CCDC87 KRT15
# Hit: CCDC87 MEPCE
# Hit: CCDC87 TRIM54
# Hit: CCDC87 VIRMA
# Hit: CCDC87 CDK9
# Hit: CCDC87 STAT3
# Hit: DPPA4 CIR1
# Hit: DPPA4 CLU
# Hit: RAC2 CHGB
# Hit: SGTB CD200R1
# Hit: SGTB AGR2
# Hit: SGTB AGR3
# Hit: SGTA AGR2
# Hit: SGTA BCL2L12
# Hit: SGTA AGR3
# Hit: TRIM41 CEP44
# Hit: PEX5 CAT
# Hit: IVL ACTA2
# Hit: SCN3B ANKRD46
# Hit: SCN3B AGPAT4
# Hit: TBK1 CEP44
# Hit: KNL1 ADGRE5
# Hit: PFDN5 ANKRD55
# Hit: DTNB ABI1
# Hit: POMK CERS6
# Hit: HIRA ASF1B
# Hit: RIPK1 CASP10
# Hit: RIPK1 CFLAR
# Hit: RIPK1 CASP8
# Hit: CLPB CHCHD10
# Hit: NKAPD1 CCNL1
# Hit: NKAPD1 ACTN1
# Hit: SLC9A3R2 AHI1
# Hit: SLC9A3R2 ACTN1
# Hit: ZNF417 CEP44
# Hit: ZNF417 CDR2
# Hit: ACTN2 ABI1
# Hit: ACTN1 MYH9
# Hit: ACTN1 HSF5
# Hit: ACTN1 KCTD6
# Hit: ACTN1 IQGAP1
# Hit: ACTN1 JUN
# Hit: ACTN1 KIF14
# Hit: ACTN1 PIAS4
# Hit: ACTN1 CIT
# Hit: ACTN1 PRC1
# Hit: ACTN1 GABARAPL1
# Hit: ACTN1 EIF2S1
# Hit: ACTN1 ZYX
# Hit: ACTN1 PDHX
# Hit: ACTN1 APEX1
# Hit: ACTN1 NCOA1
# Hit: ACTN1 ECT2
# Hit: ACTN1 PDLIM1
# Hit: ACTN1 PSEN1
# Hit: ACTN1 CACNA1C
# Hit: ACTN1 DYNLT1
# Hit: ACTN1 NR1H3
# Hit: ACTN1 GADD45G
# Hit: ACTN1 PSMA1
# Hit: ACTN1 MED14
# Hit: ACTN1 TTN
# Hit: ACTN1 VIRMA
# Hit: ACTN1 YAP1
# Hit: ACTN1 GIT2
# Hit: ACTN1 TSC1
# Hit: ACTN1 MAPRE1
# Hit: ACTN1 USP2
# Hit: ACTN1 LNX1
# Hit: ACTN1 PDLIM4
# Hit: ACTN1 RPS27
# Hit: ACTN1 PDLIM7
# Hit: ACTN1 APPBP2
# Hit: ACTN1 TXN
# Hit: ACTN1 PKN1
# Hit: ACTN1 GTF2H1
# Hit: ACTN1 ANLN
# Hit: ACTN1 Q7Z763
# Hit: ACTN1 FXR1
# Hit: ACTN1 MCM5
# Hit: ACTN1 FXN
# Hit: ACTN1 MCM2
# Hit: ACTN1 ATXN7
# Hit: ACTN1 SYNPO2L
# Hit: ACTN1 COIL
# Hit: ACTN1 SHANK3
# Hit: ACTN1 CTNNA1
# Hit: ACTN1 CBY2
# Hit: ACTN1 CAPZA2
# Hit: ACTN1 MAGEA11
# Hit: ACTN1 MYOZ1
# Hit: ACTN1 ESR2
# Hit: ACTN1 ESR1
# Hit: ACTN1 ARX
# Hit: ACTN1 B2R8Y4
# Hit: ACTN1 MICALL2
# Hit: ACTN1 PPP1CB
# Hit: ACTN1 CBL
# Hit: ACTN1 CACNA1A
# Hit: ACTN1 KPNA2
# Hit: ACTN1 UBC
# Hit: ACTN1 MYOZ2
# Hit: ACTN1 NUMBL
# Hit: ACTN1 ATXN2
# Hit: ACTN1 CFTR
# Hit: ACTN1 SYNPO
# Hit: ACTN1 KIF20A
# Hit: PTPRQ AHI1
# Hit: PTPRA AMFR
# Hit: HAUS7 CEP44
# Hit: PTPRM AMFR
# Hit: PTPRK ANKRD46
# Hit: PTPRK B3GLCT
# Hit: PTPRK ARSB
# Hit: GPR152 ANKRD46
# Hit: GPR152 CLEC17A
# Hit: RNASEH1 CHCHD10
# Hit: MGC50722 CDR2
# Hit: GSTZ1 CLVS2
# Hit: MAP1LC3A ACTA2
# Hit: MAP1LC3A ACTBL2
# Hit: MAP1LC3A BNIP3L
# Hit: MAP1LC3A ATG3
# Hit: MAP1LC3C ACTA2
# Hit: MAP1LC3C ATG3
# Hit: MAP1LC3B ACTA2
# Hit: MAP1LC3B ACTBL2
# Hit: MAP1LC3B BIRC6
# Hit: MAP1LC3B ATG3
# Hit: MAP1LC3B CASP8
# Hit: GDI1 ACAP2
# Hit: CBY2 CEP44
# Hit: ARL5B AKAP14
# Hit: ERLIN1 AMFR
# Hit: ERLIN1 AGR3
# Hit: SPDL1 CA8
# Hit: TLE1 ARL3
# Hit: TLE5 AGR2
# Hit: TLE5 CCNJL
# Hit: PLP1 CLDN20
# Hit: GET3 AGR2
# Hit: COX5B CDR2
# Hit: TM9SF4 CEP44
# Hit: PHF12 ARID4B
# Hit: ADGRL1 NRG1
# Hit: ADGRL1 CD1B
# Hit: ADGRL1 VSIG4
# Hit: ADGRL1 CACNA1A
# Hit: ADGRL1 EDIL3
# Hit: ADGRL1 SHANK2
# Hit: ADGRL1 PSMA3
# Hit: ADGRL1 VIRMA
# Hit: ADGRL1 TMEM30A
# Hit: ADGRL1 SHANK3
# Hit: ADGRL1 KIF20A
# Hit: SPANXB1 ARID4B
# Hit: COX5A CHCHD10
# Hit: HTT CCDC7
# Hit: P2RY12 CERS6
# Hit: MBD3 ARID4B
# Hit: MBD3 AGR2
# Hit: MBD2 ARID4B
# Hit: CMTM7 ADTRP
# Hit: MPC2 CHCHD10
# Hit: TSPAN15 ADGRE5
# Hit: TSPAN17 AGPAT4
# Hit: HEPACAM2 CADM4
# Hit: SLC25A13 CHCHD10
# Hit: SLC25A11 ACTBL2
# Hit: SLC25A11 CHCHD10
# Hit: SLC25A11 ABI1
# Hit: CCDC14 CEP295
# Hit: NDUFA13 CHCHD10
# Hit: TMUB1 AMFR
# Hit: ALDH1L1 CHCHD10
# Hit: ZNF280D CBX3
# Hit: ZNF280C CBX3
# Hit: PTPN12 ARHGAP10
# Hit: SMARCE1 ARID1B
# Hit: SMARCE1 BRMS1
# Hit: SMARCE1 CDR2
# Hit: CLDN7 ANKRD46
# Hit: MAGEB2 ARID3A
# Hit: SMYD1 CBX3
# Hit: MAGEB4 ARID3A
# Hit: MRFAP1 ABI1
# Hit: TMEM150A ACOX3
# Hit: MTO1 CCNJL
# Hit: KLHL12 C1QTNF2
# Hit: MTOR BSG
# Hit: UNG CASP8
# Hit: TRIM65 CCNJL
# Hit: TRIM66 CEP295
# Hit: TRIM66 AHR
# Hit: ITK CD28
# Hit: GABPB1 AGR2
# Hit: HIP1 CASP8
# Hit: BIK ANKRD46
# Hit: BIK CNIH3
# Hit: BID CASP8
# Hit: QDPR CASP8
# Hit: PRAG1 CHGB
# Hit: EPHB6 AGR2
# Hit: NISCH ARID3A
# Hit: NTAQ1 AGR2
# Hit: NTAQ1 AGR3
# Hit: NTAQ1 ARID4B
# Hit: NTAQ1 CDR2
# Hit: POC1A CEP44
# Hit: POC1B CEP44
# Hit: RAPH1 ABI1
# Hit: PARK7 BBS1
# Hit: ROR2 ATXN7L1
# Hit: SNRPD3 CASP8
# Hit: TTC30A ANKRD55
# Hit: IFT46 ANKRD55
# Hit: UNC119B ARL3
# Hit: CRX BOD1L2
# Hit: CRX CA8
# Hit: FRS3 ANKRD55
# Hit: GOLT1B ADGRE5
# Hit: GPR180 CLU
# Hit: ENKD1 CDR2
# Hit: ENKD1 ABI1
# Hit: IQCB1 AHI1
# Hit: IQCB1 BSG
# Hit: ORM1 CLU
# Hit: MAX CBX3
# Hit: MAL CLDN20
# Hit: EDC4 BSG
# Hit: BACH2 ANKRD55
# Hit: KCNIP3 CD177
# Hit: KCNIP3 C1QTNF2
# Hit: PRSS50 CASP8
# Hit: FTCD AGR2
# Hit: UTP20 BSG
# Hit: LEUTX CNIH3
# Hit: LEUTX AGPAT4
# Hit: SMYD2 AHI1
# Hit: SMYD2 AKAP11
# Hit: VAPB AKAP11
# Hit: NPHP3 ARL3
# Hit: TELO2 BSG
# Hit: RGPD3 CEP44
# Hit: TRMT44 CCNJL
# Hit: MOB2 ATG3
# Hit: MOB4 CEP44
# Hit: EEF1A1 BRMS1
# Hit: CA11 BIRC6
# Hit: EIF4E2 CDR2
# Hit: FXR1 CIR1
# Hit: FXR1 CLU
# Hit: FXR1 ABI1
# Hit: FXR1 CDR2
# Hit: ACTR1B ACTR1A
# Hit: ACTR1A HLA-B
# Hit: ACTR1A BIRC3
# Hit: ACTR1A COPS5
# Hit: ACTR1A DCTN2
# Hit: ACTR1A DCTN1
# Hit: ACTR1A JUN
# Hit: ACTR1A APEX1
# Hit: ACTR1A ACTC1
# Hit: ACTR1A VIRMA
# Hit: ACTR1A MAPRE1
# Hit: ACTR1A ZFC3H1
# Hit: ACTR1A CUL3
# Hit: ACTR1A RAB5A
# Hit: ACTR1A ANLN
# Hit: ACTR1A IWS1
# Hit: ACTR1A DYNC1H1
# Hit: ACTR1A CAPZA2
# Hit: ACTR1A NIN
# Hit: ACTR1A ESR1
# Hit: ACTR1A CUL1
# Hit: ACTR1A UBC
# Hit: ACTR1A CFTR
# Hit: WDR74 CCNJL
# Hit: WDR76 CBX3
# Hit: PRPF8 BSG
# Hit: PRPF6 BSG
# Hit: CD177 EWSR1
# Hit: KIAA0930 CEP44
# Hit: ELK4 ACTBL2
# Hit: ELK4 ACAP2
# Hit: RPRM CLEC17A
# Hit: ATXN7L2 CBX3
# Hit: ATXN7L1 MRPL23
# Hit: ATXN7L1 SPRED1
# Hit: ATXN7L1 KAT2A
# Hit: ATXN7L1 SSPOP
# Hit: ATXN7L1 ATXN7L3
# Hit: ATXN7L1 GSN
# Hit: ATXN7L1 VEZF1
# Hit: ATXN7L1 APPBP2
# Hit: ATXN7L1 RAB1A
# Hit: ATXN7L1 RHOC
# Hit: ATXN7L1 KRTAP10-9
# Hit: ATXN7L1 ZNF862
# Hit: ATXN7L1 TTC32
# Hit: ATXN7L1 PHF1
# Hit: FASTKD1 BSG
# Hit: CALML5 ACTA2
# Hit: GAS8 CDR2
# Hit: BTLA TNFRSF14
# Hit: NUP62 AGR3
# Hit: TPM1 CCDC96
# Hit: FOXB1 ARID3A
# Hit: FBXW2 CLVS2
# Hit: TAGLN AGR2
# Hit: SSX2IP AHI1
# Hit: SMARCA1 ARID4B
# Hit: SMARCA2 ARID1B
# Hit: FYN CD2
# Hit: GOLGA6L2 CDR2
# Hit: FCGR2A AGPAT4
# Hit: AGR2 HSPA5
# Hit: AGR2 CD34
# Hit: AGR2 NDUFB2
# Hit: AGR2 MYL6
# Hit: AGR2 TPI1
# Hit: AGR2 UBQLN4
# Hit: AGR2 TYK2
# Hit: AGR2 RTL4
# Hit: AGR2 CANX
# Hit: AGR2 USP20
# Hit: AGR2 EIF3F
# Hit: AGR2 HSP90AB1
# Hit: AGR2 TAGLN2
# Hit: AGR2 GPI
# Hit: AGR2 RAB5C
# Hit: AGR2 STK16
# Hit: AGR2 P4HB
# Hit: AGR2 PSORS1C2
# Hit: AGR2 SH3GLB1
# Hit: AGR2 CREB1
# Hit: AGR2 OSTF1
# Hit: AGR2 RBP5
# Hit: AGR2 THOC1
# Hit: AGR2 NME4
# Hit: AGR2 NME1
# Hit: AGR2 A0A024R4Z4
# Hit: AGR2 HSD3B7
# Hit: AGR2 LACTB
# Hit: AGR2 CYB5R2
# Hit: AGR2 GAPDH
# Hit: AGR2 TSTD2
# Hit: AGR2 PPM1K
# Hit: AGR2 TKT
# Hit: AGR2 GRB2
# Hit: AGR2 VEZF1
# Hit: AGR2 CRMP1
# Hit: AGR2 CCDC90B
# Hit: AGR2 PKM
# Hit: AGR2 POM121
# Hit: AGR2 MED31
# Hit: AGR2 POLR2L
# Hit: AGR2 UBE2I
# Hit: AGR2 RBFOX1
# Hit: AGR2 SDC3
# Hit: AGR2 ATP5F1B
# Hit: AGR2 MEF2B
# Hit: AGR2 SH2D1B
# Hit: AGR2 FABP2
# Hit: AGR2 HCK
# Hit: AGR2 POU6F2
# Hit: AGR2 ASPH
# Hit: AGR2 PSMA1
# Hit: AGR2 FASN
# Hit: AGR2 C3
# Hit: AGR2 PTTG2
# Hit: AGR2 RAB1A
# Hit: AGR2 PGK1
# Hit: AGR2 BCAP31
# Hit: AGR2 CNNM3
# Hit: AGR2 NUP54
# Hit: AGR2 CDKN2AIPNL
# Hit: AGR2 NUP58
# Hit: AGR2 APOBEC3B
# Hit: AGR2 CATSPER1
# Hit: AGR2 FAM117B
# Hit: AGR2 PPIA
# Hit: AGR2 NRF1
# Hit: AGR2 FAM110A
# Hit: AGR2 PRDX6
# Hit: AGR2 SPATA20
# Hit: AGR2 PRDX4
# Hit: AGR2 PRDX1
# Hit: AGR2 DCAF11
# Hit: AGR2 MDH2
# Hit: AGR2 CAMLG
# Hit: AGR2 ANKRD11
# Hit: AGR2 YWHAZ
# Hit: AGR2 TXN
# Hit: AGR2 LYPD3
# Hit: AGR2 UBQLN2
# Hit: AGR2 PRPF18
# Hit: AGR2 UBQLN1
# Hit: AGR2 IMPDH2
# Hit: AGR2 ADCK1
# Hit: AGR2 YWHAB
# Hit: AGR2 LDHA
# Hit: AGR2 YWHAE
# Hit: AGR2 ANXA1
# Hit: AGR2 TRAF2
# Hit: AGR2 ANXA2
# Hit: AGR2 PDIA6
# Hit: AGR2 PDIA3
# Hit: AGR2 LSM1
# Hit: AGR2 GTF2H5
# Hit: AGR2 ALDOA
# Hit: AGR2 ZDHHC24
# Hit: AGR2 NUP62CL
# Hit: AGR2 POGZ
# Hit: AGR3 ASB10
# Hit: AGR3 TGFB1
# Hit: AGR3 SDC3
# Hit: AGR3 FXYD3
# Hit: AGR3 DESI1
# Hit: AGR3 MMGT1
# Hit: AGR3 PDZK1IP1
# Hit: AGR3 SPINT1
# Hit: AGR3 LYPD3
# Hit: AGR3 UBQLN2
# Hit: AGR3 UBQLN1
# Hit: AGR3 CATSPER1
# Hit: AGR3 PRAF2
# Hit: AGR3 CD46
# Hit: AGR3 LSM1
# Hit: AGR3 PTPN1
# Hit: AGR3 BCAR3
# Hit: AGR3 LIME1
# Hit: AGR3 EDA2R
# Hit: AGR3 CNNM3
# Hit: AGR3 ESR2
# Hit: AGR3 NRM
# Hit: AGR3 CASP8
# Hit: CKB ARID3A
# Hit: COMMD3 BSG
# Hit: GPAM CLU
# Hit: DCD ASF1B
# Hit: EIF4ENIF1 ARID3A
# Hit: CUL5 ACTBL2
# Hit: CUL5 ANXA6
# Hit: CUL1 ACTA2
# Hit: CUL1 ACTBL2
# Hit: CUL1 CBX3
# Hit: CUL2 ACTA2
# Hit: CUL2 ACTBL2
# Hit: CUL3 ACTA2
# Hit: CUL3 ACTBL2
# Hit: CUL3 AKAP11
# Hit: CUL3 CASP8
# Hit: CUL3 BSG
# Hit: TRIM28 CBX3
# Hit: CREB3 ADTRP
# Hit: TRIM23 ANKRD55
# Hit: TRIM23 CDR2
# Hit: GNPAT C1QTNF2
# Hit: GNPAT BSG
# Hit: DYNC2LI1 BSG
# Hit: GBA BMP2K
# Hit: MMGT1 ANKRD46
# Hit: SMARCD3 ARID1B
# Hit: TMEM79 ANKRD46
# Hit: PPP6C CEP44
# Hit: OGG1 CHGB
# Hit: ATP5PB CERS6
# Hit: B4GAT1 LARGE2
# Hit: BAG3 ATG3
# Hit: BAG6 CD248
# Hit: BAG6 AMFR
# Hit: BAG6 CLU
# Hit: BAG4 ATAD2
# Hit: MEOX2 CLVS2
# Hit: MEOX2 BOD1L2
# Hit: CD79A CNIH3
# Hit: ARHGAP25 CDHR3
# Hit: ATXN10 BSG
# Hit: FSCN1 CFLAR
# Hit: ECM1 BNIP3L
# Hit: ECM1 CA8
# Hit: FMR1 CASP8
# Hit: GREB1 CASP8
# Hit: LYPD3 BRMS1
# Hit: LYPD3 CASP8
# Hit: DEDD2 CASP8
# Hit: DEDD2 CFLAR
# Hit: GAK BMP2K
# Hit: CDK2AP1 ARID4B
# Hit: HSP90AB1 CFLAR
# Hit: CD28 GRAP2
# Hit: CD28 CD80
# Hit: CD28 GRB2
# Hit: CD28 PIK3R2
# Hit: CD28 PIK3R1
# Hit: MRPS7 ASF1B
# Hit: CD22 ANKRD46
# Hit: TWF2 CHGB
# Hit: GRB2 CELF2
# Hit: GRB2 CLU
# Hit: PSG3 ANKRD46
# Hit: PSG1 ANKRD46
# Hit: GFUS CLVS2
# Hit: CHAT ARHGEF38
# Hit: C19ORF25 BSG
# Hit: POLR2E CHGB
# Hit: POLR2A CBX3
# Hit: TLK1 ASF1B
# Hit: TLK2 ASF1B
# Hit: USP54 CCNJL
# Hit: USP53 CAT
# Hit: DHCR24 ACTA2
# Hit: ITFG2 C1QTNF2
# Hit: TACC2 CLVS2
# Hit: PICK1 BCL2L14
# Hit: TMEM239 CLDN20
# Hit: TMEM237 CNIH3
# Hit: KIF20A CBX3
# Hit: MKI67 CBX3
# Hit: MKI67 ABI1
# Hit: CAB39 CEP44
# Hit: LCA5 CEP44
# Hit: BCL2L14 TRAPPC2L
# Hit: BCL2L14 TRAPPC9
# Hit: BCL2L14 TEPSIN
# Hit: BCL2L14 TRAPPC14
# Hit: BCL2L14 TRAPPC1
# Hit: BCL2L14 PPP2R2D
# Hit: BCL2L14 TRAPPC3
# Hit: BCL2L14 TRAPPC2
# Hit: BCL2L14 TRAPPC5
# Hit: BCL2L14 TRAPPC4
# Hit: BCL2L14 TRAPPC6B
# Hit: BCL2L14 TRAPPC10
# Hit: BCL2L14 DDIT4L
# Hit: BCL2L14 CHEK1
# Hit: BCL2L10 CASP8
# Hit: BCL2L10 APAF1
# Hit: BCL2L12 PPP1R9A
# Hit: BCL2L12 UBC
# Hit: BCL2L12 AMY2A
# Hit: CTU1 CCNJL
# Hit: SIN3B ARID4B
# Hit: SIN3A BRMS1
# Hit: SIN3A ARID4B
# Hit: RPL31 ASF1B
# Hit: TARBP1 BSG
# Hit: SMARCC2 ARID1B
# Hit: SMARCC1 ARID1B
# Hit: BLOC1S6 CEP44
# Hit: SDF4 CLU
# Hit: LHX4 BOD1L2
# Hit: LHX4 ABI1
# Hit: BLOC1S1 BLOC1S4
# Hit: MIB1 ANKRD55
# Hit: PRPF4B AKAP13
# Hit: CYP3A4 AMFR
# Hit: YBX1 CASP8
# Hit: H3-3A|H3-3B CBX3
# Hit: H3-3A|H3-3B ASF1B
# Hit: C3ORF20 BIRC6
# Hit: CHIC2 CDR2
# Hit: CHIC2 CEP44
# Hit: CHIC2 C1QTNF2
# Hit: RNF41 BIRC6
# Hit: ING5 CEP44
# Hit: VSNL1 C1QTNF2
# Hit: TMEM11 BNIP3L
# Hit: BSG PARL
# Hit: BSG VPS35L
# Hit: BSG CACNA1C
# Hit: BSG ABCD1
# Hit: BSG VAC14
# Hit: BSG AQP6
# Hit: BSG COG8
# Hit: BSG MTX1
# Hit: BSG COG3
# Hit: BSG COG2
# Hit: BSG COG1
# Hit: BSG COG7
# Hit: BSG COG5
# Hit: BSG COG4
# Hit: BSG C3ORF33
# Hit: BSG RINT1
# Hit: BSG SLC25A24
# Hit: BSG ATP2B4
# Hit: BSG TTI2
# Hit: BSG CFTR
# Hit: BSG UFL1
# Hit: BSG DOCK8
# Hit: BSG METAP2
# Hit: BSG TBRG4
# Hit: BSG SLC25A30
# Hit: BSG XPO4
# Hit: BSG XPO7
# Hit: BSG SAMD1
# Hit: BSG PDLIM7
# Hit: BSG DDC
# Hit: BSG GCFC2
# Hit: BSG FASTKD3
# Hit: BSG FAM162A
# Hit: BSG UBE2A
# Hit: BSG USP50
# Hit: BSG IPO8
# Hit: BSG MYBBP1A
# Hit: BSG VPS53
# Hit: BSG VPS52
# Hit: BSG VPS51
# Hit: BSG VPS50
# Hit: BSG MDN1
# Hit: BSG EARS2
# Hit: BSG NLRX1
# Hit: BSG DNAAF5
# Hit: BSG INTS12
# Hit: BSG KNTC1
# Hit: BSG HSPA12B
# Hit: BSG HSPA12A
# Hit: BSG FANCA
# Hit: BSG NFKB1
# Hit: BSG RANBP3
# Hit: BSG EXOC2
# Hit: BSG PDS5A
# Hit: BSG GCN1
# Hit: BSG PDS5B
# Hit: BSG RAD51C
# Hit: BSG BTAF1
# Hit: BSG TBCD
# Hit: BSG AGPAT5
# Hit: BSG STEAP3
# Hit: BSG METTL15
# Hit: BSG PPIA
# Hit: BSG MAD2L1
# Hit: BSG BIRC3
# Hit: BSG DNM3
# Hit: BSG MAP2K7
# Hit: BSG ACAD10
# Hit: BSG LARS2
# Hit: BSG CAND2
# Hit: BSG CAND1
# Hit: BSG NOP56
# Hit: BSG SLC16A13
# Hit: BSG VIRMA
# Hit: BSG APOL2
# Hit: BSG HEATR6
# Hit: BSG RFXANK
# Hit: BSG EXOC3
# Hit: BSG EXOC1
# Hit: BSG EXOC4
# Hit: BSG SLC16A1
# Hit: BSG SYMPK
# Hit: RIF1 BRMS1
# Hit: RIF1 ARL3
# Hit: AK1 B3GLCT
# Hit: WDR83 CEP44
# Hit: EPS8 ABI1
# Hit: SH2D3C AGPAT4
# Hit: SH2D3C CAT
# Hit: SH2D3C ANXA3
# Hit: HERPUD1 AMFR
# Hit: HERPUD1 CD58
# Hit: TRA2B ABI1
# Hit: BRMS1L ARID4B
# Hit: UBXN11 ABI1
# Hit: NAAA ARSB
# Hit: TSC22D4 CLU
# Hit: CD2BP2 CD2
# Hit: ADAMTSL4 CBX3
# Hit: CYB561 ANKRD46
# Hit: ACOX3 FKBP6
# Hit: ACOX3 MICU2
# Hit: DISC1 CLU
# Hit: SPACA1 AGPAT4
# Hit: STXBP1 APBA1
# Hit: CFLAR BCL2L1
# Hit: CFLAR TNFSF10
# Hit: CFLAR SF3B1
# Hit: CFLAR SF3B3
# Hit: CFLAR MIF
# Hit: CFLAR TNFRSF10B
# Hit: CFLAR TNFRSF10A
# Hit: CFLAR PSMD2
# Hit: CFLAR CACYBP
# Hit: CFLAR PLIN5
# Hit: CFLAR RAF1
# Hit: CFLAR EPPK1
# Hit: CFLAR DOK2
# Hit: CFLAR SUN2
# Hit: CFLAR FAS
# Hit: CFLAR AARSD1
# Hit: CFLAR EIF3F
# Hit: CFLAR HNRNPL
# Hit: CFLAR Q53FC7
# Hit: CFLAR Q96BE0
# Hit: CFLAR SPATS1
# Hit: CFLAR TRAF1
# Hit: CFLAR TRAF2
# Hit: CFLAR FADD
# Hit: CFLAR UBC
# Hit: CFLAR RPS29
# Hit: CFLAR USP15
# Hit: CFLAR B4DYC6
# Hit: CFLAR DEDD
# Hit: CFLAR CASP10
# Hit: XRN1 ADGRE5
# Hit: FBXO6 CLU
# Hit: BCORL1 CBX3
# Hit: PIK3R1 CBX3
# Hit: POLD1 CHGB
# Hit: SREK1IP1 CCNL1
# Hit: STAU1 ATAD2
# Hit: CHGB MGLL
# Hit: CHGB NR2B3
# Hit: CHGB TAZ
# Hit: CHGB F2Z2H6
# Hit: CHGB LRRK2
# Hit: CHGB UBTF
# Hit: CHGB YLPM1
# Hit: CHGB RXRG
# Hit: CHGB ANXA7
# Hit: CHGB SLC25A6
# Hit: CHGB TK1
# Hit: CHGB RCC1
# Hit: CHGB SAFB2
# Hit: CHGB Q8NBB9
# Hit: CHGB I7HJJ0
# Hit: CHGB ATXN2
# Hit: SORT1 CNIH3
# Hit: AQP12B AGPAT4
# Hit: SPATA7 BNIP3L
# Hit: MAP3K14 CASP8
# Hit: CCZ1B CEP44
# Hit: KDM2B CBX3
# Hit: C2CD6 CDR2
# Hit: L3MBTL2 CBX3
# Hit: PPTC7 BNIP3L
# Hit: LIN37 CDR2
# Hit: PRKAR1B AKAP14
# Hit: PRKAR1B BOD1L2
# Hit: NOL3 CASP8
# Hit: CORO1A CEP44
# Hit: CDC42 CDC42EP3
# Hit: CHAF1B CBX3
# Hit: CHAF1B ASF1B
# Hit: BIN3 ARHGEF37
# Hit: BIN3 AZU1
# Hit: ECT2 CIR1
# Hit: CYB5B BNIP3L
# Hit: VPS33A CASP8
# Hit: GC CLU
# Hit: BRK1 ABI1
# Hit: RELB ARID1B
# Hit: RELA AHR
# Hit: CLEC17A TMEM218
# Hit: CLEC17A NCK2
# Hit: CLEC17A NINJ2
# Hit: CLEC17A FAM3C
# Hit: CLEC17A TMEM201
# Hit: CLEC17A TM4SF4
# Hit: CLEC17A PELI1
# Hit: CLEC17A PELI2
# Hit: CLEC17A CTXN3
# Hit: KLK5 CASP8
# Hit: THOC6 ABI1
# Hit: COPS5 ACTA2
# Hit: ZNF598 CEP44
# Hit: MAF AHR
# Hit: ECD CEP44
# Hit: LRRC3B CD37
# Hit: CXADR ANKRD46
# Hit: TTC23 CDR2
# Hit: TTC23 ABI1
# Hit: MAD2L2 CBX3
# Hit: KTN1 CDR2
# Hit: KTN1 ABI1
# Hit: CEP57L1 CEP44
# Hit: CEP57L1 CDR2
# Hit: FAM90A1 CDR2
# Hit: SLC16A2 ANKRD46
# Hit: SLC16A2 CNIH3
# Hit: DYNLL1 ASF1B
# Hit: CACNA1A ABI1
# Hit: CACNA1B APBA1
# Hit: PSMA3 CCDC69
# Hit: PSMA1 CDR2
# Hit: CP CLU
# Hit: AGPAT4 HSD17B13
# Hit: AGPAT4 HSD17B11
# Hit: AGPAT4 SLC7A8
# Hit: AGPAT4 TSPAN5
# Hit: AGPAT4 MFF
# Hit: AGPAT4 GPR101
# Hit: AGPAT4 SLC35C2
# Hit: AGPAT4 MFSD14B
# Hit: AGPAT4 RETREG3
# Hit: AGPAT4 JAGN1
# Hit: KIAA1217 ABI1
# Hit: ACTL6A ARID1B
# Hit: FOXO3 CEP44
# Hit: SORBS1 ABI1
# Hit: PPP1CA AKAP11
# Hit: SRP9 CDHR3
# Hit: UBR1 ANXA3
# Hit: H4C1|H4C2|H4C3|H4C4|H4C5|H4C6|H4C8|H4C9|H4C11|H4C12|H4C13|H4C14|H4C15|H4-16 ATAD2
# Hit: H4C1|H4C2|H4C3|H4C4|H4C5|H4C6|H4C8|H4C9|H4C11|H4C12|H4C13|H4C14|H4C15|H4-16 CBX3
# Hit: H4C1|H4C2|H4C3|H4C4|H4C5|H4C6|H4C8|H4C9|H4C11|H4C12|H4C13|H4C14|H4C15|H4-16 ASF1B
# Hit: PCM1 ABI1
# Hit: GSK3B AKAP11
# Hit: NCKAP1 ABI1
# Hit: LRRK2 CBX3
# Hit: LRRK2 CDC42EP3
# Hit: CRMP1 AMFR
# Hit: MRPL12 CBX3
# Hit: NCOR2 AHR
# Hit: NFKB1 ACTA2
# Hit: GABARAP ATG3
# Hit: RPS19BP1 CBX3
# Hit: AP1M1 CASP8
# Hit: CCDC146 CDR2
# Hit: CCDC146 CEP44
# Hit: DLG4 CLU
# Hit: CDH13 CASP8
# Hit: OSBPL8 AMFR
# Hit: OSBPL6 AZU1
# Hit: TUBB4B ABI1
# Hit: ARHGAP15 TGFBR1
# Hit: ARHGAP10 C2CD2
# Hit: ARHGAP10 SH3BP2
# Hit: ARHGAP10 VIRMA
# Hit: ARHGAP10 RHOA
# Hit: ARHGAP10 ANKS1A
# Hit: GSTM3 CLVS2
# Hit: DST ABI1
# Hit: UBE2D4 AMFR
# Hit: RING1 CBX3
# Hit: TICAM1 CASP8
# Hit: PTH1R CERS6
# Hit: PHETA2 CLVS2
# Hit: SETX CLU
# Hit: HMGB1 CCNL1
# Hit: LMO1 CEP44
# Hit: LMO1 ABI1
# Hit: PBRM1 ARID1B
# Hit: BEX1 CASP8
# Hit: MCRS1 BRMS1
# Hit: MCRS1 CEP44
# Hit: ERAL1 CEP44
# Hit: GJB1 CD37
# Hit: TRIP10 ABI1
# Hit: LIN7C APBA1
# Hit: CLSTN1 CCNL1
# Hit: EIF3H ABI1
# Hit: FADD CASP8
# Hit: BARD1 CBX3
# Hit: CD46 ANKRD46
# Hit: PVR ANKRD46
# Hit: FRY CDKL2
# Hit: HELZ CCNJL
# Hit: HELZ ARID3A
# Hit: COPE CDC42EP3
# Hit: NRIP1 AHR
# Hit: RHOA AKAP13
# Hit: NSG2 ANKRD46
# Hit: SH3GLB1 CCNL1
# Hit: ARHGEF28 AKAP13
# Hit: PRKAR1A AKAP11
# Hit: ATG10 ATG3
# Hit: ATG12 ATG3
# Hit: KIAA0753 CEP44
# Hit: CASK BNIP3L
# Hit: CASK APBA1
# Hit: GPR84 CERS6
# Hit: GLCE CASP8
# Hit: IL16 ANXA6
# Hit: ANXA3 TP53
# Hit: ANXA3 EMG1
# Hit: ANXA3 UNC119
# Hit: ANXA3 IGSF21
# Hit: ANXA3 EYA1
# Hit: ANXA2 AKAP13
# Hit: ANXA6 SHOC2
# Hit: ANXA6 VIRMA
# Hit: AMFR HSPA5
# Hit: AMFR DERL1
# Hit: AMFR SELENOS
# Hit: AMFR DERL2
# Hit: AMFR UBE2G2
# Hit: AMFR UBE2G1
# Hit: AMFR OS9
# Hit: AMFR TOM1L1
# Hit: AMFR INSIG2
# Hit: AMFR HMGCR
# Hit: AMFR GET4
# Hit: AMFR UBE2N
# Hit: AMFR CD3D
# Hit: AMFR HTR3E
# Hit: CLVS2 PCYT2
# Hit: CLVS2 MYH7
# Hit: CLVS2 FLAD1
# Hit: CLVS2 GYS1
# Hit: CLVS2 S100A7A
# Hit: MFF ANKRD46
# Hit: GEM CDR2
# Hit: DTNBP1 BLOC1S4
# Hit: DTNBP1 ABI1
# Hit: VPS28 AKAP11
# Hit: TCHP CEP44
# Hit: TCHP CDR2
# Hit: DYNC2I2 CCNJL
# Hit: SS18L1 ARID1B
# Hit: VARS2 ABI1
# Hit: NDN CDR2
# Hit: CHAF1A CBX3
# Hit: CHAF1A ASF1B
# Hit: SCGB2A2 CASP8
# Hit: AIMP2 BLOC1S4
# Hit: SMARCA4 ARID1B
# Hit: PPP6R3 CEP44
# Hit: PPP6R1 CEP44
# Hit: CASP6 CASP8
# Hit: CASP7 CASP8
# Hit: CASP2 CASP8
# Hit: CASP3 CASP8
# Hit: CASP8 CASP8AP2
# Hit: CASP8 PLIN4
# Hit: CASP8 S100A14
# Hit: CASP8 CCNL1
# Hit: CASP8 FASLG
# Hit: CASP8 EPSTI1
# Hit: CASP8 DKFZP762B153
# Hit: CASP8 ST14
# Hit: CASP8 TRAF6
# Hit: CASP8 UMPS
# Hit: CASP8 PRDM14
# Hit: CASP8 ATAD2
# Hit: CASP8 XIAP
# Hit: CASP8 TNFSF10
# Hit: CASP8 Q5SVL1
# Hit: CASP8 TRADD
# Hit: CASP8 SOX2
# Hit: CASP8 CASP9
# Hit: CASP8 PEA15
# Hit: CASP8 TRAF2
# Hit: CASP8 PDIA6
# Hit: CASP8 CASC3
# Hit: CASP8 TNF
# Hit: CASP8 DEDD
# Hit: CASP8 HBP1
# Hit: CASP8 TFCP2
# Hit: CASP8 BAP1
# Hit: CASP9 APAF1
# Hit: MYC ATAD2
# Hit: MYC CDR2
# Hit: XIAP APAF1
# Hit: DKFZP762B153 ATG3
# Hit: PNMA1 ACTA2
# Hit: ODF2 CEP44
# Hit: ODF4 CNIH3
# Hit: FAM209A ANKRD46
# Hit: KIF11 CEP295
# Hit: C1ORF94 CCNJL
# Hit: RBM18 ACTA2
# Hit: EMP1 CD37
# Hit: MAP7D3 CEP44
# Hit: KIF14 AHR
# Hit: KIF14 AKAP11
# Hit: KIF14 ARID5B
# Hit: KIF14 CBX3
# Hit: KIF14 CCR7
# Hit: PRPF38A CCNL1
# Hit: APBB1 CEP44
# Hit: WDR5 CBX3
# Hit: SMARCD2 ARID1B
# Hit: SMARCD1 ARID1B
# Hit: SMARCD1 CDR2
# Hit: SMARCD1 ABI1
# Hit: CEP295 EXOC1
# Hit: CEP295 CEP43
# Hit: CEP295 CEP135
# Hit: CEP295 VIRMA
# Hit: SCNM1 CEP44
# Hit: SCNM1 CDR2
# Hit: WDR62 CEP44
# Hit: TTC32 ARID3A
# Hit: CDC23 CEP44
# Hit: PRC1 CBX3
# Hit: PDZD4 CDR2
# Hit: RYBP CBX3
# Hit: ZNF644 CBX3
# Hit: CDH23 ABI1
# Hit: HGS CDR2
# Hit: ABR TP53
# Hit: ABR CEP250
# Hit: ABR VIRMA
# Hit: ABR ABL1
# Hit: BAIAP2 ABI1
# Hit: E9PBK3 CBX3
# Hit: ARAF ACTA2
# Hit: NUDT21 AKAP13
# Hit: EHBP1 ACAP2
# Hit: LSAMP CD248
# Hit: CBX6 CBX3
# Hit: CBX5 CBX3
# Hit: CBX3 STK16
# Hit: CBX3 H1-4
# Hit: CBX3 HIST1H4J
# Hit: CBX3 SGO1
# Hit: CBX3 RAD54L2
# Hit: CBX3 DSN1
# Hit: CBX3 CBX8
# Hit: CBX3 CBX1
# Hit: CBX3 NLRP3
# Hit: CBX3 CCDC71L
# Hit: CBX3 CHAMP1
# Hit: CBX3 METTL14
# Hit: CBX3 MAP2K1
# Hit: CBX3 ZMYND8
# Hit: CBX3 SUV39H1
# Hit: CBX3 BAP1
# Hit: JADE1 ACTA2
# Hit: PSEN1 APBA1
# Hit: NRBF2 CEP44
# Hit: REP15 ARID3A
# Hit: CD248 ICAM5
# Hit: TMEM248 ANKRD46
# Hit: CLEC4D ANKRD46
# Hit: UBN2 ASF1B
# Hit: PSTPIP1 CD2
# Hit: IFNLR1 ANKRD46
# Hit: BOD1L2 TRAF2
# Hit: CYCS APAF1
# Hit: BCL2L1 BNIP3L
# Hit: BCL2L1 APAF1
# Hit: NXN ABI1
# Hit: PCMT1 AKAP13
# Hit: PCMT1 ABI1
# Hit: YIPF2 ACTA2
# Hit: ABL1 ABI1
# Hit: SHANK3 CLU
# Hit: SHANK3 ABI1
# Hit: HNRNPK ABI1
# Hit: H2BC1 ARID5B
# Hit: HSP90AA1 AHR
# Hit: CD53 CD37
# Hit: CD53 CNIH2
# Hit: HAX1 CLU
# Hit: RAB35 ACAP2
# Hit: DOK2 ASF1B
# Hit: DOK2 ACAP2
# Hit: DOK5 BNIP3L
# Hit: PDIA3 CLU
# Hit: ARMC6 CLU
# Hit: CCDC120 CDR2
# Hit: TSGA10 CEP44
# Hit: HSPA7 ABI1
# Hit: HSPA6 ABI1
# Hit: HSPA5 CLU
# Hit: HSPA5 CCNJL
# Hit: HSPA4 APAF1
# Hit: MUC1 ANKRD46
# Hit: CEP85 CEP44
# Hit: XPO1 AHR
# Hit: TTR CDR2
# Hit: MMS22L ASF1B
# Hit: ATAD2 SUMO2
# Hit: ATAD2 BCAR3
# Hit: ATAD2 VIRMA
# Hit: CAMK1D BNIP3L
# Hit: C4ORF46 CDR2
# Hit: CEP170 CEP44
# Hit: HOMER1 ABI1
# Hit: HOMER3 ABI1
# Hit: ZGPAT CDR2
# Hit: EWSR1 BNIP3L
# Hit: HDAC1 ARID5B
# Hit: ATG7 ATG3
# Hit: DPY30 AKAP14
# Hit: NFASC ABI1
# Hit: RINT1 BNIP3L
# Hit: SMARCB1 ARID1B
# Hit: TCF4 ABI1
# Hit: BTK ARID3A
# Hit: FOXF2 CCNJL
# Hit: CST9 ANKRD46
# Hit: C16ORF54 ANKRD46
# Hit: TMEM52B CNIH3
# Hit: PRG2 ACTA2
# Hit: PRDX2 AKAP13
# Hit: VASP ABI1
# Hit: LAMP2 CCNL1
# Hit: CD37 LHFPL5
# Hit: POLR3C CEP44
# Hit: CRB3 ANKRD46
# Hit: KIF5B CDR2
# Hit: CANX CLU
# Hit: LENG1 CDR2
# Hit: UMPS CDC42EP3
# Hit: CDK11A CCNL1
# Hit: AMIGO1 ANKRD46
# Hit: ZC2HC1A CEP44
# Hit: CYP2E1 CLU
# Hit: SECTM1 ANKRD46
# Hit: DHX57 CEP44
# Hit: RPSA CDR2
# Hit: CCNJL SALL2
# Hit: CCNJL ARHGEF1
# Hit: CCNJL TROAP
# Hit: CCNJL TRAF2
# Hit: CCNJL RSPRY1
# Hit: CCNJL ZNF503
# Hit: RPL23 CLU
# Hit: ATG3 KRT85
# Hit: ATG3 ATG5
# Hit: TTK CEP44
# Hit: OAZ2 CDR2
# Hit: PRR4 CLU
# Hit: TMEM120B BNIP3L
# Hit: CCDC185 CEP44
# Hit: UQCC1 CDR2
# Hit: UQCC2 CDR2
# Hit: CIR1 MB21D2
# Hit: CIR1 AGO3
# Hit: FOXH1 ARID3A
# Hit: IL20RB CLU
# Hit: HP CLU
# Hit: RETREG3 CERS6
# Hit: RETREG3 ANKRD46
# Hit: CD200R1L NKX3-1
# Hit: SH2D4A CDR2
# Hit: THAP11 ACTA2
# Hit: LUC7L ARID3A
# Hit: TMPRSS2 CNIH2
# Hit: TMPRSS2 ANKRD46
# Hit: TMPRSS2 CNIH3
# Hit: TMPRSS4 BNIP3L
# Hit: CCDC80 VIRMA
# Hit: CCDC80 CUL4B
# Hit: COMMD1 CLU
# Hit: TSC1 ABI1
# Hit: TSC1 CDR2
# Hit: METTL14 CLU
# Hit: RNASE13 CLU
# Hit: H2AP CEP44
# Hit: ANO4 VIRMA
# Hit: POLR1C CLU
# Hit: NR2F1 AHR
# Hit: DDB1 AHR
# Hit: CEP44 TNRC6C
# Hit: CEP44 GLI3
# Hit: CEP44 CENPP
# Hit: CEP44 SPAG5
# Hit: CEP44 PASK
# Hit: CEP44 KLHL7
# Hit: CEP44 FXR2
# Hit: CEP44 TNRC6B
# Hit: CEP44 QSOX2
# Hit: CEP44 CC2D1A
# Hit: CEP44 TP53BP2
# Hit: CEP44 CEP63
# Hit: CEP44 NCK2
# Hit: CEP44 BYSL
# Hit: CEP44 AP3M1
# Hit: CEP44 RBM15
# Hit: CEP44 BEND7
# Hit: CEP44 MGC24125
# Hit: CEP44 CEP43
# Hit: CEP44 PSMD3
# Hit: CEP44 DIP2A
# Hit: CEP44 FAM161A
# Hit: CEP44 EXOC4
# Hit: CEP44 CEP135
# Hit: CCNL1 ZRSR2
# Hit: VIRMA ARID1B
# Hit: ANKRD46 EFNB2
# Hit: ANKRD46 HSD17B13
# Hit: ANKRD46 HSD17B11
# Hit: ANKRD46 SLC10A6
# Hit: ANKRD46 RELL2
# Hit: ANKRD46 APH1A
# Hit: ANKRD46 GPR42
# Hit: ANKRD46 GPHA2
# Hit: ANKRD46 EFNB1
# Hit: ANKRD46 ST6GALNAC6
# Hit: ANKRD46 BSCL2
# Hit: ANKRD46 LAMTOR5
# Hit: ENAH ABI1
# Hit: KANSL1 CDR2
# Hit: ACTC1 ARID1B
# Hit: ZNF35 CDR2
# Hit: FHL2 ABI1
# Hit: ARID3A ARID3B
# Hit: ARID3A PTMA
# Hit: ARID3A HSPE1
# Hit: CDC42EP3 SRPK1
# Hit: ODF3L2 ABI1
# Hit: SYNE2 ABI1
# Hit: ABI1 PRPSAP1
# Hit: ABI1 PRPSAP2
# Hit: ABI1 HSD17B12
# Hit: ABI1 TUBB
# Hit: ABI1 RCOR3
# Hit: ABI1 RBM15
# Hit: ABI1 RBM14
# Hit: ABI1 PRPS2
# Hit: ABI1 PRPS1
# Hit: ABI1 CCHCR1
# Hit: ABI1 NCK1
# Hit: ABI1 NCK2
# Hit: ARNT2 CDR2
# Hit: YAP1 ARID1B
# Hit: PSMD7 CDR2
# Hit: ARID1B CAND1
# Hit: ARID1B ARID1A
# Hit: GMPPA CDR2
# Hit: FAM110A CDR2
# Hit: CD2 CD2AP
# Hit: TBC1D22B CDR2
# Hit: RCOR3 CDR2
# Hit: CDR2 CCHCR1
# Saving...

# %%
taiji_sig_set = sig_set_nodot('../../Input_data/processed_Taiji/final_genes_all_sets_152.csv', set_name='Taiji', output_dir='../../Sample_outputs', save='True', taiji='True')

# %%
taiji_genes = pd.read_csv('../../Input_data/first_degree_int/taiji_unique_genes_df.csv')
#pps_genes = pd.read_csv('../../Input_data/first_degree_int/pps_unique_genes_df.csv')
#rna_genes = pd.read_csv('../../Input_data/first_degree_int/rna_unique_genes_df.csv')

# %%
unique_to_df1 = set(rna_genes['Genes']) - set(pps_genes['Genes'])

# %%
pps_taiji_genes_fd = set(taiji_genes['Genes']).union(set(pps_genes['Genes']))
pps_taiji_fd_df = pd.DataFrame()
pps_taiji_fd_df['uGenes'] = list(pps_taiji_genes_fd)
pps_taiji_fd_df.to_csv('../../Input_data/first_degree_int/pps_taiji_nomodule1_unique_genes_df.txt', index=False)
#pps_taiji = pps_set.union(taiji_set)

# %%
pps_taiji_rna_genes_fd = set(taiji_genes['Genes']).union(set(pps_genes['Genes'])).union(set(rna_genes['Genes']))
pps_taiji_rna_fd_df = pd.DataFrame()
pps_taiji_rna_fd_df['uGenes'] = list(pps_taiji_rna_genes_fd)
pps_taiji_rna_fd_df.to_csv('../../Input_data/first_degree_int/pps_taiji_rna_unique_genes_df.txt', index=False)
#pps_taiji = pps_set.union(taiji_set)

# %%
pps_unique = pd.read_csv('../../Input_data/first_degree_int/pps_unique_genes_df.csv')
taiji_unique = pd.read_csv('../../Input_data/first_degree_int/taiji_unique_genes_df.csv')
rna_unique = pd.read_csv('../../Input_data/first_degree_int/rna_unique_genes_df.csv')

# %%
pps_unique = list(pps_unique['Genes'])
taiji_unique= list(taiji_unique['Genes'])
rna_unique = list(rna_unique['Genes'])

# %%
#Find overlap with known datasets:
vin_taiji_overlap = first_degree_goldstand_set(vinuesa_list, taiji_genes, hint_data, set_name= 'taiji')

# %%
#taiji_overlapping = find_overlap(taiji, list_name='taiji_151', output='percent')

#taiji_overlapping_random = random_overlaps_perm(taiji_set, set_name = 'taiji', num_perm=1000,output= 'genes_gene_len')
#taiji_overlapping_random_fd = random_overlaps_perm_(taiji_genes['Genes'], set_name = 'taiji_fd', num_perm=1000, output= 'genes_gene_len')
#taiji_overlapping_random.to_csv('/ix/djishnu/Alisa/Tfh/Network_analysis/results/percent_recouped_plots/random_taiji_overlaps_df.csv')
#taiji_overlapping_random_fd.to_csv('/ix/djishnu/Alisa/Tfh/Network_analysis/results/percent_recouped_plots/random_taiji_fd_overlaps_df.csv')

#pps_overlapping_random = random_overlaps_perm(pps_set, set_name = 'pps', num_perm=1000,output= 'genes_gene_len')
#pps_overlapping_random_fd = random_overlaps_perm(pps_genes['Genes'], set_name = 'pps_fd', num_perm=1000, output= 'genes_gene_len')
#pps_overlapping_random.to_csv('/ix/djishnu/Alisa/Tfh/Network_analysis/results/percent_recouped_plots/random_pps_overlaps_df.csv')
#pps_overlapping_random_fd.to_csv('/ix/djishnu/Alisa/Tfh/Network_analysis/results/percent_recouped_plots/random_pps_fd_overlaps_df.csv')

#logFC_random_fd = random_overlaps_perm(logFC_genes[1], set_name = 'logFC_fd', num_perm=1000, output= 'genes_gene_len')
#logFC_random_fd_random_fd.to_csv('/ix/djishnu/Alisa/Tfh/Network_analysis/results/percent_recouped_plots/random_logFC_random_fd_overlaps_df.csv')

pps_noprop_random_fd = random_overlaps_perm(pps_noprop[1], set_name = 'pps_noprop_fd', num_perm=1000, output= 'genes_gene_len')
pps_noprop_random_fd.to_csv('../../Input_data/random_pps_noprop_random_fd_overlaps_df_184.csv')
# Out:
# Num_perm= 0
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_noprop_fd_0        4           5      16       5
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# Num_perm= 1
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_noprop_fd_0        4           5      16       5
# 0  Random_pps_noprop_fd_1        6           7      11       7
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# Num_perm= 2
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_noprop_fd_0        4           5      16       5
# 0  Random_pps_noprop_fd_1        6           7      11       7
# 0  Random_pps_noprop_fd_2        7          10      11       4
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# Num_perm= 3
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_noprop_fd_0        4           5      16       5
# 0  Random_pps_noprop_fd_1        6           7      11       7
# 0  Random_pps_noprop_fd_2        7          10      11       4
# 0  Random_pps_noprop_fd_3        2           5       6       6
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# Num_perm= 4
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_noprop_fd_0        4           5      16       5
# 0  Random_pps_noprop_fd_1        6           7      11       7
# 0  Random_pps_noprop_fd_2        7          10      11       4
# 0  Random_pps_noprop_fd_3        2           5       6       6
# 0  Random_pps_noprop_fd_4        6           6       8       6
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# Num_perm= 5
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_noprop_fd_0        4           5      16       5
# 0  Random_pps_noprop_fd_1        6           7      11       7
# 0  Random_pps_noprop_fd_2        7          10      11       4
# 0  Random_pps_noprop_fd_3        2           5       6       6
# 0  Random_pps_noprop_fd_4        6           6       8       6
# 0  Random_pps_noprop_fd_5        6           7      12       7
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# Num_perm= 6
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_noprop_fd_0        4           5      16       5
# 0  Random_pps_noprop_fd_1        6           7      11       7
# 0  Random_pps_noprop_fd_2        7          10      11       4
# 0  Random_pps_noprop_fd_3        2           5       6       6
# 0  Random_pps_noprop_fd_4        6           6       8       6
# 0  Random_pps_noprop_fd_5        6           7      12       7
# 0  Random_pps_noprop_fd_6        3           7       9       6
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# Num_perm= 7
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_noprop_fd_0        4           5      16       5
# 0  Random_pps_noprop_fd_1        6           7      11       7
# 0  Random_pps_noprop_fd_2        7          10      11       4
# 0  Random_pps_noprop_fd_3        2           5       6       6
# 0  Random_pps_noprop_fd_4        6           6       8       6
# 0  Random_pps_noprop_fd_5        6           7      12       7
# 0  Random_pps_noprop_fd_6        3           7       9       6
# 0  Random_pps_noprop_fd_7        6           7       4       3
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# Num_perm= 8
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_noprop_fd_0        4           5      16       5
# 0  Random_pps_noprop_fd_1        6           7      11       7
# 0  Random_pps_noprop_fd_2        7          10      11       4
# 0  Random_pps_noprop_fd_3        2           5       6       6
# 0  Random_pps_noprop_fd_4        6           6       8       6
# 0  Random_pps_noprop_fd_5        6           7      12       7
# 0  Random_pps_noprop_fd_6        3           7       9       6
# 0  Random_pps_noprop_fd_7        6           7       4       3
# 0  Random_pps_noprop_fd_8        4           6       8       5
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# Num_perm= 9
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_noprop_fd_0        4           5      16       5
# 0  Random_pps_noprop_fd_1        6           7      11       7
# 0  Random_pps_noprop_fd_2        7          10      11       4
# 0  Random_pps_noprop_fd_3        2           5       6       6
# 0  Random_pps_noprop_fd_4        6           6       8       6
# 0  Random_pps_noprop_fd_5        6           7      12       7
# 0  Random_pps_noprop_fd_6        3           7       9       6
# 0  Random_pps_noprop_fd_7        6           7       4       3
# 0  Random_pps_noprop_fd_8        4           6       8       5
# 0  Random_pps_noprop_fd_9        6          11      11      10
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# Num_perm= 10
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# Num_perm= 11
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# Num_perm= 12
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# Num_perm= 13
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# 0  {BCAT2, KCNN4, GRTP1, Q59EY7, HSD17B7, TMEM19,...
# Num_perm= 14
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
# 0  Random_pps_noprop_fd_14        5           6      12      11
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# 0  {BCAT2, KCNN4, GRTP1, Q59EY7, HSD17B7, TMEM19,...
# 0  {KCNN4, STK39, TAAR8, K7N5N2, FADS2, PACRGL, P...
# Num_perm= 15
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
# 0  Random_pps_noprop_fd_14        5           6      12      11
# 0  Random_pps_noprop_fd_15        4           8       7       6
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# 0  {BCAT2, KCNN4, GRTP1, Q59EY7, HSD17B7, TMEM19,...
# 0  {KCNN4, STK39, TAAR8, K7N5N2, FADS2, PACRGL, P...
# 0  {AGXT2, SMIM20, KRIT1, CRLF1, FRAT2, SLC43A1, ...
# Num_perm= 16
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
# 0  Random_pps_noprop_fd_14        5           6      12      11
# 0  Random_pps_noprop_fd_15        4           8       7       6
# 0  Random_pps_noprop_fd_16        0           2       9       6
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# 0  {BCAT2, KCNN4, GRTP1, Q59EY7, HSD17B7, TMEM19,...
# 0  {KCNN4, STK39, TAAR8, K7N5N2, FADS2, PACRGL, P...
# 0  {AGXT2, SMIM20, KRIT1, CRLF1, FRAT2, SLC43A1, ...
# 0  {PRKCB, KCNN3, KIN, FAM72B, BROX, FAM53A, DYSF...
# Num_perm= 17
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
# 0  Random_pps_noprop_fd_14        5           6      12      11
# 0  Random_pps_noprop_fd_15        4           8       7       6
# 0  Random_pps_noprop_fd_16        0           2       9       6
# 0  Random_pps_noprop_fd_17        4           6       9       6
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# 0  {BCAT2, KCNN4, GRTP1, Q59EY7, HSD17B7, TMEM19,...
# 0  {KCNN4, STK39, TAAR8, K7N5N2, FADS2, PACRGL, P...
# 0  {AGXT2, SMIM20, KRIT1, CRLF1, FRAT2, SLC43A1, ...
# 0  {PRKCB, KCNN3, KIN, FAM72B, BROX, FAM53A, DYSF...
# 0  {PRKCB, GRTP1, Q59EY7, K7N5N2, APLP1, RTEL1-TN...
# Num_perm= 18
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
# 0  Random_pps_noprop_fd_14        5           6      12      11
# 0  Random_pps_noprop_fd_15        4           8       7       6
# 0  Random_pps_noprop_fd_16        0           2       9       6
# 0  Random_pps_noprop_fd_17        4           6       9       6
# 0  Random_pps_noprop_fd_18        4           7      10       7
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# 0  {BCAT2, KCNN4, GRTP1, Q59EY7, HSD17B7, TMEM19,...
# 0  {KCNN4, STK39, TAAR8, K7N5N2, FADS2, PACRGL, P...
# 0  {AGXT2, SMIM20, KRIT1, CRLF1, FRAT2, SLC43A1, ...
# 0  {PRKCB, KCNN3, KIN, FAM72B, BROX, FAM53A, DYSF...
# 0  {PRKCB, GRTP1, Q59EY7, K7N5N2, APLP1, RTEL1-TN...
# 0  {FLOT2, STK39, BROX, RAF1, PJA2, LRRC25, GHRHR...
# Num_perm= 19
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
# 0  Random_pps_noprop_fd_14        5           6      12      11
# 0  Random_pps_noprop_fd_15        4           8       7       6
# 0  Random_pps_noprop_fd_16        0           2       9       6
# 0  Random_pps_noprop_fd_17        4           6       9       6
# 0  Random_pps_noprop_fd_18        4           7      10       7
# 0  Random_pps_noprop_fd_19        5           8      12       8
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# 0  {BCAT2, KCNN4, GRTP1, Q59EY7, HSD17B7, TMEM19,...
# 0  {KCNN4, STK39, TAAR8, K7N5N2, FADS2, PACRGL, P...
# 0  {AGXT2, SMIM20, KRIT1, CRLF1, FRAT2, SLC43A1, ...
# 0  {PRKCB, KCNN3, KIN, FAM72B, BROX, FAM53A, DYSF...
# 0  {PRKCB, GRTP1, Q59EY7, K7N5N2, APLP1, RTEL1-TN...
# 0  {FLOT2, STK39, BROX, RAF1, PJA2, LRRC25, GHRHR...
# 0  {KCNN4, APLP1, GLRX, CSNK1G3, NACA, LRRFIP1, M...
# Num_perm= 20
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
# 0  Random_pps_noprop_fd_14        5           6      12      11
# 0  Random_pps_noprop_fd_15        4           8       7       6
# 0  Random_pps_noprop_fd_16        0           2       9       6
# 0  Random_pps_noprop_fd_17        4           6       9       6
# 0  Random_pps_noprop_fd_18        4           7      10       7
# 0  Random_pps_noprop_fd_19        5           8      12       8
# 0  Random_pps_noprop_fd_20        5           6      18      11
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# 0  {BCAT2, KCNN4, GRTP1, Q59EY7, HSD17B7, TMEM19,...
# 0  {KCNN4, STK39, TAAR8, K7N5N2, FADS2, PACRGL, P...
# 0  {AGXT2, SMIM20, KRIT1, CRLF1, FRAT2, SLC43A1, ...
# 0  {PRKCB, KCNN3, KIN, FAM72B, BROX, FAM53A, DYSF...
# 0  {PRKCB, GRTP1, Q59EY7, K7N5N2, APLP1, RTEL1-TN...
# 0  {FLOT2, STK39, BROX, RAF1, PJA2, LRRC25, GHRHR...
# 0  {KCNN4, APLP1, GLRX, CSNK1G3, NACA, LRRFIP1, M...
# 0  {KCNN4, Q59EY7, K7N5N2, TMEM185A, APLP1, GLRX,...
# Num_perm= 21
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
# 0  Random_pps_noprop_fd_14        5           6      12      11
# 0  Random_pps_noprop_fd_15        4           8       7       6
# 0  Random_pps_noprop_fd_16        0           2       9       6
# 0  Random_pps_noprop_fd_17        4           6       9       6
# 0  Random_pps_noprop_fd_18        4           7      10       7
# 0  Random_pps_noprop_fd_19        5           8      12       8
# 0  Random_pps_noprop_fd_20        5           6      18      11
# 0  Random_pps_noprop_fd_21        7           9      12       8
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# 0  {BCAT2, KCNN4, GRTP1, Q59EY7, HSD17B7, TMEM19,...
# 0  {KCNN4, STK39, TAAR8, K7N5N2, FADS2, PACRGL, P...
# 0  {AGXT2, SMIM20, KRIT1, CRLF1, FRAT2, SLC43A1, ...
# 0  {PRKCB, KCNN3, KIN, FAM72B, BROX, FAM53A, DYSF...
# 0  {PRKCB, GRTP1, Q59EY7, K7N5N2, APLP1, RTEL1-TN...
# 0  {FLOT2, STK39, BROX, RAF1, PJA2, LRRC25, GHRHR...
# 0  {KCNN4, APLP1, GLRX, CSNK1G3, NACA, LRRFIP1, M...
# 0  {KCNN4, Q59EY7, K7N5N2, TMEM185A, APLP1, GLRX,...
# 0  {PHTF2, Q59EY7, DYSF, NACA, TRAK1, KLRC1, Q59G...
# Num_perm= 22
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
# 0  Random_pps_noprop_fd_14        5           6      12      11
# 0  Random_pps_noprop_fd_15        4           8       7       6
# 0  Random_pps_noprop_fd_16        0           2       9       6
# 0  Random_pps_noprop_fd_17        4           6       9       6
# 0  Random_pps_noprop_fd_18        4           7      10       7
# 0  Random_pps_noprop_fd_19        5           8      12       8
# 0  Random_pps_noprop_fd_20        5           6      18      11
# 0  Random_pps_noprop_fd_21        7           9      12       8
# 0  Random_pps_noprop_fd_22        1           2       6       2
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# 0  {BCAT2, KCNN4, GRTP1, Q59EY7, HSD17B7, TMEM19,...
# 0  {KCNN4, STK39, TAAR8, K7N5N2, FADS2, PACRGL, P...
# 0  {AGXT2, SMIM20, KRIT1, CRLF1, FRAT2, SLC43A1, ...
# 0  {PRKCB, KCNN3, KIN, FAM72B, BROX, FAM53A, DYSF...
# 0  {PRKCB, GRTP1, Q59EY7, K7N5N2, APLP1, RTEL1-TN...
# 0  {FLOT2, STK39, BROX, RAF1, PJA2, LRRC25, GHRHR...
# 0  {KCNN4, APLP1, GLRX, CSNK1G3, NACA, LRRFIP1, M...
# 0  {KCNN4, Q59EY7, K7N5N2, TMEM185A, APLP1, GLRX,...
# 0  {PHTF2, Q59EY7, DYSF, NACA, TRAK1, KLRC1, Q59G...
# 0  {Q86TT2, TMEM185A, COQ2, SLC17A5, GHRHR, GYG2,...
# Num_perm= 23
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
# 0  Random_pps_noprop_fd_14        5           6      12      11
# 0  Random_pps_noprop_fd_15        4           8       7       6
# 0  Random_pps_noprop_fd_16        0           2       9       6
# 0  Random_pps_noprop_fd_17        4           6       9       6
# 0  Random_pps_noprop_fd_18        4           7      10       7
# 0  Random_pps_noprop_fd_19        5           8      12       8
# 0  Random_pps_noprop_fd_20        5           6      18      11
# 0  Random_pps_noprop_fd_21        7           9      12       8
# 0  Random_pps_noprop_fd_22        1           2       6       2
# 0  Random_pps_noprop_fd_23        6           8      13       9
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# 0  {BCAT2, KCNN4, GRTP1, Q59EY7, HSD17B7, TMEM19,...
# 0  {KCNN4, STK39, TAAR8, K7N5N2, FADS2, PACRGL, P...
# 0  {AGXT2, SMIM20, KRIT1, CRLF1, FRAT2, SLC43A1, ...
# 0  {PRKCB, KCNN3, KIN, FAM72B, BROX, FAM53A, DYSF...
# 0  {PRKCB, GRTP1, Q59EY7, K7N5N2, APLP1, RTEL1-TN...
# 0  {FLOT2, STK39, BROX, RAF1, PJA2, LRRC25, GHRHR...
# 0  {KCNN4, APLP1, GLRX, CSNK1G3, NACA, LRRFIP1, M...
# 0  {KCNN4, Q59EY7, K7N5N2, TMEM185A, APLP1, GLRX,...
# 0  {PHTF2, Q59EY7, DYSF, NACA, TRAK1, KLRC1, Q59G...
# 0  {Q86TT2, TMEM185A, COQ2, SLC17A5, GHRHR, GYG2,...
# 0  {KCNN4, Q86TT2, UNC80, SLC16A4, FADS2, APLP1, ...
# Num_perm= 24
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
# 0  Random_pps_noprop_fd_14        5           6      12      11
# 0  Random_pps_noprop_fd_15        4           8       7       6
# 0  Random_pps_noprop_fd_16        0           2       9       6
# 0  Random_pps_noprop_fd_17        4           6       9       6
# 0  Random_pps_noprop_fd_18        4           7      10       7
# 0  Random_pps_noprop_fd_19        5           8      12       8
# 0  Random_pps_noprop_fd_20        5           6      18      11
# 0  Random_pps_noprop_fd_21        7           9      12       8
# 0  Random_pps_noprop_fd_22        1           2       6       2
# 0  Random_pps_noprop_fd_23        6           8      13       9
# 0  Random_pps_noprop_fd_24        1           6       8       4
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# 0  {BCAT2, KCNN4, GRTP1, Q59EY7, HSD17B7, TMEM19,...
# 0  {KCNN4, STK39, TAAR8, K7N5N2, FADS2, PACRGL, P...
# 0  {AGXT2, SMIM20, KRIT1, CRLF1, FRAT2, SLC43A1, ...
# 0  {PRKCB, KCNN3, KIN, FAM72B, BROX, FAM53A, DYSF...
# 0  {PRKCB, GRTP1, Q59EY7, K7N5N2, APLP1, RTEL1-TN...
# 0  {FLOT2, STK39, BROX, RAF1, PJA2, LRRC25, GHRHR...
# 0  {KCNN4, APLP1, GLRX, CSNK1G3, NACA, LRRFIP1, M...
# 0  {KCNN4, Q59EY7, K7N5N2, TMEM185A, APLP1, GLRX,...
# 0  {PHTF2, Q59EY7, DYSF, NACA, TRAK1, KLRC1, Q59G...
# 0  {Q86TT2, TMEM185A, COQ2, SLC17A5, GHRHR, GYG2,...
# 0  {KCNN4, Q86TT2, UNC80, SLC16A4, FADS2, APLP1, ...
# 0  {BCAT2, Q86TT2, PRKCB, KCNN4, TRAPPC2, HSD17B7...
# Num_perm= 25
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
# 0  Random_pps_noprop_fd_14        5           6      12      11
# 0  Random_pps_noprop_fd_15        4           8       7       6
# 0  Random_pps_noprop_fd_16        0           2       9       6
# 0  Random_pps_noprop_fd_17        4           6       9       6
# 0  Random_pps_noprop_fd_18        4           7      10       7
# 0  Random_pps_noprop_fd_19        5           8      12       8
# 0  Random_pps_noprop_fd_20        5           6      18      11
# 0  Random_pps_noprop_fd_21        7           9      12       8
# 0  Random_pps_noprop_fd_22        1           2       6       2
# 0  Random_pps_noprop_fd_23        6           8      13       9
# 0  Random_pps_noprop_fd_24        1           6       8       4
# 0  Random_pps_noprop_fd_25        4           7      15       9
#
#                                                Genes
# 0  {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0  {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0  {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0  {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0  {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# 0  {BCAT2, PHTF2, TAAR8, GRTP1, STK39, C16ORF72, ...
# 0  {UNC80, LRRC25, CD74, USP40, RELB, Q59GL9, DOP...
# 0  {PHTF2, PHF20, C16ORF72, BROX, DYSF, TRAK1, IL...
# 0  {TRAPPC2, KIN, C16ORF72, RAF1, BROX, APLP1, GL...
# 0  {TRAPPC2, KCNN3, TAAR8, PHTF2, HSD17B7, COQ2, ...
# 0  {HSD17B7, TMEM19, PPWD1, GLRX, SLC17A5, CNKSR1...
# 0  {KCNN3, FLOT2, PHF20, HSD17B7, K7N5N2, COQ2, K...
# 0  {Q86TT2, TMEM185A, PACRGL, PJA2, RTEL1-TNFRSF6...
# 0  {BCAT2, KCNN4, GRTP1, Q59EY7, HSD17B7, TMEM19,...
# 0  {KCNN4, STK39, TAAR8, K7N5N2, FADS2, PACRGL, P...
# 0  {AGXT2, SMIM20, KRIT1, CRLF1, FRAT2, SLC43A1, ...
# 0  {PRKCB, KCNN3, KIN, FAM72B, BROX, FAM53A, DYSF...
# 0  {PRKCB, GRTP1, Q59EY7, K7N5N2, APLP1, RTEL1-TN...
# 0  {FLOT2, STK39, BROX, RAF1, PJA2, LRRC25, GHRHR...
# 0  {KCNN4, APLP1, GLRX, CSNK1G3, NACA, LRRFIP1, M...
# 0  {KCNN4, Q59EY7, K7N5N2, TMEM185A, APLP1, GLRX,...
# 0  {PHTF2, Q59EY7, DYSF, NACA, TRAK1, KLRC1, Q59G...
# 0  {Q86TT2, TMEM185A, COQ2, SLC17A5, GHRHR, GYG2,...
# 0  {KCNN4, Q86TT2, UNC80, SLC16A4, FADS2, APLP1, ...
# 0  {BCAT2, Q86TT2, PRKCB, KCNN4, TRAPPC2, HSD17B7...
# 0  {STK39, PHF20, CXCL1, USP40, MORF4L1, CNKSR1, ...
# Num_perm= 26
#                        Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_noprop_fd_0        4           5      16       5
# 0   Random_pps_noprop_fd_1        6           7      11       7
# 0   Random_pps_noprop_fd_2        7          10      11       4
# 0   Random_pps_noprop_fd_3        2           5       6       6
# 0   Random_pps_noprop_fd_4        6           6       8       6
# 0   Random_pps_noprop_fd_5        6           7      12       7
# 0   Random_pps_noprop_fd_6        3           7       9       6
# 0   Random_pps_noprop_fd_7        6           7       4       3
# 0   Random_pps_noprop_fd_8        4           6       8       5
# 0   Random_pps_noprop_fd_9        6          11      11      10
# 0  Random_pps_noprop_fd_10        8          11      11       6
# 0  Random_pps_noprop_fd_11        3           7       7       6
# 0  Random_pps_noprop_fd_12        7          10      14       5
# 0  Random_pps_noprop_fd_13        6           6      13       8
# 0  Random_pps_noprop_fd_14        5           6      12      11
# 0  Random_pps_noprop_fd_15        4           8       7       6
# 0  Random_pps_noprop_fd_16        0           2       9       6
# 0  Random_pps_noprop_fd_17        4           6       9       6
# 0  Random_pps_noprop_fd_18        4           7      10       7
# 0  Random_pps_noprop_fd_19        5           8      12       8
# 0  Random_pps_noprop_fd_20        5           6      18      11
# 0  Random_pps_noprop_fd_21        7           9      12       8
# 0  Random_pps_noprop_fd_22        1           2       6       2
# 0  Random_pps_noprop_fd_23        6           8      13       9
# ...
# 0   {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0   {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0   {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0   {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# ..                                                ...
# 0   {C5ORF46, SLC16A4, PACRGL, C16ORF72, SLC17A5, ...
# 0   {PRKCB, C16ORF72, PPWD1, PMP22, APLP1, DYSF, C...
# 0   {BCAT2, FLOT2, UNC80, SLC16A4, COQ2, FAM72B, C...
# 0   {KCNN4, STK39, GRTP1, FLOT2, COQ2, FAM72B, SLC...
# 0   {PHTF2, STK39, Q59EY7, HSD17B7, KIN, LRRC25, S...
#
# [990 rows x 6 columns]
# Num_perm= 990
#                          Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_noprop_fd_0        4           5      16       5
# 0     Random_pps_noprop_fd_1        6           7      11       7
# 0     Random_pps_noprop_fd_2        7          10      11       4
# 0     Random_pps_noprop_fd_3        2           5       6       6
# 0     Random_pps_noprop_fd_4        6           6       8       6
# ..                       ...      ...         ...     ...     ...
# 0   Random_pps_noprop_fd_986        7           9      12       6
# 0   Random_pps_noprop_fd_987        9          12      13      13
# 0   Random_pps_noprop_fd_988        8          11      13       8
# 0   Random_pps_noprop_fd_989        7           8      10      13
# 0   Random_pps_noprop_fd_990        5           7      10       9
#
#                                                 Genes
# 0   {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0   {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0   {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0   {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0   {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# ..                                                ...
# 0   {PRKCB, C16ORF72, PPWD1, PMP22, APLP1, DYSF, C...
# 0   {BCAT2, FLOT2, UNC80, SLC16A4, COQ2, FAM72B, C...
# 0   {KCNN4, STK39, GRTP1, FLOT2, COQ2, FAM72B, SLC...
# 0   {PHTF2, STK39, Q59EY7, HSD17B7, KIN, LRRC25, S...
# 0   {KCNN3, COQ2, FAM72B, BROX, LRRC25, IVNS1ABP, ...
#
# [991 rows x 6 columns]
# Num_perm= 991
#                          Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_noprop_fd_0        4           5      16       5
# 0     Random_pps_noprop_fd_1        6           7      11       7
# 0     Random_pps_noprop_fd_2        7          10      11       4
# 0     Random_pps_noprop_fd_3        2           5       6       6
# 0     Random_pps_noprop_fd_4        6           6       8       6
# ..                       ...      ...         ...     ...     ...
# 0   Random_pps_noprop_fd_987        9          12      13      13
# 0   Random_pps_noprop_fd_988        8          11      13       8
# 0   Random_pps_noprop_fd_989        7           8      10      13
# 0   Random_pps_noprop_fd_990        5           7      10       9
# 0   Random_pps_noprop_fd_991        5          12      14      12
#
#                                                 Genes
# 0   {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0   {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0   {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0   {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0   {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# ..                                                ...
# 0   {BCAT2, FLOT2, UNC80, SLC16A4, COQ2, FAM72B, C...
# 0   {KCNN4, STK39, GRTP1, FLOT2, COQ2, FAM72B, SLC...
# 0   {PHTF2, STK39, Q59EY7, HSD17B7, KIN, LRRC25, S...
# 0   {KCNN3, COQ2, FAM72B, BROX, LRRC25, IVNS1ABP, ...
# 0   {TRAPPC2, FLOT2, Q59EY7, TRAK1, CAV1, USP40, D...
#
# [992 rows x 6 columns]
# Num_perm= 992
#                          Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_noprop_fd_0        4           5      16       5
# 0     Random_pps_noprop_fd_1        6           7      11       7
# 0     Random_pps_noprop_fd_2        7          10      11       4
# 0     Random_pps_noprop_fd_3        2           5       6       6
# 0     Random_pps_noprop_fd_4        6           6       8       6
# ..                       ...      ...         ...     ...     ...
# 0   Random_pps_noprop_fd_988        8          11      13       8
# 0   Random_pps_noprop_fd_989        7           8      10      13
# 0   Random_pps_noprop_fd_990        5           7      10       9
# 0   Random_pps_noprop_fd_991        5          12      14      12
# 0   Random_pps_noprop_fd_992        7           7      11       5
#
#                                                 Genes
# 0   {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0   {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0   {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0   {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0   {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# ..                                                ...
# 0   {KCNN4, STK39, GRTP1, FLOT2, COQ2, FAM72B, SLC...
# 0   {PHTF2, STK39, Q59EY7, HSD17B7, KIN, LRRC25, S...
# 0   {KCNN3, COQ2, FAM72B, BROX, LRRC25, IVNS1ABP, ...
# 0   {TRAPPC2, FLOT2, Q59EY7, TRAK1, CAV1, USP40, D...
# 0   {BCAT2, FAM72B, TMEM19, FADS2, DYSF, IVNS1ABP,...
#
# [993 rows x 6 columns]
# Num_perm= 993
#                          Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_noprop_fd_0        4           5      16       5
# 0     Random_pps_noprop_fd_1        6           7      11       7
# 0     Random_pps_noprop_fd_2        7          10      11       4
# 0     Random_pps_noprop_fd_3        2           5       6       6
# 0     Random_pps_noprop_fd_4        6           6       8       6
# ..                       ...      ...         ...     ...     ...
# 0   Random_pps_noprop_fd_989        7           8      10      13
# 0   Random_pps_noprop_fd_990        5           7      10       9
# 0   Random_pps_noprop_fd_991        5          12      14      12
# 0   Random_pps_noprop_fd_992        7           7      11       5
# 0   Random_pps_noprop_fd_993        6           7      10      10
#
#                                                 Genes
# 0   {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0   {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0   {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0   {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0   {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# ..                                                ...
# 0   {PHTF2, STK39, Q59EY7, HSD17B7, KIN, LRRC25, S...
# 0   {KCNN3, COQ2, FAM72B, BROX, LRRC25, IVNS1ABP, ...
# 0   {TRAPPC2, FLOT2, Q59EY7, TRAK1, CAV1, USP40, D...
# 0   {BCAT2, FAM72B, TMEM19, FADS2, DYSF, IVNS1ABP,...
# 0   {STK39, SLC16A4, FADS2, LRRC25, SLC17A5, RTEL1...
#
# [994 rows x 6 columns]
# Num_perm= 994
#                          Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_noprop_fd_0        4           5      16       5
# 0     Random_pps_noprop_fd_1        6           7      11       7
# 0     Random_pps_noprop_fd_2        7          10      11       4
# 0     Random_pps_noprop_fd_3        2           5       6       6
# 0     Random_pps_noprop_fd_4        6           6       8       6
# ..                       ...      ...         ...     ...     ...
# 0   Random_pps_noprop_fd_990        5           7      10       9
# 0   Random_pps_noprop_fd_991        5          12      14      12
# 0   Random_pps_noprop_fd_992        7           7      11       5
# 0   Random_pps_noprop_fd_993        6           7      10      10
# 0   Random_pps_noprop_fd_994        5           7      14       8
#
#                                                 Genes
# 0   {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0   {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0   {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0   {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0   {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# ..                                                ...
# 0   {KCNN3, COQ2, FAM72B, BROX, LRRC25, IVNS1ABP, ...
# 0   {TRAPPC2, FLOT2, Q59EY7, TRAK1, CAV1, USP40, D...
# 0   {BCAT2, FAM72B, TMEM19, FADS2, DYSF, IVNS1ABP,...
# 0   {STK39, SLC16A4, FADS2, LRRC25, SLC17A5, RTEL1...
# 0   {TMEM185A, FADS2, APLP1, PMP22, CSNK1G3, SLITR...
#
# [995 rows x 6 columns]
# Num_perm= 995
#                          Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_noprop_fd_0        4           5      16       5
# 0     Random_pps_noprop_fd_1        6           7      11       7
# 0     Random_pps_noprop_fd_2        7          10      11       4
# 0     Random_pps_noprop_fd_3        2           5       6       6
# 0     Random_pps_noprop_fd_4        6           6       8       6
# ..                       ...      ...         ...     ...     ...
# 0   Random_pps_noprop_fd_991        5          12      14      12
# 0   Random_pps_noprop_fd_992        7           7      11       5
# 0   Random_pps_noprop_fd_993        6           7      10      10
# 0   Random_pps_noprop_fd_994        5           7      14       8
# 0   Random_pps_noprop_fd_995        7          10      13       9
#
#                                                 Genes
# 0   {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0   {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0   {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0   {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0   {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# ..                                                ...
# 0   {TRAPPC2, FLOT2, Q59EY7, TRAK1, CAV1, USP40, D...
# 0   {BCAT2, FAM72B, TMEM19, FADS2, DYSF, IVNS1ABP,...
# 0   {STK39, SLC16A4, FADS2, LRRC25, SLC17A5, RTEL1...
# 0   {TMEM185A, FADS2, APLP1, PMP22, CSNK1G3, SLITR...
# 0   {TRAPPC2, DYSF, UQCRC2, LRRFIP1, AGXT2, MOCS3,...
#
# [996 rows x 6 columns]
# Num_perm= 996
#                          Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_noprop_fd_0        4           5      16       5
# 0     Random_pps_noprop_fd_1        6           7      11       7
# 0     Random_pps_noprop_fd_2        7          10      11       4
# 0     Random_pps_noprop_fd_3        2           5       6       6
# 0     Random_pps_noprop_fd_4        6           6       8       6
# ..                       ...      ...         ...     ...     ...
# 0   Random_pps_noprop_fd_992        7           7      11       5
# 0   Random_pps_noprop_fd_993        6           7      10      10
# 0   Random_pps_noprop_fd_994        5           7      14       8
# 0   Random_pps_noprop_fd_995        7          10      13       9
# 0   Random_pps_noprop_fd_996        6           7      12       8
#
#                                                 Genes
# 0   {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0   {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0   {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0   {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0   {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# ..                                                ...
# 0   {BCAT2, FAM72B, TMEM19, FADS2, DYSF, IVNS1ABP,...
# 0   {STK39, SLC16A4, FADS2, LRRC25, SLC17A5, RTEL1...
# 0   {TMEM185A, FADS2, APLP1, PMP22, CSNK1G3, SLITR...
# 0   {TRAPPC2, DYSF, UQCRC2, LRRFIP1, AGXT2, MOCS3,...
# 0   {C5ORF46, RHBDF1, SLC16A4, PACRGL, LRRC25, UQC...
#
# [997 rows x 6 columns]
# Num_perm= 997
#                          Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_noprop_fd_0        4           5      16       5
# 0     Random_pps_noprop_fd_1        6           7      11       7
# 0     Random_pps_noprop_fd_2        7          10      11       4
# 0     Random_pps_noprop_fd_3        2           5       6       6
# 0     Random_pps_noprop_fd_4        6           6       8       6
# ..                       ...      ...         ...     ...     ...
# 0   Random_pps_noprop_fd_993        6           7      10      10
# 0   Random_pps_noprop_fd_994        5           7      14       8
# 0   Random_pps_noprop_fd_995        7          10      13       9
# 0   Random_pps_noprop_fd_996        6           7      12       8
# 0   Random_pps_noprop_fd_997        5           6      10       8
#
#                                                 Genes
# 0   {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0   {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0   {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0   {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0   {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# ..                                                ...
# 0   {STK39, SLC16A4, FADS2, LRRC25, SLC17A5, RTEL1...
# 0   {TMEM185A, FADS2, APLP1, PMP22, CSNK1G3, SLITR...
# 0   {TRAPPC2, DYSF, UQCRC2, LRRFIP1, AGXT2, MOCS3,...
# 0   {C5ORF46, RHBDF1, SLC16A4, PACRGL, LRRC25, UQC...
# 0   {BCAT2, STK39, GRTP1, COQ2, KIN, TMEM19, GLRX,...
#
# [998 rows x 6 columns]
# Num_perm= 998
#                          Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_noprop_fd_0        4           5      16       5
# 0     Random_pps_noprop_fd_1        6           7      11       7
# 0     Random_pps_noprop_fd_2        7          10      11       4
# 0     Random_pps_noprop_fd_3        2           5       6       6
# 0     Random_pps_noprop_fd_4        6           6       8       6
# ..                       ...      ...         ...     ...     ...
# 0   Random_pps_noprop_fd_994        5           7      14       8
# 0   Random_pps_noprop_fd_995        7          10      13       9
# 0   Random_pps_noprop_fd_996        6           7      12       8
# 0   Random_pps_noprop_fd_997        5           6      10       8
# 0   Random_pps_noprop_fd_998        3           4       9       6
#
#                                                 Genes
# 0   {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0   {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0   {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0   {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0   {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# ..                                                ...
# 0   {TMEM185A, FADS2, APLP1, PMP22, CSNK1G3, SLITR...
# 0   {TRAPPC2, DYSF, UQCRC2, LRRFIP1, AGXT2, MOCS3,...
# 0   {C5ORF46, RHBDF1, SLC16A4, PACRGL, LRRC25, UQC...
# 0   {BCAT2, STK39, GRTP1, COQ2, KIN, TMEM19, GLRX,...
# 0   {KCNN4, FLOT2, RHBDF1, K7N5N2, PPWD1, C16ORF72...
#
# [999 rows x 6 columns]
# Num_perm= 999
#                          Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_noprop_fd_0        4           5      16       5
# 0     Random_pps_noprop_fd_1        6           7      11       7
# 0     Random_pps_noprop_fd_2        7          10      11       4
# 0     Random_pps_noprop_fd_3        2           5       6       6
# 0     Random_pps_noprop_fd_4        6           6       8       6
# ..                       ...      ...         ...     ...     ...
# 0   Random_pps_noprop_fd_995        7          10      13       9
# 0   Random_pps_noprop_fd_996        6           7      12       8
# 0   Random_pps_noprop_fd_997        5           6      10       8
# 0   Random_pps_noprop_fd_998        3           4       9       6
# 0   Random_pps_noprop_fd_999       10          11      15       7
#
#                                                 Genes
# 0   {PHTF2, PHF20, PPWD1, PJA2, DYSF, MYLK3, CNKSR...
# 0   {K7N5N2, COQ2, WDR46, IL36G, GYG2, AGXT2, DOP1...
# 0   {KCNN4, Q59EY7, SLC16A4, FADS2, TMEM19, EVA1C,...
# 0   {Q59EY7, TMEM185A, KIN, BROX, PMP22, FAM53A, R...
# 0   {FLOT2, TMEM19, GLRX, CD74, WDR46, E9PSI1, IL3...
# ..                                                ...
# 0   {TRAPPC2, DYSF, UQCRC2, LRRFIP1, AGXT2, MOCS3,...
# 0   {C5ORF46, RHBDF1, SLC16A4, PACRGL, LRRC25, UQC...
# 0   {BCAT2, STK39, GRTP1, COQ2, KIN, TMEM19, GLRX,...
# 0   {KCNN4, FLOT2, RHBDF1, K7N5N2, PPWD1, C16ORF72...
# 0   {GRTP1, HSD17B7, PACRGL, BROX, APLP1, RAF1, CX...
#
# [1000 rows x 6 columns]

# %%
#taiji_overlapping_random.to_csv('/ix/djishnu/Alisa/Tfh/Network_analysis/results/percent_recouped_plots/random_taiji_overlaps_df.csv')
#taiji_overlapping_random_fd.to_csv('/ix/djishnu/Alisa/Tfh/Network_analysis/results/percent_recouped_plots/random_taiji_fd_overlaps_TR_df.csv')

#pps_overlapping_random = random_overlaps_perm(pps_set, set_name = 'pps', num_perm=1000,output= 'genes_gene_len')
#pps_overlapping_random_fd = random_overlaps_perm(pps_genes['Genes'], set_name = 'pps_fd', num_perm=1000, output= 'genes_gene_len')
#pps_overlapping_random.to_csv('/ix/djishnu/Alisa/Tfh/Network_analysis/results/percent_recouped_plots/random_pps_overlaps_df.csv')
#pps_overlapping_random_fd.to_csv('/ix/djishnu/Alisa/Tfh/Network_analysis/results/percent_recouped_plots/random_pps_fd_overlaps_df.csv')

# %%
pps_taiji_overlapping_random_fd =  random_overlaps_perm(pps_taiji_genes_fd, set_name = 'pps_taiji_fd', num_perm=1000, output= 'genes_gene_len')
pps_taiji_overlapping_random_fd.to_csv('../../Input_data/random_pps_taiji_fd_overlaps_df.csv')
# Out:
# Num_perm= 0
#                      Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_taiji_fd_0       14          20      22      17
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# Num_perm= 1
#                      Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_taiji_fd_0       14          20      22      17
# 0  Random_pps_taiji_fd_1        6           8      23      10
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# Num_perm= 2
#                      Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_taiji_fd_0       14          20      22      17
# 0  Random_pps_taiji_fd_1        6           8      23      10
# 0  Random_pps_taiji_fd_2       15          20      28      22
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# Num_perm= 3
#                      Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_taiji_fd_0       14          20      22      17
# 0  Random_pps_taiji_fd_1        6           8      23      10
# 0  Random_pps_taiji_fd_2       15          20      28      22
# 0  Random_pps_taiji_fd_3       16          27      28      20
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# Num_perm= 4
#                      Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_taiji_fd_0       14          20      22      17
# 0  Random_pps_taiji_fd_1        6           8      23      10
# 0  Random_pps_taiji_fd_2       15          20      28      22
# 0  Random_pps_taiji_fd_3       16          27      28      20
# 0  Random_pps_taiji_fd_4       10          13      21      13
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# Num_perm= 5
#                      Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_taiji_fd_0       14          20      22      17
# 0  Random_pps_taiji_fd_1        6           8      23      10
# 0  Random_pps_taiji_fd_2       15          20      28      22
# 0  Random_pps_taiji_fd_3       16          27      28      20
# 0  Random_pps_taiji_fd_4       10          13      21      13
# 0  Random_pps_taiji_fd_5       11          16      23      14
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# Num_perm= 6
#                      Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_taiji_fd_0       14          20      22      17
# 0  Random_pps_taiji_fd_1        6           8      23      10
# 0  Random_pps_taiji_fd_2       15          20      28      22
# 0  Random_pps_taiji_fd_3       16          27      28      20
# 0  Random_pps_taiji_fd_4       10          13      21      13
# 0  Random_pps_taiji_fd_5       11          16      23      14
# 0  Random_pps_taiji_fd_6       11          13      18      16
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# Num_perm= 7
#                      Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_taiji_fd_0       14          20      22      17
# 0  Random_pps_taiji_fd_1        6           8      23      10
# 0  Random_pps_taiji_fd_2       15          20      28      22
# 0  Random_pps_taiji_fd_3       16          27      28      20
# 0  Random_pps_taiji_fd_4       10          13      21      13
# 0  Random_pps_taiji_fd_5       11          16      23      14
# 0  Random_pps_taiji_fd_6       11          13      18      16
# 0  Random_pps_taiji_fd_7       18          21      30      19
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# Num_perm= 8
#                      Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_taiji_fd_0       14          20      22      17
# 0  Random_pps_taiji_fd_1        6           8      23      10
# 0  Random_pps_taiji_fd_2       15          20      28      22
# 0  Random_pps_taiji_fd_3       16          27      28      20
# 0  Random_pps_taiji_fd_4       10          13      21      13
# 0  Random_pps_taiji_fd_5       11          16      23      14
# 0  Random_pps_taiji_fd_6       11          13      18      16
# 0  Random_pps_taiji_fd_7       18          21      30      19
# 0  Random_pps_taiji_fd_8       10          17      21      16
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# Num_perm= 9
#                      Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0  Random_pps_taiji_fd_0       14          20      22      17
# 0  Random_pps_taiji_fd_1        6           8      23      10
# 0  Random_pps_taiji_fd_2       15          20      28      22
# 0  Random_pps_taiji_fd_3       16          27      28      20
# 0  Random_pps_taiji_fd_4       10          13      21      13
# 0  Random_pps_taiji_fd_5       11          16      23      14
# 0  Random_pps_taiji_fd_6       11          13      18      16
# 0  Random_pps_taiji_fd_7       18          21      30      19
# 0  Random_pps_taiji_fd_8       10          17      21      16
# 0  Random_pps_taiji_fd_9        8          10      18       8
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# Num_perm= 10
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# Num_perm= 11
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# Num_perm= 12
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# Num_perm= 13
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# 0  {STK39, CXCL1, GHRHR, WDR46, SLITRK1, CAV1, MO...
# Num_perm= 14
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
# 0  Random_pps_taiji_fd_14       10          14      23      17
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# 0  {STK39, CXCL1, GHRHR, WDR46, SLITRK1, CAV1, MO...
# 0  {STK39, HSD17B7, C16ORF72, RAF1, GHRHR, E9PSI1...
# Num_perm= 15
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
# 0  Random_pps_taiji_fd_14       10          14      23      17
# 0  Random_pps_taiji_fd_15        7          12      18      15
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# 0  {STK39, CXCL1, GHRHR, WDR46, SLITRK1, CAV1, MO...
# 0  {STK39, HSD17B7, C16ORF72, RAF1, GHRHR, E9PSI1...
# 0  {C16ORF72, BROX, CXCL1, SLITRK1, GYG2, TBL3, M...
# Num_perm= 16
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
# 0  Random_pps_taiji_fd_14       10          14      23      17
# 0  Random_pps_taiji_fd_15        7          12      18      15
# 0  Random_pps_taiji_fd_16       18          21      28      19
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# 0  {STK39, CXCL1, GHRHR, WDR46, SLITRK1, CAV1, MO...
# 0  {STK39, HSD17B7, C16ORF72, RAF1, GHRHR, E9PSI1...
# 0  {C16ORF72, BROX, CXCL1, SLITRK1, GYG2, TBL3, M...
# 0  {SLC16A4, C16ORF72, RAF1, GHRHR, CNKSR1, ANKRD...
# Num_perm= 17
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
# 0  Random_pps_taiji_fd_14       10          14      23      17
# 0  Random_pps_taiji_fd_15        7          12      18      15
# 0  Random_pps_taiji_fd_16       18          21      28      19
# 0  Random_pps_taiji_fd_17       14          17      21      15
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# 0  {STK39, CXCL1, GHRHR, WDR46, SLITRK1, CAV1, MO...
# 0  {STK39, HSD17B7, C16ORF72, RAF1, GHRHR, E9PSI1...
# 0  {C16ORF72, BROX, CXCL1, SLITRK1, GYG2, TBL3, M...
# 0  {SLC16A4, C16ORF72, RAF1, GHRHR, CNKSR1, ANKRD...
# 0  {STK39, SLC16A4, HSD17B7, CXCL1, USP40, MYLK3,...
# Num_perm= 18
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
# 0  Random_pps_taiji_fd_14       10          14      23      17
# 0  Random_pps_taiji_fd_15        7          12      18      15
# 0  Random_pps_taiji_fd_16       18          21      28      19
# 0  Random_pps_taiji_fd_17       14          17      21      15
# 0  Random_pps_taiji_fd_18       13          20      24      13
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# 0  {STK39, CXCL1, GHRHR, WDR46, SLITRK1, CAV1, MO...
# 0  {STK39, HSD17B7, C16ORF72, RAF1, GHRHR, E9PSI1...
# 0  {C16ORF72, BROX, CXCL1, SLITRK1, GYG2, TBL3, M...
# 0  {SLC16A4, C16ORF72, RAF1, GHRHR, CNKSR1, ANKRD...
# 0  {STK39, SLC16A4, HSD17B7, CXCL1, USP40, MYLK3,...
# 0  {C16ORF72, CXCL1, E9PSI1, CAV1, CNKSR1, GYG2, ...
# Num_perm= 19
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
# 0  Random_pps_taiji_fd_14       10          14      23      17
# 0  Random_pps_taiji_fd_15        7          12      18      15
# 0  Random_pps_taiji_fd_16       18          21      28      19
# 0  Random_pps_taiji_fd_17       14          17      21      15
# 0  Random_pps_taiji_fd_18       13          20      24      13
# 0  Random_pps_taiji_fd_19       13          14      24      13
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# 0  {STK39, CXCL1, GHRHR, WDR46, SLITRK1, CAV1, MO...
# 0  {STK39, HSD17B7, C16ORF72, RAF1, GHRHR, E9PSI1...
# 0  {C16ORF72, BROX, CXCL1, SLITRK1, GYG2, TBL3, M...
# 0  {SLC16A4, C16ORF72, RAF1, GHRHR, CNKSR1, ANKRD...
# 0  {STK39, SLC16A4, HSD17B7, CXCL1, USP40, MYLK3,...
# 0  {C16ORF72, CXCL1, E9PSI1, CAV1, CNKSR1, GYG2, ...
# 0  {HSD17B7, BROX, WDR46, CAV1, MYLK3, USP40, MAP...
# Num_perm= 20
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
# 0  Random_pps_taiji_fd_14       10          14      23      17
# 0  Random_pps_taiji_fd_15        7          12      18      15
# 0  Random_pps_taiji_fd_16       18          21      28      19
# 0  Random_pps_taiji_fd_17       14          17      21      15
# 0  Random_pps_taiji_fd_18       13          20      24      13
# 0  Random_pps_taiji_fd_19       13          14      24      13
# 0  Random_pps_taiji_fd_20        7          17      20      15
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# 0  {STK39, CXCL1, GHRHR, WDR46, SLITRK1, CAV1, MO...
# 0  {STK39, HSD17B7, C16ORF72, RAF1, GHRHR, E9PSI1...
# 0  {C16ORF72, BROX, CXCL1, SLITRK1, GYG2, TBL3, M...
# 0  {SLC16A4, C16ORF72, RAF1, GHRHR, CNKSR1, ANKRD...
# 0  {STK39, SLC16A4, HSD17B7, CXCL1, USP40, MYLK3,...
# 0  {C16ORF72, CXCL1, E9PSI1, CAV1, CNKSR1, GYG2, ...
# 0  {HSD17B7, BROX, WDR46, CAV1, MYLK3, USP40, MAP...
# 0  {HSD17B7, RAF1, CXCL1, SLITRK1, CAV1, CNKSR1, ...
# Num_perm= 21
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
# 0  Random_pps_taiji_fd_14       10          14      23      17
# 0  Random_pps_taiji_fd_15        7          12      18      15
# 0  Random_pps_taiji_fd_16       18          21      28      19
# 0  Random_pps_taiji_fd_17       14          17      21      15
# 0  Random_pps_taiji_fd_18       13          20      24      13
# 0  Random_pps_taiji_fd_19       13          14      24      13
# 0  Random_pps_taiji_fd_20        7          17      20      15
# 0  Random_pps_taiji_fd_21       11          15      20      17
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# 0  {STK39, CXCL1, GHRHR, WDR46, SLITRK1, CAV1, MO...
# 0  {STK39, HSD17B7, C16ORF72, RAF1, GHRHR, E9PSI1...
# 0  {C16ORF72, BROX, CXCL1, SLITRK1, GYG2, TBL3, M...
# 0  {SLC16A4, C16ORF72, RAF1, GHRHR, CNKSR1, ANKRD...
# 0  {STK39, SLC16A4, HSD17B7, CXCL1, USP40, MYLK3,...
# 0  {C16ORF72, CXCL1, E9PSI1, CAV1, CNKSR1, GYG2, ...
# 0  {HSD17B7, BROX, WDR46, CAV1, MYLK3, USP40, MAP...
# 0  {HSD17B7, RAF1, CXCL1, SLITRK1, CAV1, CNKSR1, ...
# 0  {HSD17B7, C16ORF72, BROX, USP40, UTP18, SMIM20...
# Num_perm= 22
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
# 0  Random_pps_taiji_fd_14       10          14      23      17
# 0  Random_pps_taiji_fd_15        7          12      18      15
# 0  Random_pps_taiji_fd_16       18          21      28      19
# 0  Random_pps_taiji_fd_17       14          17      21      15
# 0  Random_pps_taiji_fd_18       13          20      24      13
# 0  Random_pps_taiji_fd_19       13          14      24      13
# 0  Random_pps_taiji_fd_20        7          17      20      15
# 0  Random_pps_taiji_fd_21       11          15      20      17
# 0  Random_pps_taiji_fd_22       11          16      26      16
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# 0  {STK39, CXCL1, GHRHR, WDR46, SLITRK1, CAV1, MO...
# 0  {STK39, HSD17B7, C16ORF72, RAF1, GHRHR, E9PSI1...
# 0  {C16ORF72, BROX, CXCL1, SLITRK1, GYG2, TBL3, M...
# 0  {SLC16A4, C16ORF72, RAF1, GHRHR, CNKSR1, ANKRD...
# 0  {STK39, SLC16A4, HSD17B7, CXCL1, USP40, MYLK3,...
# 0  {C16ORF72, CXCL1, E9PSI1, CAV1, CNKSR1, GYG2, ...
# 0  {HSD17B7, BROX, WDR46, CAV1, MYLK3, USP40, MAP...
# 0  {HSD17B7, RAF1, CXCL1, SLITRK1, CAV1, CNKSR1, ...
# 0  {HSD17B7, C16ORF72, BROX, USP40, UTP18, SMIM20...
# 0  {C16ORF72, BROX, CXCL1, IL36G, MYLK3, CNKSR1, ...
# Num_perm= 23
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
# 0  Random_pps_taiji_fd_14       10          14      23      17
# 0  Random_pps_taiji_fd_15        7          12      18      15
# 0  Random_pps_taiji_fd_16       18          21      28      19
# 0  Random_pps_taiji_fd_17       14          17      21      15
# 0  Random_pps_taiji_fd_18       13          20      24      13
# 0  Random_pps_taiji_fd_19       13          14      24      13
# 0  Random_pps_taiji_fd_20        7          17      20      15
# 0  Random_pps_taiji_fd_21       11          15      20      17
# 0  Random_pps_taiji_fd_22       11          16      26      16
# 0  Random_pps_taiji_fd_23       12          17      20      14
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# 0  {STK39, CXCL1, GHRHR, WDR46, SLITRK1, CAV1, MO...
# 0  {STK39, HSD17B7, C16ORF72, RAF1, GHRHR, E9PSI1...
# 0  {C16ORF72, BROX, CXCL1, SLITRK1, GYG2, TBL3, M...
# 0  {SLC16A4, C16ORF72, RAF1, GHRHR, CNKSR1, ANKRD...
# 0  {STK39, SLC16A4, HSD17B7, CXCL1, USP40, MYLK3,...
# 0  {C16ORF72, CXCL1, E9PSI1, CAV1, CNKSR1, GYG2, ...
# 0  {HSD17B7, BROX, WDR46, CAV1, MYLK3, USP40, MAP...
# 0  {HSD17B7, RAF1, CXCL1, SLITRK1, CAV1, CNKSR1, ...
# 0  {HSD17B7, C16ORF72, BROX, USP40, UTP18, SMIM20...
# 0  {C16ORF72, BROX, CXCL1, IL36G, MYLK3, CNKSR1, ...
# 0  {C16ORF72, RAF1, SLITRK1, GYG2, TBL3, ANKRD24,...
# Num_perm= 24
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
# 0  Random_pps_taiji_fd_14       10          14      23      17
# 0  Random_pps_taiji_fd_15        7          12      18      15
# 0  Random_pps_taiji_fd_16       18          21      28      19
# 0  Random_pps_taiji_fd_17       14          17      21      15
# 0  Random_pps_taiji_fd_18       13          20      24      13
# 0  Random_pps_taiji_fd_19       13          14      24      13
# 0  Random_pps_taiji_fd_20        7          17      20      15
# 0  Random_pps_taiji_fd_21       11          15      20      17
# 0  Random_pps_taiji_fd_22       11          16      26      16
# 0  Random_pps_taiji_fd_23       12          17      20      14
# 0  Random_pps_taiji_fd_24       12          15      20      13
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# 0  {STK39, CXCL1, GHRHR, WDR46, SLITRK1, CAV1, MO...
# 0  {STK39, HSD17B7, C16ORF72, RAF1, GHRHR, E9PSI1...
# 0  {C16ORF72, BROX, CXCL1, SLITRK1, GYG2, TBL3, M...
# 0  {SLC16A4, C16ORF72, RAF1, GHRHR, CNKSR1, ANKRD...
# 0  {STK39, SLC16A4, HSD17B7, CXCL1, USP40, MYLK3,...
# 0  {C16ORF72, CXCL1, E9PSI1, CAV1, CNKSR1, GYG2, ...
# 0  {HSD17B7, BROX, WDR46, CAV1, MYLK3, USP40, MAP...
# 0  {HSD17B7, RAF1, CXCL1, SLITRK1, CAV1, CNKSR1, ...
# 0  {HSD17B7, C16ORF72, BROX, USP40, UTP18, SMIM20...
# 0  {C16ORF72, BROX, CXCL1, IL36G, MYLK3, CNKSR1, ...
# 0  {C16ORF72, RAF1, SLITRK1, GYG2, TBL3, ANKRD24,...
# 0  {SLC16A4, C16ORF72, CXCL1, CAV1, USP40, MORF4L...
# Num_perm= 25
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
# 0  Random_pps_taiji_fd_14       10          14      23      17
# 0  Random_pps_taiji_fd_15        7          12      18      15
# 0  Random_pps_taiji_fd_16       18          21      28      19
# 0  Random_pps_taiji_fd_17       14          17      21      15
# 0  Random_pps_taiji_fd_18       13          20      24      13
# 0  Random_pps_taiji_fd_19       13          14      24      13
# 0  Random_pps_taiji_fd_20        7          17      20      15
# 0  Random_pps_taiji_fd_21       11          15      20      17
# 0  Random_pps_taiji_fd_22       11          16      26      16
# 0  Random_pps_taiji_fd_23       12          17      20      14
# 0  Random_pps_taiji_fd_24       12          15      20      13
# 0  Random_pps_taiji_fd_25        9          14      18       9
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0  {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0  {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# 0  {HSD17B7, BROX, RAF1, SLITRK1, CNKSR1, UTP18, ...
# 0  {STK39, SLC16A4, TMEM19, CXCL1, IL36G, E9PSI1,...
# 0  {SLC16A4, TMEM19, BROX, CNKSR1, UTP18, MAPK15,...
# 0  {SLC16A4, HSD17B7, TMEM19, CXCL1, CAV1, GYG2, ...
# 0  {SLC16A4, TMEM19, CAV1, MYLK3, MORF4L1, CNKSR1...
# 0  {CXCL1, IL36G, USP40, UTP18, ANKRD24, CRLF1, O...
# 0  {C16ORF72, MAPK15, ANKRD24, CRLF1, MFSD14B, CB...
# 0  {STK39, BROX, IL36G, WDR46, SLITRK1, CAV1, ANK...
# 0  {STK39, CXCL1, GHRHR, WDR46, SLITRK1, CAV1, MO...
# 0  {STK39, HSD17B7, C16ORF72, RAF1, GHRHR, E9PSI1...
# 0  {C16ORF72, BROX, CXCL1, SLITRK1, GYG2, TBL3, M...
# 0  {SLC16A4, C16ORF72, RAF1, GHRHR, CNKSR1, ANKRD...
# 0  {STK39, SLC16A4, HSD17B7, CXCL1, USP40, MYLK3,...
# 0  {C16ORF72, CXCL1, E9PSI1, CAV1, CNKSR1, GYG2, ...
# 0  {HSD17B7, BROX, WDR46, CAV1, MYLK3, USP40, MAP...
# 0  {HSD17B7, RAF1, CXCL1, SLITRK1, CAV1, CNKSR1, ...
# 0  {HSD17B7, C16ORF72, BROX, USP40, UTP18, SMIM20...
# 0  {C16ORF72, BROX, CXCL1, IL36G, MYLK3, CNKSR1, ...
# 0  {C16ORF72, RAF1, SLITRK1, GYG2, TBL3, ANKRD24,...
# 0  {SLC16A4, C16ORF72, CXCL1, CAV1, USP40, MORF4L...
# 0  {C16ORF72, IL36G, SLITRK1, MYLK3, MORF4L1, GYG...
# Num_perm= 26
#                       Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0   Random_pps_taiji_fd_0       14          20      22      17
# 0   Random_pps_taiji_fd_1        6           8      23      10
# 0   Random_pps_taiji_fd_2       15          20      28      22
# 0   Random_pps_taiji_fd_3       16          27      28      20
# 0   Random_pps_taiji_fd_4       10          13      21      13
# 0   Random_pps_taiji_fd_5       11          16      23      14
# 0   Random_pps_taiji_fd_6       11          13      18      16
# 0   Random_pps_taiji_fd_7       18          21      30      19
# 0   Random_pps_taiji_fd_8       10          17      21      16
# 0   Random_pps_taiji_fd_9        8          10      18       8
# 0  Random_pps_taiji_fd_10       13          16      25      17
# 0  Random_pps_taiji_fd_11       12          17      21      19
# 0  Random_pps_taiji_fd_12        8          13      26      19
# 0  Random_pps_taiji_fd_13       11          13      25      17
# 0  Random_pps_taiji_fd_14       10          14      23      17
# 0  Random_pps_taiji_fd_15        7          12      18      15
# 0  Random_pps_taiji_fd_16       18          21      28      19
# 0  Random_pps_taiji_fd_17       14          17      21      15
# 0  Random_pps_taiji_fd_18       13          20      24      13
# 0  Random_pps_taiji_fd_19       13          14      24      13
# 0  Random_pps_taiji_fd_20        7          17      20      15
# 0  Random_pps_taiji_fd_21       11          15      20      17
# 0  Random_pps_taiji_fd_22       11          16      26      16
# 0  Random_pps_taiji_fd_23       12          17      20      14
# 0  Random_pps_taiji_fd_24       12          15      20      13
# 0  Random_pps_taiji_fd_25        9          14      18       9
# 0  Random_pps_taiji_fd_26        9          11      23      19
#
#                                                Genes
# 0  {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0  {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0  {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# ...
#
#                                                 Genes
# 0   {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0   {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0   {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0   {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0   {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# ..                                                ...
# 0   {GHRHR, USP40, CNKSR1, GYG2, PDE6G, A8K1V4, FO...
# 0   {STK39, SLC16A4, TMEM19, C16ORF72, WDR46, SLIT...
# 0   {SLC16A4, BROX, CXCL1, IL36G, SMIM20, GLP1R, C...
# 0   {SLC16A4, C16ORF72, WDR46, E9PSI1, CNKSR1, MAP...
# 0   {STK39, SLC16A4, CAV1, GYG2, TBL3, MAPK15, ANK...
#
# [990 rows x 6 columns]
# Num_perm= 990
#                         Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_taiji_fd_0       14          20      22      17
# 0     Random_pps_taiji_fd_1        6           8      23      10
# 0     Random_pps_taiji_fd_2       15          20      28      22
# 0     Random_pps_taiji_fd_3       16          27      28      20
# 0     Random_pps_taiji_fd_4       10          13      21      13
# ..                      ...      ...         ...     ...     ...
# 0   Random_pps_taiji_fd_986       10          13      23      14
# 0   Random_pps_taiji_fd_987       15          25      29      19
# 0   Random_pps_taiji_fd_988        5           9      17      12
# 0   Random_pps_taiji_fd_989       14          11      20      13
# 0   Random_pps_taiji_fd_990       12          14      22      17
#
#                                                 Genes
# 0   {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0   {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0   {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0   {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0   {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# ..                                                ...
# 0   {STK39, SLC16A4, TMEM19, C16ORF72, WDR46, SLIT...
# 0   {SLC16A4, BROX, CXCL1, IL36G, SMIM20, GLP1R, C...
# 0   {SLC16A4, C16ORF72, WDR46, E9PSI1, CNKSR1, MAP...
# 0   {STK39, SLC16A4, CAV1, GYG2, TBL3, MAPK15, ANK...
# 0   {STK39, CXCL1, GHRHR, WDR46, MYLK3, USP40, UTP...
#
# [991 rows x 6 columns]
# Num_perm= 991
#                         Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_taiji_fd_0       14          20      22      17
# 0     Random_pps_taiji_fd_1        6           8      23      10
# 0     Random_pps_taiji_fd_2       15          20      28      22
# 0     Random_pps_taiji_fd_3       16          27      28      20
# 0     Random_pps_taiji_fd_4       10          13      21      13
# ..                      ...      ...         ...     ...     ...
# 0   Random_pps_taiji_fd_987       15          25      29      19
# 0   Random_pps_taiji_fd_988        5           9      17      12
# 0   Random_pps_taiji_fd_989       14          11      20      13
# 0   Random_pps_taiji_fd_990       12          14      22      17
# 0   Random_pps_taiji_fd_991       10          12      18      14
#
#                                                 Genes
# 0   {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0   {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0   {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0   {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0   {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# ..                                                ...
# 0   {SLC16A4, BROX, CXCL1, IL36G, SMIM20, GLP1R, C...
# 0   {SLC16A4, C16ORF72, WDR46, E9PSI1, CNKSR1, MAP...
# 0   {STK39, SLC16A4, CAV1, GYG2, TBL3, MAPK15, ANK...
# 0   {STK39, CXCL1, GHRHR, WDR46, MYLK3, USP40, UTP...
# 0   {SLC16A4, HSD17B7, CXCL1, GHRHR, IL36G, MYLK3,...
#
# [992 rows x 6 columns]
# Num_perm= 992
#                         Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_taiji_fd_0       14          20      22      17
# 0     Random_pps_taiji_fd_1        6           8      23      10
# 0     Random_pps_taiji_fd_2       15          20      28      22
# 0     Random_pps_taiji_fd_3       16          27      28      20
# 0     Random_pps_taiji_fd_4       10          13      21      13
# ..                      ...      ...         ...     ...     ...
# 0   Random_pps_taiji_fd_988        5           9      17      12
# 0   Random_pps_taiji_fd_989       14          11      20      13
# 0   Random_pps_taiji_fd_990       12          14      22      17
# 0   Random_pps_taiji_fd_991       10          12      18      14
# 0   Random_pps_taiji_fd_992       11          18      21      16
#
#                                                 Genes
# 0   {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0   {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0   {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0   {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0   {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# ..                                                ...
# 0   {SLC16A4, C16ORF72, WDR46, E9PSI1, CNKSR1, MAP...
# 0   {STK39, SLC16A4, CAV1, GYG2, TBL3, MAPK15, ANK...
# 0   {STK39, CXCL1, GHRHR, WDR46, MYLK3, USP40, UTP...
# 0   {SLC16A4, HSD17B7, CXCL1, GHRHR, IL36G, MYLK3,...
# 0   {STK39, HSD17B7, TMEM19, GHRHR, IL36G, WDR46, ...
#
# [993 rows x 6 columns]
# Num_perm= 993
#                         Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_taiji_fd_0       14          20      22      17
# 0     Random_pps_taiji_fd_1        6           8      23      10
# 0     Random_pps_taiji_fd_2       15          20      28      22
# 0     Random_pps_taiji_fd_3       16          27      28      20
# 0     Random_pps_taiji_fd_4       10          13      21      13
# ..                      ...      ...         ...     ...     ...
# 0   Random_pps_taiji_fd_989       14          11      20      13
# 0   Random_pps_taiji_fd_990       12          14      22      17
# 0   Random_pps_taiji_fd_991       10          12      18      14
# 0   Random_pps_taiji_fd_992       11          18      21      16
# 0   Random_pps_taiji_fd_993       15          21      25      15
#
#                                                 Genes
# 0   {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0   {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0   {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0   {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0   {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# ..                                                ...
# 0   {STK39, SLC16A4, CAV1, GYG2, TBL3, MAPK15, ANK...
# 0   {STK39, CXCL1, GHRHR, WDR46, MYLK3, USP40, UTP...
# 0   {SLC16A4, HSD17B7, CXCL1, GHRHR, IL36G, MYLK3,...
# 0   {STK39, HSD17B7, TMEM19, GHRHR, IL36G, WDR46, ...
# 0   {C16ORF72, BROX, RAF1, TMEM19, IL36G, E9PSI1, ...
#
# [994 rows x 6 columns]
# Num_perm= 994
#                         Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_taiji_fd_0       14          20      22      17
# 0     Random_pps_taiji_fd_1        6           8      23      10
# 0     Random_pps_taiji_fd_2       15          20      28      22
# 0     Random_pps_taiji_fd_3       16          27      28      20
# 0     Random_pps_taiji_fd_4       10          13      21      13
# ..                      ...      ...         ...     ...     ...
# 0   Random_pps_taiji_fd_990       12          14      22      17
# 0   Random_pps_taiji_fd_991       10          12      18      14
# 0   Random_pps_taiji_fd_992       11          18      21      16
# 0   Random_pps_taiji_fd_993       15          21      25      15
# 0   Random_pps_taiji_fd_994       14          15      22      15
#
#                                                 Genes
# 0   {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0   {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0   {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0   {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0   {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# ..                                                ...
# 0   {STK39, CXCL1, GHRHR, WDR46, MYLK3, USP40, UTP...
# 0   {SLC16A4, HSD17B7, CXCL1, GHRHR, IL36G, MYLK3,...
# 0   {STK39, HSD17B7, TMEM19, GHRHR, IL36G, WDR46, ...
# 0   {C16ORF72, BROX, RAF1, TMEM19, IL36G, E9PSI1, ...
# 0   {SLC16A4, C16ORF72, CXCL1, GHRHR, IL36G, WDR46...
#
# [995 rows x 6 columns]
# Num_perm= 995
#                         Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_taiji_fd_0       14          20      22      17
# 0     Random_pps_taiji_fd_1        6           8      23      10
# 0     Random_pps_taiji_fd_2       15          20      28      22
# 0     Random_pps_taiji_fd_3       16          27      28      20
# 0     Random_pps_taiji_fd_4       10          13      21      13
# ..                      ...      ...         ...     ...     ...
# 0   Random_pps_taiji_fd_991       10          12      18      14
# 0   Random_pps_taiji_fd_992       11          18      21      16
# 0   Random_pps_taiji_fd_993       15          21      25      15
# 0   Random_pps_taiji_fd_994       14          15      22      15
# 0   Random_pps_taiji_fd_995       13          18      23      14
#
#                                                 Genes
# 0   {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0   {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0   {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0   {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0   {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# ..                                                ...
# 0   {SLC16A4, HSD17B7, CXCL1, GHRHR, IL36G, MYLK3,...
# 0   {STK39, HSD17B7, TMEM19, GHRHR, IL36G, WDR46, ...
# 0   {C16ORF72, BROX, RAF1, TMEM19, IL36G, E9PSI1, ...
# 0   {SLC16A4, C16ORF72, CXCL1, GHRHR, IL36G, WDR46...
# 0   {GHRHR, WDR46, USP40, TBL3, GLP1R, CRLF1, FOXJ...
#
# [996 rows x 6 columns]
# Num_perm= 996
#                         Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_taiji_fd_0       14          20      22      17
# 0     Random_pps_taiji_fd_1        6           8      23      10
# 0     Random_pps_taiji_fd_2       15          20      28      22
# 0     Random_pps_taiji_fd_3       16          27      28      20
# 0     Random_pps_taiji_fd_4       10          13      21      13
# ..                      ...      ...         ...     ...     ...
# 0   Random_pps_taiji_fd_992       11          18      21      16
# 0   Random_pps_taiji_fd_993       15          21      25      15
# 0   Random_pps_taiji_fd_994       14          15      22      15
# 0   Random_pps_taiji_fd_995       13          18      23      14
# 0   Random_pps_taiji_fd_996       13          18      26      14
#
#                                                 Genes
# 0   {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0   {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0   {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0   {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0   {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# ..                                                ...
# 0   {STK39, HSD17B7, TMEM19, GHRHR, IL36G, WDR46, ...
# 0   {C16ORF72, BROX, RAF1, TMEM19, IL36G, E9PSI1, ...
# 0   {SLC16A4, C16ORF72, CXCL1, GHRHR, IL36G, WDR46...
# 0   {GHRHR, WDR46, USP40, TBL3, GLP1R, CRLF1, FOXJ...
# 0   {STK39, HSD17B7, C16ORF72, BROX, SLITRK1, CNKS...
#
# [997 rows x 6 columns]
# Num_perm= 997
#                         Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_taiji_fd_0       14          20      22      17
# 0     Random_pps_taiji_fd_1        6           8      23      10
# 0     Random_pps_taiji_fd_2       15          20      28      22
# 0     Random_pps_taiji_fd_3       16          27      28      20
# 0     Random_pps_taiji_fd_4       10          13      21      13
# ..                      ...      ...         ...     ...     ...
# 0   Random_pps_taiji_fd_993       15          21      25      15
# 0   Random_pps_taiji_fd_994       14          15      22      15
# 0   Random_pps_taiji_fd_995       13          18      23      14
# 0   Random_pps_taiji_fd_996       13          18      26      14
# 0   Random_pps_taiji_fd_997       12          22      29      17
#
#                                                 Genes
# 0   {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0   {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0   {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0   {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0   {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# ..                                                ...
# 0   {C16ORF72, BROX, RAF1, TMEM19, IL36G, E9PSI1, ...
# 0   {SLC16A4, C16ORF72, CXCL1, GHRHR, IL36G, WDR46...
# 0   {GHRHR, WDR46, USP40, TBL3, GLP1R, CRLF1, FOXJ...
# 0   {STK39, HSD17B7, C16ORF72, BROX, SLITRK1, CNKS...
# 0   {SLC16A4, C16ORF72, BROX, E9PSI1, CAV1, TBL3, ...
#
# [998 rows x 6 columns]
# Num_perm= 998
#                         Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_taiji_fd_0       14          20      22      17
# 0     Random_pps_taiji_fd_1        6           8      23      10
# 0     Random_pps_taiji_fd_2       15          20      28      22
# 0     Random_pps_taiji_fd_3       16          27      28      20
# 0     Random_pps_taiji_fd_4       10          13      21      13
# ..                      ...      ...         ...     ...     ...
# 0   Random_pps_taiji_fd_994       14          15      22      15
# 0   Random_pps_taiji_fd_995       13          18      23      14
# 0   Random_pps_taiji_fd_996       13          18      26      14
# 0   Random_pps_taiji_fd_997       12          22      29      17
# 0   Random_pps_taiji_fd_998       11          15      26      13
#
#                                                 Genes
# 0   {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0   {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0   {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0   {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0   {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# ..                                                ...
# 0   {SLC16A4, C16ORF72, CXCL1, GHRHR, IL36G, WDR46...
# 0   {GHRHR, WDR46, USP40, TBL3, GLP1R, CRLF1, FOXJ...
# 0   {STK39, HSD17B7, C16ORF72, BROX, SLITRK1, CNKS...
# 0   {SLC16A4, C16ORF72, BROX, E9PSI1, CAV1, TBL3, ...
# 0   {SLC16A4, HSD17B7, IL36G, SMIM20, GLP1R, CRLF1...
#
# [999 rows x 6 columns]
# Num_perm= 999
#                         Set  Vinuesa  TFH Review  Crotty  Beckys  \
# 0     Random_pps_taiji_fd_0       14          20      22      17
# 0     Random_pps_taiji_fd_1        6           8      23      10
# 0     Random_pps_taiji_fd_2       15          20      28      22
# 0     Random_pps_taiji_fd_3       16          27      28      20
# 0     Random_pps_taiji_fd_4       10          13      21      13
# ..                      ...      ...         ...     ...     ...
# 0   Random_pps_taiji_fd_995       13          18      23      14
# 0   Random_pps_taiji_fd_996       13          18      26      14
# 0   Random_pps_taiji_fd_997       12          22      29      17
# 0   Random_pps_taiji_fd_998       11          15      26      13
# 0   Random_pps_taiji_fd_999        9          18      19      15
#
#                                                 Genes
# 0   {HSD17B7, C16ORF72, IL36G, WDR46, SLITRK1, USP...
# 0   {TMEM19, CXCL1, IL36G, MYLK3, TBL3, MAPK15, CC...
# 0   {C16ORF72, BROX, E9PSI1, USP40, GYG2, MORF4L1,...
# 0   {STK39, C16ORF72, CXCL1, MYLK3, MORF4L1, GLP1R...
# 0   {GHRHR, SLITRK1, CNKSR1, UTP18, SMIM20, PDE6G,...
# ..                                                ...
# 0   {GHRHR, WDR46, USP40, TBL3, GLP1R, CRLF1, FOXJ...
# 0   {STK39, HSD17B7, C16ORF72, BROX, SLITRK1, CNKS...
# 0   {SLC16A4, C16ORF72, BROX, E9PSI1, CAV1, TBL3, ...
# 0   {SLC16A4, HSD17B7, IL36G, SMIM20, GLP1R, CRLF1...
# 0   {STK39, CAV1, MYLK3, UTP18, USP40, SMIM20, ANK...
#
# [1000 rows x 6 columns]

# %%
pps_taiji_overlapping_random =  random_overlaps_perm(pps_taiji, set_name = 'pps_taiji', num_perm=1000, output= 'genes_gene_len')
pps_taiji_overlapping_random.to_csv('../../Input_data/random_pps_taiji_overlaps_df.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 pps_taiji_overlapping_random =  random_overlaps_perm(pps_taiji, set_name = 'pps_taiji', num_perm=1000, output= 'genes_gene_len')
#       2 pps_taiji_overlapping_random.to_csv('../../Input_data/random_pps_taiji_overlaps_df.csv')
#
# NameError: name 'pps_taiji' is not defined

# %%
print(np.round(np.mean(taiji_overlapping_random['Vinuesa'])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 print(np.round(np.mean(taiji_overlapping_random['Vinuesa'])))
#
# NameError: name 'taiji_overlapping_random' is not defined

# %%
taiji_random_gene_set = taiji_overlapping_random_fd.loc[(taiji_overlapping_random_fd['Vinuesa'].eq(6)) 
                                                        & (taiji_overlapping_random_fd['TFH Review'].eq(8))
                                                        & (taiji_overlapping_random_fd['Crotty'].eq(11))
                                                        #& (taiji_overlapping_random_fd['Beckys'].eq(7))
                                                       ].reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 taiji_random_gene_set = taiji_overlapping_random_fd.loc[(taiji_overlapping_random_fd['Vinuesa'].eq(6))
#       2                                                         & (taiji_overlapping_random_fd['TFH Review'].eq(8))
#       3                                                         & (taiji_overlapping_random_fd['Crotty'].eq(11))
#       4                                                         #& (taiji_overlapping_random_fd['Beckys'].eq(7))
#       5                                                        ].reset_index()
#
# NameError: name 'taiji_overlapping_random_fd' is not defined

# %%
#get_random_gene_list(logFC_random_fd, set_name = 'logFC_RNA_fd', save='on')
get_random_gene_list(pps_noprop_random_fd, set_name = 'PPS_noprop_fd_184', save='on')
# Out:
# Saving File...
# ({'KCNN4',
#   'Q86TT2',
#   'UNC80',
#   'SLC16A4',
#   'FADS2',
#   'APLP1',
#   'BROX',
#   'RAF1',
#   'FAM53A',
#   'IVNS1ABP',
#   'CD74',
#   'IL36G',
#   'CAV1',
#   'GYG2',
#   'SMIM20',
#   'KDF1',
#   'B7Z3W8',
#   'HSPA1B',
#   'ASB13',
#   'FRAT2',
#   'SLC43A1',
#   'K7ENZ8',
#   'KLK6',
#   'Q5JU30',
#   'DDOST',
#   'PRAME',
#   'H3BSY8',
#   'GPD1',
#   'KCNIP1',
#   'SCNM1',
#   'AKAP13',
#   'LYPD5',
#   'IPO7',
#   'ELMOD2',
#   'B3KRP9',
#   'GNG4',
#   'HCFC1',
#   'TMCO3',
#   'SLC7A10',
#   'DHX37',
#   'ZNF865',
#   'KIAA0100',
#   'TPSG1',
#   'INSL3',
#   'EFNA1',
#   'TMEM258',
#   'GABRG1',
#   'ZNF300',
#   'SUSD4',
#   'PRXL2B',
#   'SLC7A9',
#   'ZAP70',
#   'APCS',
#   'UPI0002176A5B',
#   'DECR1',
#   'UPI0001A48FB5',
#   'MED27',
#   'CRACDL',
#   'DPCD',
#   'DRAP1',
#   'RELA',
#   'KIF5B',
#   'KIAA0087',
#   'ZSCAN9',
#   'STAG1',
#   'GPATCH4',
#   'GPR61',
#   'ANKRD26P1',
#   'CLIP2',
#   'PYURF',
#   'WDR45',
#   'TP53I11',
#   'PEBP4',
#   'SPIC',
#   'SH2D3A',
#   'TMPRSS11A',
#   'RPL41',
#   'GLG1',
#   'NFX1',
#   'TMEM183A',
#   'C1GALT1C1',
#   'NFKB1',
#   'DKFZP564M2422',
#   'LYRM1',
#   'OSBPL1A',
#   'RANBP10',
#   'C14ORF133',
#   'CDA',
#   'CTNND2',
#   'KMT2D',
#   'HLA-B57',
#   'SMARCD3',
#   'CCDC184',
#   'HOPX',
#   'NEF3',
#   'OCEL1',
#   'DUSP18',
#   'MT-ND4',
#   'KCTD9',
#   'Q53HD4',
#   'ACACA',
#   'GSAP',
#   'SAMM50',
#   'UBAP2',
#   'SPRY3',
#   'ST8SIA1',
#   'RAB5C',
#   'NCAPH2',
#   'H2BC1',
#   'ZNF763',
#   'EFS',
#   'Q96IQ6',
#   'GMDS',
#   'BBOX1',
#   'ASXL2',
#   'PLIN2',
#   'PTAFR',
#   'CEL',
#   'RPS14',
#   'ZNF101',
#   'CPXM2',
#   'MAGOH',
#   'PDXK',
#   'F8W6J9',
#   'RNF115',
#   'MT1F',
#   'TUBB1',
#   'B4GALT5',
#   'FES',
#   'NGRN',
#   'PCDH18',
#   'CHCHD10',
#   'UPI0002590962',
#   'PPP4C',
#   'RSPO2',
#   'TPD52',
#   'ARHGEF16',
#   'IQGAP3',
#   'SFRS3',
#   'ZNF23',
#   'MXD3',
#   'TELO2',
#   'ARMC9',
#   'PSG4',
#   'EIF4EBP3',
#   'EVC',
#   'NEUROD2',
#   'C12ORF4',
#   'ELL3',
#   'NOD2',
#   'WTAP',
#   'LDHB',
#   'TMEM109',
#   'DHRS13',
#   'INCA1',
#   'SERP2',
#   'ZFYVE28',
#   'CLTA',
#   'ADCY3',
#   'OR9G1',
#   'SLC25A35',
#   'PCDHA4',
#   'Q8NAS7',
#   'PDE4DIP',
#   'ETF1',
#   'CCL14',
#   'NPHP3',
#   'VWA5B2',
#   'LYPD1',
#   'HES7',
#   'TXNDC5',
#   'MYL2',
#   'MYLIP',
#   'TMEM236',
#   'IL13RA1',
#   'NDUFS4',
#   'NLGN2',
#   'MMAB',
#   'IL10RA',
#   'TMEM108',
#   'FAM181B',
#   'ZMAT2',
#   'MYO10',
#   'ZNF841',
#   'CLEC5A',
#   'UST',
#   'HIST1H1E',
#   'JUP',
#   'C4ORF46',
#   'NUFIP2',
#   'HERC6',
#   'MYADML2',
#   'ETNK1',
#   'ZDHHC24',
#   'UNC93B1',
#   'CASC5',
#   'ZFAND6',
#   'CIAPIN1',
#   'HSPA12A',
#   'PENK',
#   'HSF1',
#   'HYOU1',
#   'EGFLAM',
#   'Q9H368',
#   'ADORA2A',
#   'CRTAC1',
#   'AKAP8',
#   'HGD',
#   'HIVEP2',
#   'ZC2HC1C',
#   'ITFG1',
#   'SERINC5',
#   'FAM20A',
#   'MAGI3',
#   'LRRC23',
#   'TMEM127',
#   'CALD1',
#   'CEP295',
#   'TOMM7',
#   'O95065',
#   'STARD7',
#   'TSPO',
#   'RAB3B',
#   'FSBP',
#   'IRF5',
#   'ACP2',
#   'AURKA',
#   'VPREB1',
#   'NUDT16',
#   'GPR3',
#   'LRRC73',
#   'RNF111',
#   'GTF2IRD2B',
#   'PLEKHA8',
#   'MSTN',
#   'CENPA',
#   'GPI',
#   'LIPM',
#   'ADNP2',
#   'ZKSCAN4',
#   'B3GALT4',
#   'PCBP1',
#   'USP48',
#   'SLC10A4',
#   'PES1',
#   'CROT',
#   'SPATS2',
#   'SRGAP2B',
#   'SNTG1',
#   'PTCRA',
#   'ACKR2',
#   'FILIP1L',
#   'MAGEB10',
#   'PIG59',
#   'ALG10B',
#   'ST6GALNAC4',
#   'ZMYND10',
#   'UBXN7',
#   'TMEM214',
#   'E5KN15',
#   'CCDC154',
#   'GDAP1',
#   'CCDC32',
#   'SGSH',
#   'SVIP',
#   'MST075',
#   'TUBA8',
#   'ZEB2',
#   'ZNF563',
#   'PNPLA2',
#   'ERGIC2',
#   'UQCC3',
#   'PPP1R3B',
#   'TINF2',
#   'GAL3ST4',
#   'GNAQ',
#   'DLX4',
#   'GGNBP2',
#   'MRRF',
#   'PREB',
#   'THAP11',
#   'HSPB2-C11ORF52',
#   'OSBPL10',
#   'TDG',
#   'AMBN',
#   'EXOSC5',
#   'RAB29',
#   'JRK',
#   'AMOT',
#   'MUC15',
#   'TEKT2',
#   'ZNF740',
#   'GLTP',
#   'BAP18',
#   'FOXS1',
#   'LCE1D',
#   'NOVA2',
#   'BTBD16',
#   'TTC21A',
#   'IDH3A',
#   'AHNAK',
#   'LRRC18',
#   'TRNT1',
#   'M6PR',
#   'NANP',
#   'ZNF19',
#   'IL2RG',
#   'CMTR2',
#   'GLI2',
#   'GON7',
#   'TPGS1',
#   'LY96',
#   'RHOT1',
#   'CRB2',
#   'MSX1',
#   'PAX9',
#   'ADAMTS4',
#   'PIK3R2',
#   'INVS',
#   'LRP5L',
#   'BORCS6',
#   'LMOD3',
#   'C20ORF203',
#   'NAIF1',
#   'GGTLC2',
#   'ERG',
#   'Q5T7C6',
#   'FLNA',
#   'CCNI',
#   'OAZ1',
#   'KLKB1',
#   'ABTB1',
#   'ATP6V0D1',
#   'R3HDM1',
#   'CUL1',
#   'KLHL6',
#   'EN1',
#   'CDKL3',
#   'ZNF443',
#   'SLC15A4',
#   'PRTN3',
#   'STT3B',
#   'FOXH1',
#   'CLEC18A',
#   'HAVCR1',
#   'UBAC2',
#   'UBTD1',
#   'HDAC9',
#   'NOS1AP',
#   'SETMAR',
#   'LCAT',
#   'LRRC41',
#   'KAT5',
#   'MBL2',
#   'PHLDA2',
#   'NRIP1',
#   'PEX12',
#   'GAS6',
#   'CCNJ',
#   'USP3',
#   'PARD6G',
#   'ZNF550',
#   'LYRM7',
#   'RPL21',
#   'GYS1',
#   'UTRN',
#   'PSMA4',
#   'VSIR',
#   'PBX3',
#   'PLPP1',
#   'CCDC80',
#   'FKBP5',
#   'CLK4',
#   'TOR2A',
#   'TSSK2',
#   'RIPPLY1',
#   'HDAC6',
#   'LCOR',
#   'DIMT1',
#   'THOP1',
#   'CA14',
#   'SKIL',
#   'MASP2',
#   'EBF1',
#   'CTDP1',
#   'FAR1',
#   'AKAP14',
#   'HECW1',
#   'SLX4',
#   'LRRFIP2',
#   'TP53INP2',
#   'TMEM120A',
#   'SLC7A4',
#   'EIF4E1B',
#   'PDK1',
#   'PCSK2',
#   'VGLL1',
#   'SPA17',
#   'FBXL19',
#   'TP73',
#   'GP1BB',
#   'RNF180',
#   'SCN3A',
#   'COPZ1',
#   'A8K940',
#   'NR0B1',
#   'RANGAP1',
#   'HEYL',
#   'COX5B',
#   'PAX8',
#   'F8WCN8',
#   'SYTL4',
#   'FNBP1L',
#   'G4',
#   'H9NIM3',
#   'NBPF3',
#   'RBM19',
#   'KRT14',
#   'B7Z9S8',
#   'TATDN1',
#   'RTN4RL2',
#   'CAPN5',
#   'SCEL',
#   'ENC1',
#   'KAT7',
#   'CFAP410',
#   'RBP4',
#   'ERLIN2',
#   'EIF4G2',
#   'ZNF251',
#   'ASB8',
#   'HSD11B1',
#   'IBA57',
#   'PGAP3',
#   'PIK3CB',
#   'ZNF620',
#   'PEG3',
#   'SGSM1',
#   'SSX2IP',
#   'ZNF830',
#   'ANP32C',
#   'ACAD9',
#   'RSU1',
#   'MFSD10',
#   'GOT2',
#   'CACNA1H',
#   'PIAS2',
#   'TCOF1',
#   'GCOM1',
#   'ZNF84',
#   'LIN37',
#   'ZNF408',
#   'ZNF439',
#   'KLRK1',
#   'SCT',
#   'ABCB6',
#   'EOMES',
#   'DEK',
#   'ASTN2',
#   'PTPA',
#   'EMD',
#   'TMPRSS6',
#   'BLID',
#   'Q59G16',
#   'MPHOSPH8',
#   'KLHDC1',
#   'MRPL12',
#   'PRDM4',
#   'ZNF782',
#   'GFRA2',
#   'MFSD8',
#   'SLC44A3',
#   'ZNF585B',
#   'TUBA1A',
#   'ABCA5',
#   'FBXL8',
#   'MDH2',
#   'MTMR12',
#   'NR2F6',
#   'MRGBP',
#   'IDUA',
#   'B4DNA4',
#   'WDCP',
#   'GGN',
#   'NDUFV2',
#   'BLOC1S1',
#   'GFRA1',
#   'DBR1',
#   'SNX22',
#   'F8WBI7',
#   'SMIM21',
#   'PEAR1',
#   'RSPH9',
#   'KRTAP12-3',
#   'D7RIH9',
#   'IGHG3',
#   'AGBL1',
#   'TM9SF1',
#   'LMO4',
#   'KRTAP5-6',
#   'SLC25A1',
#   'B2RDX5',
#   'POLR3B',
#   'RXYLT1',
#   'WDR74',
#   'TBCCD1',
#   'FASTKD5',
#   'NME6',
#   'KCNA4',
#   'MREG',
#   'NADK',
#   'CYBC1',
#   'Q5T4L4',
#   'TSR2',
#   'SPHKAP',
#   'GAGE5',
#   'APBB3',
#   'CDK16',
#   'TEX10',
#   'FAM104A',
#   'RAD21L1',
#   'CEP131',
#   'CPT1A',
#   'PRDM16',
#   'TATDN2',
#   'MRPL20',
#   'MPP2',
#   'C21ORF58',
#   'SCAF11',
#   'NUDT22',
#   'ZSWIM9',
#   'V1-11',
#   'MYO1C',
#   'SPTBN2',
#   'HMGN2',
#   'PPY',
#   'ABHD17C',
#   'AJM1',
#   'ATG101',
#   'LIX1L',
#   'ARL6IP1',
#   'NACC2',
#   'HCFC1R1',
#   'TMEM234',
#   'JAKMIP1',
#   'RAB40C',
#   'ADK',
#   'C15ORF65',
#   'PTGES',
#   'TMEM199',
#   'SPRR1A',
#   'TRAPPC14',
#   'MIDEAS',
#   'LGALS9C',
#   'PCK1',
#   'ZNF426',
#   'GABRQ',
#   'AMN',
#   'ITGB7',
#   'CAGE1',
#   'Q95HA4',
#   'GRK1',
#   'CFAP91',
#   'HLA-DQA1',
#   'INSC',
#   'SIX4',
#   'DNASE1L2',
#   'SFXN3',
#   'DEFB103A|DEFB103B',
#   'RBM47',
#   'ADIRF',
#   'FAM126B',
#   'FLJ10404',
#   'FAM83B',
#   'SLC52A2',
#   'RAB38',
#   'TRIM72',
#   'NRXN1',
#   'CD79A',
#   'SPACA6',
#   'UFD1',
#   'BLOC1S5',
#   'ACTL7B',
#   'ANXA8L1',
#   'SRGAP3',
#   'MRPL1',
#   'PDCD4',
#   'GOLGB1',
#   'ATP12A',
#   'CALB2',
#   'SLA',
#   'UNC79',
#   'FBXL15',
#   'ANO8',
#   'CHD2',
#   'DKFZP451O0517',
#   'CCDC92',
#   'TET2',
#   'XAF1',
#   'RBMS3',
#   'PSMD2',
#   'PRKX',
#   'UXS1',
#   'RTKN2',
#   'ABHD14A',
#   'SFPQ',
#   'ADGRE2',
#   'MPDZ',
#   'SOX3',
#   'PELO',
#   'VCPIP1',
#   'ZNF10',
#   'SPRR3',
#   'CT45A7',
#   'A8K8G8',
#   'HECTD2',
#   'ARSJ',
#   'N4BP3',
#   'GAL3ST2',
#   'NDUFB8',
#   'FIG4',
#   'RPL13',
#   'SYDE1',
#   'Q86YY1',
#   'AMELY',
#   'METTL7A',
#   'NSL1',
#   'ZNF649',
#   'PHF13',
#   'ZBTB20',
#   'MTMR2',
#   'EPRS1',
#   'SMARCB1',
#   'GP9',
#   'YPEL5',
#   'CAVIN4',
#   'GALNT15',
#   'BEND3',
#   'TIA1',
#   'EPDR1',
#   'HNRNPK',
#   'SPIB',
#   'C16ORF54',
#   'NALCN',
#   'PFKFB2',
#   'PPP1R1B',
#   'NLRX1',
#   'CCDC127',
#   'PCMTD1',
#   'NDUFC2',
#   'POTEM',
#   'KCNA5',
#   'FASLG',
#   'STUM',
#   'CEP85L',
#   'EHD4',
#   'SYT17',
#   'PTGER3',
#   'SLC7A3',
#   'SENP5',
#   'UMPS',
#   'EID2B',
#   'SP1',
#   'FZD3',
#   'YTHDC2',
#   'XK',
#   'ELOVL7',
#   'PSMA3',
#   'ERI2',
#   'FAM102A',
#   'NDUFAF6',
#   'IHH',
#   'DMBT1',
#   'NTS',
#   'MRPL54',
#   'PAPSS2',
#   'RNASEK-C17ORF49',
#   'ARD1A',
#   'CENPBD1',
#   'CHORDC1',
#   'SMYD3',
#   'ARHGEF3',
#   'TNFRSF10D',
#   'PLAT',
#   'ATP6V0D2',
#   'ZNF664',
#   'POLG',
#   'GSK3A',
#   'IGLC2',
#   'LEPROTL1',
#   'KRT74',
#   'GAS7',
#   'ABITRAM',
#   'STK35',
#   'DNAJC5B',
#   'IAPP',
#   'GABARAPL2',
#   'KAZN',
#   'PLAGL2',
#   'GPSM1',
#   'SUPT20HL1',
#   'PRRX1',
#   'ZNF441',
#   'CCDC66',
#   'ANGPT1',
#   'REG1B',
#   'HSD17B14',
#   'VPS9D1',
#   'B2RDC9',
#   'CCL22',
#   'ZBTB14',
#   'TMEPAI',
#   'IRF9',
#   'KLHL23',
#   'FAM160B1',
#   'SLC51A',
#   'MARS1',
#   'RGSL1',
#   'WLS',
#   'PBX4',
#   'ECHS1',
#   'MAGEB16',
#   'RPS6KB1',
#   'ZNF891',
#   'ARPC1A',
#   'VIP',
#   'USH1G',
#   'TIMM10',
#   'CEP350',
#   'PPRC1',
#   'MRPL39',
#   'AKT1',
#   'AIDA',
#   'BAGE',
#   'ACIN1',
#   'NUTM2G',
#   'C22ORF9',
#   'HSPBAP1',
#   'SBK3',
#   'MEGF8',
#   'PHF21B',
#   'F5H3R7',
#   'LUC7L',
#   'C4ORF17',
#   'MLLT1',
#   'TATDN3',
#   'ARHGEF19',
#   'TXN',
#   'TSGA10IP',
#   'APAF1',
#   'PRKAR1B',
#   'ODF2',
#   'LBR',
#   'FAM120C',
#   'H2AC12',
#   'ATXN7L3',
#   'OXR1',
#   'G8JLL4',
#   'TMCC3',
#   'FYB1',
#   'DNAH17',
#   'WDR3',
#   'CUSTOS',
#   'TBC1D31',
#   'RRM1',
#   'IGHV1-46',
#   'CETN3',
#   'TM6SF2',
#   'CBX7',
#   'A8K2S7',
#   'UPK3A',
#   'CLN6',
#   'SMAD2',
#   'FRMPD1',
#   'MAML2',
#   'MDH1',
#   'HTR2A',
#   'OSR2',
#   'ZNF468',
#   'PAPD5',
#   'ATP5F1C',
#   'ICAM5',
#   'PCDH19',
#   'ARHGAP25',
#   'SNRK',
#   'ATP2B2',
#   'SLC39A1',
#   'CCBE1',
#   'AHCY',
#   'ADAM10',
#   'TENT4A',
#   'CCDC38',
#   'SOWAHA',
#   'NUP98',
#   'DCAF4L2',
#   'PPP6R2',
#   'YME1L1',
#   'TTC12',
#   'FAM90A1',
#   'MCM8',
#   'PUS10',
#   'SNTB2',
#   'H2AC18|H2AC19',
#   'ANK3',
#   'SELPLG',
#   'INSM1',
#   'JUNB',
#   'GALNT5',
#   'TMEM106A',
#   'SNRPE',
#   'ID3',
#   'STPG3',
#   'TPST2',
#   'BEX3',
#   'LPAR6',
#   'RPUSD1',
#   'PABIR2',
#   'ZNF790',
#   'Q96FS5',
#   'GPD1L',
#   'LFNG',
#   'BPGF-1',
#   'ING1',
#   'CAMK4',
#   'SWAP70',
#   'SUPT3H',
#   'COL4A1',
#   'MICAL2',
#   'RBM15',
#   'NNMT',
#   'CRMP1',
#   'FBXO44',
#   'SH3GL1',
#   'CCK',
#   'RAE1',
#   'GALNTL6',
#   'INPPL1',
#   'PARK7',
#   'SPIDR',
#   'RAPGEF3',
#   'EECP',
#   'PLEC',
#   'BCAS4',
#   'FUBP1',
#   'MCL1',
#   'GAL3ST1',
#   'SDHAF3',
#   'STARD9',
#   'TBC1D3',
#   'DKFZP434F0116',
#   'CTSA',
#   'PIGB',
#   'Q8NC36',
#   'DPM2',
#   'PRR5-ARHGAP8',
#   'PLK3',
#   'FBXL13',
#   'ZNF366',
#   'UCP2',
#   'TBC1D10B',
#   'GLIPR2',
#   'PPP1R11',
#   'BTBD9',
#   'RPGRIP1L',
#   'FSIP2',
#   'SPRING1',
#   'SPAG1',
#   'PRR20D',
#   'SPATA32',
#   'Q5T627',
#   'BHLHE41',
#   'Q59EV7',
#   'SRA1',
#   'EFCAB13',
#   'EPAS1',
#   'LRRN4CL',
#   'FOXP2',
#   'GNB4',
#   'PAM',
#   'GPX1',
#   'BCAR3',
#   'CPA4',
#   'FBF1',
#   'RLBP1',
#   'GPCPD1',
#   'CENPI',
#   'BIRC7',
#   'POLR1C',
#   'CLDND1',
#   'RP9',
#   'Q5VU21',
#   'Q9H7H1',
#   'HK2',
#   'SLC35E3',
#   'TAMALIN',
#   'NUP188',
#   'PSMD6',
#   'SLC1A1',
#   'VPS52',
#   'VPS16',
#   'IFNW1',
#   'TSR1',
#   'TP53I13',
#   'LEG1',
#   'SPOP',
#   'B4GALT4',
#   'F2Z2H2',
#   'SSTR5',
#   'GNL3L',
#   'ADA2',
#   'MAP3K2',
#   'PURA',
#   'CHRNA4',
#   'RNASET2',
#   'GTF2E2',
#   'CENPF',
#   'BEX4',
#   'PNN',
#   'HABP2',
#   'SEL1L3',
#   'DDX59',
#   'BTBD1',
#   'AGTR2',
#   'MSH3',
#   'DIPK1A',
#   'TOX4',
#   'COPS6',
#   'ZNF35',
#   'HDC',
#   'Q59FF6',
#   'SIK3',
#   'IFT43',
#   'SYCE1',
#   'PLAU',
#   'SMARCC2',
#   'TYRO3',
#   'C2ORF69',
#   'CCDC51',
#   'B2RCU6',
#   'ATF7',
#   'MBD6',
#   'PYY',
#   'COL14A1',
#   'GBA',
#   'DDX43',
#   'NRXN3',
#   'ABRA',
#   'HEY2',
#   'NOC2L',
#   'MED29',
#   'CSPP1',
#   'OFD1',
#   'RIMS2',
#   'HIC1',
#   'SAE1',
#   'NCAPG2',
#   'DNAJC3',
#   'ENKD1',
#   'HPCAL4',
#   'A6PW31',
#   'CEMIP2',
#   'MOAP1',
#   'TPRKB',
#   'HEL46',
#   'PAPSS1',
#   'ADNP',
#   'MAGEA1',
#   'PAN2',
#   'FFAR3',
#   'ARHGEF33',
#   'CCDC152',
#   'KAT6A',
#   'CHST8',
#   'ROM1',
#   'FBXO40',
#   'TLCD2',
#   'ELAPOR2',
#   'LAMA4',
#   'CELA2B',
#   'TRIB2',
#   'TNRC6B',
#   'MBD5',
#   'M1AP',
#   'WDR31',
#   'PTPN9',
#   'S100A2',
#   'CXCL10',
#   'LETM2',
#   'MSH2',
#   'CEP44',
#   'MYO19',
#   'Q9BRL5',
#   'G3V1Q1',
#   'PIK3R1',
#   'IFT20',
#   'P3H3',
#   'CHUK',
#   'HNRNPA2B1',
#   'SLC12A5',
#   'SLC13A2',
#   ...},
#  {'FLOT2',
#   'STK39',
#   'BROX',
#   'RAF1',
#   'PJA2',
#   'LRRC25',
#   'GHRHR',
#   'NACA',
#   'GYG2',
#   'DOP1A',
#   'NDUFA9',
#   'RUNDC3B',
#   'LBX2',
#   'HES4',
#   'GADD45G',
#   'CBLB',
#   'FAM83A',
#   'A8K6G4',
#   'PDPR',
#   'IFNA2',
#   'SERPINA7',
#   'LRRTM2',
#   'HIPK3',
#   'B3KRP9',
#   'C1ORF104',
#   'TMCO3',
#   'CHGB',
#   'TMEM50A',
#   'CNTNAP3',
#   'TWIST2',
#   'NOD1',
#   'ZNF865',
#   'LYPD3',
#   'ZSCAN4',
#   'DZIP3',
#   'TMEM258',
#   'TRIM66',
#   'ZNF300',
#   'RAB3IL1',
#   'SUSD4',
#   'CCDC12',
#   'SLC7A9',
#   'PHIP',
#   'C11ORF45',
#   'DLK2',
#   'BRMS1',
#   'ATP8B1',
#   'HOXC5',
#   'MAPK1IP1L',
#   'ARPC4-TTLL3',
#   'MED27',
#   'FAM107A',
#   'PHF24',
#   'Q96HN9',
#   'SPTY2D1',
#   'ESPL1',
#   'UPI0000411897',
#   'GRK2',
#   'TBC1D2B',
#   'CHMP1B',
#   'SLC10A3',
#   'RAB11B',
#   'ZNF836',
#   'PRPF31',
#   'TEX2',
#   'ABCC4',
#   'A6NG51',
#   'CDCA3',
#   'CDKL1',
#   'PDS5B',
#   'PHOSPHO2',
#   'DGKQ',
#   'CCDC91',
#   'IFNA6',
#   'DHX40',
#   'FAHD2B',
#   'NETO2',
#   'DOLK',
#   'NEF3',
#   'H4C7',
#   'NHLH2',
#   'KCTD9',
#   'ENDOG',
#   'CRYBA1',
#   'SAMM50',
#   'IL5',
#   'SPATA20',
#   'GNE',
#   'SLC38A2',
#   'GK3P',
#   'Q6ZT16',
#   'KRT82',
#   'BICDL2',
#   'RBM20',
#   'SGSM3',
#   'INSIG2',
#   'DNAJA4',
#   'ZNF281',
#   'PLIN2',
#   'PLSCR3',
#   'DDX42',
#   'CCDC88C',
#   'YAF2',
#   'ESYT1',
#   'C10ORF90',
#   'SLC30A4',
#   'PRDM5',
#   'MT1F',
#   'RNF115',
#   'RAP2B',
#   'PPFIA2',
#   'ZSCAN10',
#   'CREB3L3',
#   'FES',
#   'MSRA',
#   'NGRN',
#   'MED19',
#   'TUBA3E',
#   'B4DMS2',
#   'COMMD4',
#   'SOWAHB',
#   'UPI0002590962',
#   'CNOT9',
#   'AFG3L2',
#   'PRDX2',
#   'A0A1U9X8X8',
#   'TPD52',
#   'SLC25A15',
#   'MST1',
#   'EMG1',
#   'CXCL11',
#   'DGCR2',
#   'NDNF',
#   'COX3',
#   'PIAS3',
#   'TEAD3',
#   'VAV2',
#   'RFPL4A',
#   'NDUFB2',
#   'RGR',
#   'C12ORF4',
#   'POMGNT2',
#   'SLC25A29',
#   'PTK7',
#   'MROH8',
#   'INCA1',
#   'ZMYM1',
#   'CPS1',
#   'GPR55',
#   'RYBP',
#   'OR9G1',
#   'PTGDS',
#   'ACP1',
#   'CHAD',
#   'F5',
#   'MPST',
#   'XPO6',
#   'GJB6',
#   'SHKBP1',
#   'ISG15',
#   'RNF5',
#   'QPCT',
#   'HES7',
#   'TXNDC5',
#   'CTRB1',
#   'CKAP5',
#   'DTX2',
#   'RNF133',
#   'OR7D2',
#   'CCNF',
#   'MYLIP',
#   'EIF3L',
#   'WWP1',
#   'PAK5',
#   'CACNG2',
#   'ADSS2',
#   'JHY',
#   'SLC17A8',
#   'IL10RA',
#   'NCR2',
#   'MBD3L2',
#   'ZNF644',
#   'SRL',
#   'ZMAT2',
#   'CPLX1',
#   'KLHL7',
#   'C4ORF46',
#   'SPATA17',
#   'UCMA',
#   'ISYNA1',
#   'POLD4',
#   'RMND5A',
#   'C22ORF31',
#   'KLF13',
#   'GAST',
#   'LDHA',
#   'CCT2',
#   'ANKRD22',
#   'TFAP2D',
#   'FAM204A',
#   'UNC93B1',
#   'CASC5',
#   'A8K147',
#   'ELANE',
#   'GNPTG',
#   'ZNF180',
#   'ADORA2A',
#   'TMEM256',
#   'GRIN3A',
#   'RASA4',
#   'ZDHHC11',
#   'IL18',
#   'TXNRD3',
#   'Q14782',
#   'ZC3HC1',
#   'FAM20A',
#   'SVOPL',
#   'PRL',
#   'VGLL4',
#   'ZP1',
#   'ZNF343',
#   'ELOA',
#   'BRCC3',
#   'Q59EM9',
#   'FSBP',
#   'AACS',
#   'ING2',
#   'HHLA3',
#   'MRPS18A',
#   'TAC3',
#   'PLEKHA8',
#   'PADI4',
#   'ZDHHC23',
#   'MSTN',
#   'XPO4',
#   'ZNF69',
#   'CENPA',
#   'CICK0721Q.2',
#   'STK26',
#   'Q59EJ3',
#   'ARL5B',
#   'B3GALT4',
#   'DKK4',
#   'LONRF1',
#   'TARBP2',
#   'TPH1',
#   'TRAPPC13',
#   'GART',
#   'SPATS2',
#   'DDX47',
#   'RNFT1',
#   'DEFA5',
#   'CD47',
#   'WARS2',
#   'CTHRC1',
#   'HNRNPU',
#   'ERI3',
#   'SAAL1',
#   'TRPV5',
#   'CNRIP1',
#   'TRIP6',
#   'NKX3-1',
#   'CEP152',
#   'Q5T3S7',
#   'TMEM214',
#   'UBE2D4',
#   'RCOR3',
#   'LOC729862',
#   'BMP10',
#   'UTP6',
#   'Q86U29',
#   'TTC32',
#   'SERPINA10',
#   'PDIA6',
#   'ARL6IP5',
#   'NMRAL1',
#   'TRIB1',
#   'ANGPTL6',
#   'TGFBR2',
#   'UQCC3',
#   'C9ORF75',
#   'PIEZO2',
#   'ZMYM3',
#   'NHSL2',
#   'ZNF211',
#   'E9PAT2',
#   'BCL2',
#   'OK/KNS-CL.4',
#   'ICOS',
#   'Q5TBK5',
#   'PSMD14',
#   'UBQLN2',
#   'GLCE',
#   'RAB29',
#   'JRK',
#   'HCRTR2',
#   'J3KNL3',
#   'FAM228A',
#   'DUSP12',
#   'CTSZ',
#   'FAM25G',
#   'GALNT4',
#   'FAM83F',
#   'AHNAK',
#   'ZNF19',
#   'HEMGN',
#   'USB1',
#   'ZNF561',
#   'GDF3',
#   'CHRNA6',
#   'CFAP94',
#   'CHIC2',
#   'DDX1',
#   'BRD2',
#   'PAX9',
#   'LRP5L',
#   'PCBD1',
#   'TICAM2',
#   'PGAM4',
#   'SETDB2',
#   'PODN',
#   'NXPE1',
#   'SCN1A',
#   'ABRAXAS1',
#   'ADHFE1',
#   'MIA3',
#   'RHAG',
#   'Q53HQ0',
#   'ZNF443',
#   'PCYOX1',
#   'ATOH7',
#   'NIPSNAP2',
#   'ATP11C',
#   'MRFAP1L1',
#   'DNAH7',
#   'ODF4',
#   'VTA1',
#   'FAM200A',
#   'COL4A5',
#   'DRG1',
#   'PEX14',
#   'SETMAR',
#   'E7EMG6',
#   'HEATR5B',
#   'LRRC41',
#   'PRSS21',
#   'GALP',
#   'MBL2',
#   'DMPK',
#   'NR2F1',
#   'CD3E',
#   'ANXA11',
#   'CCNJ',
#   'SHPK',
#   'RBBP9',
#   'SMIM19',
#   'POLR3G',
#   'HIKESHI',
#   'SYCP3',
#   'PBX3',
#   'ABCA2',
#   'SCP2',
#   'HMGB2',
#   'MROH2B',
#   'ZNF22',
#   'LCOR',
#   'SYK',
#   'SLIT3',
#   'CHAF1B',
#   'EBF1',
#   'CTIF',
#   'TMEM39A',
#   'SFTPC',
#   'NRM',
#   'Q9P1I0',
#   'ZNF433',
#   'PCSK2',
#   'ZNF423',
#   'RALGPS1',
#   'CUL7',
#   'ZNF33A',
#   'SOAT2',
#   'CD99',
#   'CD53',
#   'PSMC2',
#   'CCDC142',
#   'SPPL2C',
#   'COPZ1',
#   'SYBU',
#   'RPS3',
#   'MZF1',
#   'TMEM117',
#   'FOXJ2',
#   'DCAF12',
#   'NONO',
#   'RIMS4',
#   'RANGAP1',
#   'LTV1',
#   'SYTL4',
#   'FNBP1L',
#   'NBPF3',
#   'KRTAP1-5',
#   'DGAT1',
#   'CAPN5',
#   'CFAP410',
#   'KAT7',
#   'HBA2',
#   'KDM8',
#   'ECT2',
#   'STAU2',
#   'SCARB1',
#   'SNTB1',
#   'PCDHB7',
#   'HHIPL2',
#   'PGAP3',
#   'KLHDC10',
#   'ALG10',
#   'Q5T189',
#   'DPP7',
#   'CMC1',
#   'Q9HAA9',
#   'ZNF282',
#   'USP51',
#   'FOXJ3',
#   'ANP32C',
#   'THEMIS2',
#   'CBS',
#   'UPI000187F6BA',
#   'NUBP1',
#   'PI4KB',
#   'GUCY2F',
#   'AMY1A',
#   'BICD1',
#   'URM1',
#   'GLCCI1',
#   'GFOD1',
#   'Q8WYZ0',
#   'HECTD3',
#   'PITX2',
#   'RUBCNL',
#   'EMD',
#   'MED12',
#   'STKLD1',
#   'ZNF346',
#   'B7Z2A4',
#   'Q59G16',
#   'ELF4',
#   'BLID',
#   'KANSL2',
#   'RGS16',
#   'FIBCD1',
#   'MRPL12',
#   'MLLT6',
#   'ECE1',
#   'NAT2',
#   'HYDIN',
#   'MMP1',
#   'HBG2',
#   'NUDT9',
#   'ADRA2A',
#   'MXD1',
#   'FRMD6',
#   'IL1RAPL1',
#   'SEMA3C',
#   'MAGEA3',
#   'KLF3',
#   'IKZF4',
#   'SMC4',
#   'Q5JW18',
#   'GGN',
#   'TPM2',
#   'DDI1',
#   'NFATC2IP',
#   'UNC45A',
#   'ALG5',
#   'CENPS',
#   'SP3',
#   'ZBTB5',
#   'C4ORF3',
#   'ZNF469',
#   'SLC35A5',
#   'YBEY',
#   'HBQ1',
#   'HNRNPL',
#   'ZFAND5',
#   'MSH4',
#   'C6ORF47',
#   'NOP58',
#   'NFE2L2',
#   'PEG10',
#   'SMIM21',
#   'NUDCD1',
#   'MND1',
#   'PEAR1',
#   'BNIP3L',
#   'MUC5B',
#   'B7Z8L6',
#   'SACS',
#   'RCSD1',
#   'OR2G6',
#   'RSPO3',
#   'GAD1',
#   'POLR3B',
#   'MRPS28',
#   'BOLL',
#   'MYOZ3',
#   'GPBP1',
#   'KHNYN',
#   'UCN',
#   'SNX4',
#   'RTN2',
#   'BEST1',
#   'SPHKAP',
#   'NOC3L',
#   'AAR2',
#   'C11ORF54',
#   'GHRH',
#   'CD24',
#   'CEP131',
#   'CYB561',
#   'ZSWIM9',
#   'GGA3',
#   'MKRN1',
#   'SCAF11',
#   'MRPL22',
#   'CUL5',
#   'NXN',
#   'G7',
#   'TPT1',
#   'NKX2-5',
#   'SPTBN2',
#   'ARHGAP19',
#   'DAOA',
#   'PRKCZ',
#   'C5',
#   'PIR',
#   'SH3BP1',
#   'VANGL2',
#   'TNFRSF9',
#   'NACC2',
#   'KLHL30-AS1',
#   'C18ORF55',
#   'ZGRF1',
#   'TMEM234',
#   'SPDL1',
#   'HAUS2',
#   'PLN',
#   'INTU',
#   'DTD1',
#   'EPHA6',
#   'PRSS35',
#   'OR1D2',
#   'TMEM161B',
#   'YDJC',
#   'GDPD2',
#   'KCTD3',
#   'ZCWPW1',
#   'IDS',
#   'BBS1',
#   'REXO1L1P',
#   'PDCD2L',
#   'SPRY4',
#   'GNPAT',
#   'RAD9A',
#   'TMEM196',
#   'DPY30',
#   'TOE1',
#   'DMTN',
#   'PRR10',
#   'SIX4',
#   'GRPR',
#   'GMPR',
#   'F5GZT1',
#   'EIF2S3B',
#   'MAP3K8',
#   'ZF30',
#   'PDP2',
#   'TPPP',
#   'FBXO39',
#   'MOCS1',
#   'MRPL35',
#   'PPP3CB',
#   'SPP1',
#   'TOP3B',
#   'ARL10',
#   'GYPC',
#   'ANKS1B',
#   'PGAM5',
#   'KHDC1',
#   'ALG9',
#   'ZNF726',
#   'SLC10A6',
#   'ENDOV',
#   'RHOC',
#   'IL17RB',
#   'BMPR2',
#   'IL37',
#   'ZNF333',
#   'DNAJB1',
#   'K7EK94',
#   'MGME1',
#   'ARHGAP12',
#   'SPEF1',
#   'SFPQ',
#   'ADGRE2',
#   'NUP160',
#   'PELO',
#   'VCPIP1',
#   'PPAT',
#   'ZNF10',
#   'SLC1A6',
#   'A8K8G8',
#   'MGAT5',
#   'KCNJ12',
#   'STX10',
#   'ADRA2C',
#   'SH3KBP1',
#   'FAM174A',
#   'FIG4',
#   'E9PJ43',
#   'EXOSC1',
#   'DNAJB9',
#   'DAGLA',
#   'Q9BZT1',
#   'Q5W150',
#   'IL6ST',
#   'GDF5',
#   'TNR',
#   'FAM180B',
#   'GP9',
#   'ZNF526',
#   'CDC25A',
#   'FCRL4',
#   'CFHR5',
#   'NAA35',
#   'STEAP3',
#   'XRCC3',
#   'MTERF3',
#   'HARS1',
#   'GTPBP8',
#   'SKA3',
#   'PCMTD1',
#   'SHC2',
#   'MAGEF1',
#   'ARL15',
#   'NDE1',
#   'CEP85L',
#   'SMCR8',
#   'SLC7A3',
#   'SENP5',
#   'XK',
#   'SSR4',
#   'ZNF75A',
#   'APPBP2',
#   'CLTCL1',
#   'DMBT1',
#   'MRPL54',
#   'ARHGAP11A',
#   'EED',
#   'ANKDD1B',
#   'ABTB2',
#   'RPS10-NUDT3',
#   'GALNT3',
#   'CHORDC1',
#   'MYOCD',
#   'FAM153A',
#   'TNFRSF10D',
#   'B4DF43',
#   'PLG',
#   'HLA-DOA',
#   'IFT74',
#   'ECRG4',
#   'SEMA4B',
#   'EFCAB14',
#   'ZCCHC8',
#   'NDUFB6',
#   'GPX3',
#   'PCDHA10',
#   'FUT4',
#   'PCGF2',
#   'FAM184A',
#   'TSPYL6',
#   'ADM',
#   'DLG2',
#   'TYSND1',
#   'RAB23',
#   'B4DZP6',
#   'PLBD1',
#   'DRC1',
#   'VHL',
#   'SP2',
#   'KCNMA1',
#   'CCDC77',
#   'INPP5E',
#   'Q5VYA4',
#   'FABP1',
#   'VPS9D1',
#   'PTOV1',
#   'AKR1B1',
#   'GPRC5D',
#   'GON4L',
#   'VAV3',
#   'GSTCD',
#   'GABRE',
#   'ARHGAP32',
#   'WLS',
#   'SPANXA1|SPANXA2',
#   'PIAS1',
#   'GIGYF1',
#   'HAUS7',
#   'ISG20L2',
#   'TGIF2LY',
#   'POLR2J2',
#   'VIP',
#   'ZNF823',
#   'SPON2',
#   'TRPA1',
#   'PPRC1',
#   'RADX',
#   'C7ORF26',
#   'MAPKAPK2',
#   'KRTAP5-9',
#   'KRTAP2-4',
#   'IFNA1|IFNA13',
#   'ERAF',
#   'ATG7',
#   'NIPAL3',
#   'RPL8',
#   'LOXHD1',
#   'RFC4',
#   'SOX4',
#   'F5H3R7',
#   'NPHP4',
#   'C4ORF17',
#   'SIRT4',
#   'DKFZP781I1140',
#   'FN3KRP',
#   'MINK1',
#   'B4GALNT2',
#   'APOC1',
#   'FBXL14',
#   'CALM1',
#   'SRPK1',
#   'CSK',
#   'ADAM33',
#   'MPRIP',
#   'FAM120C',
#   'TSHZ2',
#   'PAPPA2',
#   'PARD3B',
#   'USP22',
#   'PDE3B',
#   'CBX8',
#   'MSMB',
#   'CYTH4',
#   'CACNA1A',
#   'SH3D21',
#   'CCNT1',
#   'ZCCHC14',
#   'TMEM102',
#   'HYPK',
#   'FYB1',
#   'WDR3',
#   'CLEC17A',
#   'RRM1',
#   'BRIX1',
#   'C1ORF194',
#   'SCGB2A2',
#   'A8K2S7',
#   'C12ORF76',
#   'NEU2',
#   'ZNF780A',
#   'MYOT',
#   'RNPS1',
#   'WDR1',
#   'EPN2',
#   'IGKV1-33',
#   'TAF1B',
#   'TMUB2',
#   'KRT72',
#   'PCDH12',
#   'MUC1',
#   'CCDC179',
#   'Q5QPJ8',
#   'ARHGAP25',
#   'Q6ZVU3',
#   'CCZ1B',
#   'PPP6R2',
#   'CLEC4M',
#   'NOL6',
#   'AHSP',
#   'C16ORF74',
#   'SLFN12',
#   'LAMB1',
#   'REEP1',
#   'C18ORF63',
#   'H2AC18|H2AC19',
#   'TIMMDC1',
#   'COPS7B',
#   'GLMP',
#   'H2BC14',
#   'BDH2',
#   'CH25H',
#   'RPP30',
#   'AK7',
#   'RPL36',
#   'F8W6G5',
#   'SLC41A3',
#   'OPTC',
#   'ZNF74',
#   'STX8',
#   'SPTBN4',
#   'PPAN',
#   'MBTPS2',
#   'BEX3',
#   'NECTIN2',
#   'KCNH2',
#   'ZNF155',
#   'RPL7',
#   'INTS2',
#   'NPIPB5',
#   'SLC38A11',
#   'BPGF-1',
#   'VIPR1',
#   'CLDN14',
#   'APBA3',
#   'GJA3',
#   'PARVG',
#   'RTL4',
#   'USF2',
#   'CTSG',
#   'BEX1',
#   'TMPRSS3',
#   'OGFOD1',
#   'WWP2',
#   'UHRF1BP1L',
#   'DIS3L2',
#   'CXCL13',
#   'POU6F1',
#   'PLEC',
#   'RRM2B',
#   'TNFSF4',
#   'ABCF3',
#   'KIAA1217',
#   'NUDT6',
#   'HSDL2',
#   'BTN3A1',
#   'ARPC4',
#   'FNTB',
#   'PLK3',
#   'NDRG1',
#   'SLC25A13',
#   'SNCAIP',
#   'FCN2',
#   'C9JAL6',
#   'MGAT2',
#   'SNRPD2',
#   'TRIM3',
#   'Q9T9Y2',
#   'ARHGAP9',
#   'ZSCAN32',
#   'ANKFY1',
#   'TRIM49',
#   'B4DJ69',
#   'FAM214B',
#   'ALPK1',
#   'SLC25A11',
#   'PDZRN4',
#   'IL31',
#   'FCGR2A',
#   'SRA1',
#   'MSANTD3',
#   'HAVCR2',
#   'ABHD14B',
#   'PAM',
#   'ATP6V1E1',
#   'XPOT',
#   'ZDHHC21',
#   'CD58',
#   'AMER1',
#   'NR4A2',
#   'NDUFAF1',
#   'Q59GD3',
#   'CEP78',
#   'MTHFD2',
#   'RNF146',
#   'AIF1L',
#   'IMUP',
#   'ZNF518B',
#   'RP9',
#   'ARHH',
#   'PPM1F',
#   'FAM153B',
#   'ZNF860',
#   'ACSS1',
#   'TNFAIP3',
#   'Q7Z586',
#   'Q5THJ0',
#   'TM4SF18',
#   'SNRPD3',
#   'ZSCAN18',
#   'BPIFB1',
#   'SPOP',
#   'GSTA3',
#   'SOX18',
#   'F2Z2H2',
#   'LEPR',
#   'LURAP1L',
#   'MKRN4P',
#   'MYO7A',
#   'ARF5',
#   'CFAP97D1',
#   'PURA',
#   'FARS2',
#   'CTU1',
#   'ETFA',
#   'PSME4',
#   'MED23',
#   'EXPH5',
#   'C4ORF33',
#   'WNT5B',
#   'STK36',
#   'SYNE3',
#   'LYVE1',
#   'AGTR2',
#   'KIAA0226',
#   'PDXDC1',
#   'NCAPD3',
#   'CD164L2',
#   'FASTKD3',
#   'ZIC1',
#   'SLC52A3',
#   'GTF2A2',
#   'UBE3B',
#   'HP1BP3',
#   'GPR22',
#   'ST3GAL2',
#   'IFT43',
#   'NPVF',
#   'ADAT3',
#   'FAM110A',
#   'EIF1AX',
#   'ABLIM2',
#   'ITGA1',
#   'Q6TXQ4',
#   'MFN1',
#   'B2RCU6',
#   'HDAC10',
#   'PGM3',
#   'GCDH',
#   'EEF1A1',
#   'CNTFR',
#   'PAK6',
#   'SLC4A7',
#   'DNMBP',
#   'BUB1',
#   'MSRB1',
#   'ITGA10',
#   'IFIT1',
#   'MBOAT2',
#   'HEY2',
#   'RBMS2',
#   'BIRC3',
#   'HMX3',
#   'NINJ1',
#   'CA6',
#   'TNK1',
#   'HS6ST1',
#   'RNASE2',
#   'TRAPPC3',
#   'NCAPG2',
#   'ERCC6L2',
#   'TNRC6C',
#   'TGFA',
#   'BAG3',
#   'TPRKB',
#   'RPL23A',
#   'MAN1B1',
#   'NCKIPSD',
#   'CMIP',
#   'TMEM87B',
#   'ABCB7',
#   'MAGEA1',
#   'NUPR1',
#   'MESP2',
#   'SWI5',
#   'GDF9',
#   'DERA',
#   'ARHGEF12',
#   'ERVK3-1',
#   'CHST8',
#   'ADRB2',
#   'CGRRF1',
#   'TLCD2',
#   'FBXO40',
#   'PDIA4',
#   'CYTIP',
#   'ARIH2',
#   'ARAP1',
#   'HCTP4',
#   ...})

# %%
get_random_gene_list(taiji_overlapping_random_fd, set_name = 'taiji_fd')
get_random_gene_list(taiji_overlapping_random, set_name = 'taiji')
get_random_gene_list(pps_overlapping_random, set_name = 'pps')
get_random_gene_list(pps_overlapping_random_fd, set_name = 'pps_fd')
get_random_gene_list(pps_taiji_overlapping_random_fd, set_name = 'pps_taiji_fd')
get_random_gene_list(pps_taiji_overlapping_random, set_name = 'pps_taiji')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 get_random_gene_list(taiji_overlapping_random_fd, set_name = 'taiji_fd')
#       2 get_random_gene_list(taiji_overlapping_random, set_name = 'taiji')
#       3 get_random_gene_list(pps_overlapping_random, set_name = 'pps')
#
# NameError: name 'taiji_overlapping_random_fd' is not defined
